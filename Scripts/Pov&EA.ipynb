# %%
import pandas as pd
import requests

url = 'https://api.census.gov/data/2019/acs/acs5?get=B01001_001E,B17001_002E,B17001_003E,GEO_ID,NAME&for=tract:*&in=state:36&in=county:*'
response = requests.get(url)
data = response.json()

df = pd.DataFrame(data[1:], columns=data[0])

# %%
df
# Out:
#      B01001_001E B17001_002E B17001_003E                GEO_ID  \
# 0           3563        1312         579  1400000US36067005500
# 1           1599         117          69  1400000US36067005601
# 2           1842         589         282  1400000US36067006102
# 3           3844         396         175  1400000US36067011201
# 4           3950         144          11  1400000US36067005602
# ...          ...         ...         ...                   ...
# 4913        3048         639         458  1400000US36067001800
# 4914        1393         684         322  1400000US36067003400
# 4915        1387         784         399  1400000US36067004000
# 4916        1541          85          21  1400000US36067004800
# 4917        1930         911         419  1400000US36067005300
#
#                                                 NAME state county   tract
# 0         Census Tract 55, Onondaga County, New York    36    067  005500
# ...

# %%
df.rename(columns={'B01001_001E': 'Total Population', 'B17001_002E': 'Below Poverty Level', 'B17001_003E': 'Above Poverty Level', 'NAME': 'Name', 'GEO_ID': 'geoid'}, inplace=True)

# %%
df
# Out:
#      Total Population Below Poverty Level Above Poverty Level  \
# 0                3563                1312                 579
# 1                1599                 117                  69
# 2                1842                 589                 282
# 3                3844                 396                 175
# 4                3950                 144                  11
# ...               ...                 ...                 ...
# 4913             3048                 639                 458
# 4914             1393                 684                 322
# 4915             1387                 784                 399
# 4916             1541                  85                  21
# 4917             1930                 911                 419
#
#                      geoid                                            Name  \
# 0     1400000US36067005500      Census Tract 55, Onondaga County, New York
# ...

# %%
df[['Census Tract', 'County Name', 'State']] = df['Name'].str.split(',', expand=True)
df
# Out:
#      Total Population Below Poverty Level Above Poverty Level  \
# 0                3563                1312                 579
# 1                1599                 117                  69
# 2                1842                 589                 282
# 3                3844                 396                 175
# 4                3950                 144                  11
# ...               ...                 ...                 ...
# 4913             3048                 639                 458
# 4914             1393                 684                 322
# 4915             1387                 784                 399
# 4916             1541                  85                  21
# 4917             1930                 911                 419
#
#                      geoid                                            Name  \
# 0     1400000US36067005500      Census Tract 55, Onondaga County, New York
# ...

# %%
df.drop(columns=['Name', 'state', 'County Name', 'State', 'Census Tract'], inplace=True)
df
# Out:
#      Total Population Below Poverty Level Above Poverty Level  \
# 0                3563                1312                 579
# 1                1599                 117                  69
# 2                1842                 589                 282
# 3                3844                 396                 175
# 4                3950                 144                  11
# ...               ...                 ...                 ...
# 4913             3048                 639                 458
# 4914             1393                 684                 322
# 4915             1387                 784                 399
# 4916             1541                  85                  21
# 4917             1930                 911                 419
#
#                      geoid county   tract
# 0     1400000US36067005500    067  005500
# 1     1400000US36067005601    067  005601
# 2     1400000US36067006102    067  006102
# 3     1400000US36067011201    067  011201
# ...

# %%
counties = ['047', '005', '061', '085', '081']
county = df['county'].isin(counties)
df = df[county]
df
# Out:
#      Total Population Below Poverty Level Above Poverty Level  \
# 8                2238                 290                 110
# 9                1771                 359                 148
# 10               1335                 158                  58
# 11               3620                 439                 203
# 12               6851                1115                 562
# ...               ...                 ...                 ...
# 4868             2811                 399                 169
# 4869             1920                 140                  70
# 4870             1718                  97                  26
# 4871             5488                 926                 479
# 4887             1796                  97                  44
#
#                      geoid county   tract
# 8     1400000US36081036100    081  036100
# 9     1400000US36081036300    081  036300
# 10    1400000US36081037100    081  037100
# 11    1400000US36081037700    081  037700
# ...

# %%
df['county'] = df['county'].replace({'047':'Kings', '005': 'Bronx', '061': 'New York', '085': 'Richmond', '081': 'Queens'})
# Out:
# /var/folders/g5/l0bxynmx73s5ncy4_m69508r0000gn/T/ipykernel_88928/2119150980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['county'] = df['county'].replace({'047':'Kings', '005': 'Bronx', '061': 'New York', '085': 'Richmond', '081': 'Queens'})

# %%
df
# Out:
#      Total Population Below Poverty Level Above Poverty Level  \
# 8                2238                 290                 110
# 9                1771                 359                 148
# 10               1335                 158                  58
# 11               3620                 439                 203
# 12               6851                1115                 562
# ...               ...                 ...                 ...
# 4868             2811                 399                 169
# 4869             1920                 140                  70
# 4870             1718                  97                  26
# 4871             5488                 926                 479
# 4887             1796                  97                  44
#
#                      geoid    county   tract
# 8     1400000US36081036100    Queens  036100
# 9     1400000US36081036300    Queens  036300
# 10    1400000US36081037100    Queens  037100
# ...

# %%
#df.to_csv('Poverty.csv', index=False)

# %%
url = 'https://api.census.gov/data/2019/acs/acs5?get=B15003_017E,B15003_018E,B15003_019E,B15003_020E,B15003_021E,B15003_022E,B15003_023E,B15003_024E,B15003_025E,GEO_ID,NAME&for=tract:*&in=state:36&in=county:*'
response = requests.get(url)
data = response.json()

df = pd.DataFrame(data[1:], columns=data[0])

# %%
df
# Out:
#      B15003_017E B15003_018E B15003_019E B15003_020E B15003_021E B15003_022E  \
# 0            376         143         170         271         256         350
# 1            104          12          12         147          83         260
# 2            318          34          92         152         104         300
# 3            602         204         167         352         385         441
# 4              0           0           0           9          21          32
# ...          ...         ...         ...         ...         ...         ...
# 4913         369         117         119         273         187         499
# 4914          23          19          31          78           0         130
# 4915         267          97          78          74          40          47
# 4916         168          42          66         143          98         318
# 4917         243          31          69         216          92          42
#
# ...

# %%
df[['Census Tract', 'County Name', 'State']] = df['NAME'].str.split(',', expand=True)
df
# Out:
#      B15003_017E B15003_018E B15003_019E B15003_020E B15003_021E B15003_022E  \
# 0            376         143         170         271         256         350
# 1            104          12          12         147          83         260
# 2            318          34          92         152         104         300
# 3            602         204         167         352         385         441
# 4              0           0           0           9          21          32
# ...          ...         ...         ...         ...         ...         ...
# 4913         369         117         119         273         187         499
# 4914          23          19          31          78           0         130
# 4915         267          97          78          74          40          47
# 4916         168          42          66         143          98         318
# 4917         243          31          69         216          92          42
#
# ...

# %%
df.drop(columns=['NAME', 'state', 'County Name', 'State', 'Census Tract'], inplace=True)
df
# Out:
#      B15003_017E B15003_018E B15003_019E B15003_020E B15003_021E B15003_022E  \
# 0            376         143         170         271         256         350
# 1            104          12          12         147          83         260
# 2            318          34          92         152         104         300
# 3            602         204         167         352         385         441
# 4              0           0           0           9          21          32
# ...          ...         ...         ...         ...         ...         ...
# 4913         369         117         119         273         187         499
# 4914          23          19          31          78           0         130
# 4915         267          97          78          74          40          47
# 4916         168          42          66         143          98         318
# 4917         243          31          69         216          92          42
#
# ...

# %%
counties = ['047', '005', '061', '085', '081']
county = df['county'].isin(counties)
df = df[county]
df
# Out:
#      B15003_017E B15003_018E B15003_019E B15003_020E B15003_021E B15003_022E  \
# 8            546          57          59          94          56         206
# 9            469          18          14         105          87          91
# 10           248          10          34         124          75         172
# 11           790          21          40         175         105          96
# 12          1638          75          78         313         111         173
# ...          ...         ...         ...         ...         ...         ...
# 4868         557           9           9         122         156         656
# 4869         271          82          43         162         130         299
# 4870         380          27          66         166         131         219
# 4871         707         142         128         707         179        1102
# 4887          36           6          12          48          46         704
#
# ...

# %%
df['county'] = df['county'].replace({'047':'Kings', '005': 'Bronx', '061': 'New York', '085': 'Richmond', '081': 'Queens'})
df
# Out:
# /var/folders/g5/l0bxynmx73s5ncy4_m69508r0000gn/T/ipykernel_88928/474890625.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['county'] = df['county'].replace({'047':'Kings', '005': 'Bronx', '061': 'New York', '085': 'Richmond', '081': 'Queens'})
#      B15003_017E B15003_018E B15003_019E B15003_020E B15003_021E B15003_022E  \
# 8            546          57          59          94          56         206
# 9            469          18          14         105          87          91
# 10           248          10          34         124          75         172
# 11           790          21          40         175         105          96
# 12          1638          75          78         313         111         173
# ...

# %%
df = df.rename(columns={'B15003_017E': 'Less than 9th grade', 
                        'B15003_018E': '9th to 12th grade, no diploma', 
                        'B15003_019E': 'High school diploma', 
                        'B15003_020E': 'Some college',
                        'B15003_021E': 'Associate degree', 
                        'B15003_022E': 'Bachelor degree', 
                        'B15003_023E': 'Graduate degree', 
                        'B15003_024E': 'High school graduate, or higher',
                        'B15003_025E': 'Bachelor degree, or higher', 
                        'county': 'County', 
                       'GEO_ID': 'geoid'})
df
# Out:
#      Less than 9th grade 9th to 12th grade, no diploma High school diploma  \
# 8                    546                            57                  59
# 9                    469                            18                  14
# 10                   248                            10                  34
# 11                   790                            21                  40
# 12                  1638                            75                  78
# ...                  ...                           ...                 ...
# 4868                 557                             9                   9
# 4869                 271                            82                  43
# 4870                 380                            27                  66
# 4871                 707                           142                 128
# 4887                  36                             6                  12
#
# ...

# %%
#df.to_csv('EducationalAttainment.csv', index=False)

# %%
df['tract'].unique()
# Out:
# array(['036100', '036300', '037100', ..., '067400', '068600', '032100'],
#       dtype=object)

# %%
geo = gpd.read_file('/Users/ananyarajesh/Downloads/nyct2020_23a/nyct2020.shp')

# %%
p = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/Poverty.csv')

# %%
ea = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/EducationalAttainment.csv')

# %%
p
# Out:
#                    geoid                             name  B17001001  \
# 0              04000US36                         New York   19604130
# 1     14000US36001000100       Census Tract 1, Albany, NY       2156
# 2     14000US36001000201    Census Tract 2.01, Albany, NY       2890
# 3     14000US36001000202    Census Tract 2.02, Albany, NY       2434
# 4     14000US36001000301    Census Tract 3.01, Albany, NY       3108
# ...                  ...                              ...        ...
# 5407  14000US36123150301  Census Tract 1503.01, Yates, NY       2721
# 5408  14000US36123150302  Census Tract 1503.02, Yates, NY       1946
# 5409  14000US36123150400     Census Tract 1504, Yates, NY       2938
# 5410  14000US36123150501  Census Tract 1505.01, Yates, NY       2286
# 5411  14000US36123150502  Census Tract 1505.02, Yates, NY       2583
#
#       B17001001, Error  B17001002  B17001002, Error  B17001003  \
# 0                 2901    2636823             26596    1169005
# ...

# %%
ea
# Out:
#       Less than 9th grade  9th to 12th grade, no diploma  High school diploma  \
# 0                     546                             57                   59
# 1                     469                             18                   14
# 2                     248                             10                   34
# 3                     790                             21                   40
# 4                    1638                             75                   78
# ...                   ...                            ...                  ...
# 2162                  557                              9                    9
# 2163                  271                             82                   43
# 2164                  380                             27                   66
# 2165                  707                            142                  128
# 2166                   36                              6                   12
#
# ...

# %%
EAP = pd.merge(p, ea, on='geoid', how='left')

# %%
EAP.rename(columns={'county': 'County Name'}, inplace=True)

# %%
EAP
# Out:
#                    geoid                             name  B17001001  \
# 0              04000US36                         New York   19604130
# 1     14000US36001000100       Census Tract 1, Albany, NY       2156
# 2     14000US36001000201    Census Tract 2.01, Albany, NY       2890
# 3     14000US36001000202    Census Tract 2.02, Albany, NY       2434
# 4     14000US36001000301    Census Tract 3.01, Albany, NY       3108
# ...                  ...                              ...        ...
# 5407  14000US36123150301  Census Tract 1503.01, Yates, NY       2721
# 5408  14000US36123150302  Census Tract 1503.02, Yates, NY       1946
# 5409  14000US36123150400     Census Tract 1504, Yates, NY       2938
# 5410  14000US36123150501  Census Tract 1505.01, Yates, NY       2286
# 5411  14000US36123150502  Census Tract 1505.02, Yates, NY       2583
#
#       B17001001, Error  B17001002  B17001002, Error  B17001003  \
# 0                 2901    2636823             26596    1169005
# ...

# %%
EAP.columns
# Out:
# Index(['geoid', 'name', 'B17001001', 'B17001001, Error', 'B17001002',
#        'B17001002, Error', 'B17001003', 'B17001003, Error', 'B17001004',
#        'B17001004, Error',
#        ...
#        '9th to 12th grade, no diploma', 'High school diploma', 'Some college',
#        'Associate degree', 'Bachelor degree', 'Graduate degree',
#        'High school graduate, or higher', 'Bachelor degree, or higher',
#        'County', 'tract'],
#       dtype='object', length=131)

# %%
#EAP.to_csv('eap.csv', index=False)

# %% [markdown]
# # ----------

# %%
import geopandas as gpd
gdf = gpd.read_file('/Users/ananyarajesh/Downloads/nynta2020_23a/nynta2020.shp')

# %%
geo = gpd.read_file('/Users/ananyarajesh/Downloads/nyct2020_23a/nyct2020.shp')

# %%
df = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/eap.csv')

# %%
gdf
# Out:
#      BoroCode       BoroName CountyFIPS NTA2020                      NTAName  \
# 0           3       Brooklyn        047  BK0101                   Greenpoint
# 1           3       Brooklyn        047  BK0102                 Williamsburg
# 2           3       Brooklyn        047  BK0103           South Williamsburg
# 3           3       Brooklyn        047  BK0104            East Williamsburg
# 4           3       Brooklyn        047  BK0201             Brooklyn Heights
# ..        ...            ...        ...     ...                          ...
# 257         5  Staten Island        085  SI0391      Freshkills Park (South)
# 258         5  Staten Island        085  SI9561               Fort Wadsworth
# 259         5  Staten Island        085  SI9591  Hoffman & Swinburne Islands
# 260         5  Staten Island        085  SI9592                 Miller Field
# 261         5  Staten Island        085  SI9593             Great Kills Park
#
#       NTAAbbrev NTAType CDTA2020  \
# ...

# %%
geo
# Out:
#      CTLabel BoroCode       BoroName  CT2020 BoroCT2020 CDEligibil  \
# 0          1        1      Manhattan  000100    1000100       None
# 1       2.01        1      Manhattan  000201    1000201       None
# 2          6        1      Manhattan  000600    1000600       None
# 3      14.01        1      Manhattan  001401    1001401       None
# 4      14.02        1      Manhattan  001402    1001402       None
# ...      ...      ...            ...     ...        ...        ...
# 2320      77        5  Staten Island  007700    5007700       None
# 2321   19.02        4         Queens  001902    4001902       None
# 2322  171.01        4         Queens  017101    4017101       None
# 2323     475        4         Queens  047500    4047500       None
# 2324     687        4         Queens  068700    4068700       None
#
#                                                 NTAName NTA2020 CDTA2020  \
# 0     The Battery-Governors Island-Ellis Island-Libe...  MN0191     MN01
# ...

# %%
df
# Out:
#       Total Population  Below Poverty Level  Above Poverty Level  \
# 0                 2238                  290                  110
# 1                 1771                  359                  148
# 2                 1335                  158                   58
# 3                 3620                  439                  203
# 4                 6851                 1115                  562
# ...                ...                  ...                  ...
# 2162              2811                  399                  169
# 2163              1920                  140                   70
# 2164              1718                   97                   26
# 2165              5488                  926                  479
# 2166              1796                   97                   44
#
#                      geoid County Name  tract_x  Less than 9th grade  \
# 0     1400000US36081036100      Queens    36100                  546
# ...

# %%
df['GEOID'] = df['geoid'].apply(lambda x: x[-11:])
df
# Out:
#       Total Population  Below Poverty Level  Above Poverty Level  \
# 0                 2238                  290                  110
# 1                 1771                  359                  148
# 2                 1335                  158                   58
# 3                 3620                  439                  203
# 4                 6851                 1115                  562
# ...                ...                  ...                  ...
# 2162              2811                  399                  169
# 2163              1920                  140                   70
# 2164              1718                   97                   26
# 2165              5488                  926                  479
# 2166              1796                   97                   44
#
#                      geoid County Name  tract_x  Less than 9th grade  \
# 0     1400000US36081036100      Queens    36100                  546
# ...

# %%
df.drop(['geoid'], axis=1)
# Out:
#       Total Population  Below Poverty Level  Above Poverty Level County Name  \
# 0                 2238                  290                  110      Queens
# 1                 1771                  359                  148      Queens
# 2                 1335                  158                   58      Queens
# 3                 3620                  439                  203      Queens
# 4                 6851                 1115                  562      Queens
# ...                ...                  ...                  ...         ...
# 2162              2811                  399                  169       Kings
# 2163              1920                  140                   70       Kings
# 2164              1718                   97                   26       Kings
# 2165              5488                  926                  479       Kings
# 2166              1796                   97                   44    New York
#
# ...

# %%
df.columns
# Out:
# Index(['Total Population', 'Below Poverty Level', 'Above Poverty Level',
#        'geoid', 'County Name', 'tract_x', 'Less than 9th grade',
#        '9th to 12th grade, no diploma', 'High school diploma', 'Some college',
#        'Associate degree', 'Bachelor degree', 'Graduate degree',
#        'High school graduate, or higher', 'Bachelor degree, or higher',
#        'County', 'tract_y', 'GEOID'],
#       dtype='object')

# %%
gdf.columns
# Out:
# Index(['BoroCode', 'BoroName', 'CountyFIPS', 'NTA2020', 'NTAName', 'NTAAbbrev',
#        'NTAType', 'CDTA2020', 'CDTAName', 'Shape_Leng', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %%
geo.columns
# Out:
# Index(['CTLabel', 'BoroCode', 'BoroName', 'CT2020', 'BoroCT2020', 'CDEligibil',
#        'NTAName', 'NTA2020', 'CDTA2020', 'CDTANAME', 'GEOID', 'Shape_Leng',
#        'Shape_Area', 'geometry'],
#       dtype='object')

# %%
gdf.rename(columns={'BoroName': 'County Name'}, inplace=True)

# %%
ct = pd.merge(geo, df, on='GEOID')

# %%
ct
# Out:
#      CTLabel BoroCode       BoroName  CT2020 BoroCT2020 CDEligibil  \
# 0          1        1      Manhattan  000100    1000100       None
# 1       2.01        1      Manhattan  000201    1000201       None
# 2          6        1      Manhattan  000600    1000600       None
# 3      14.01        1      Manhattan  001401    1001401       None
# 4      14.02        1      Manhattan  001402    1001402       None
# ...      ...      ...            ...     ...        ...        ...
# 2029      73        2          Bronx  007300    2007300       None
# 2030      75        5  Staten Island  007500    5007500       None
# 2031      77        5  Staten Island  007700    5007700       None
# 2032     475        4         Queens  047500    4047500       None
# 2033     687        4         Queens  068700    4068700       None
#
#                                                 NTAName NTA2020 CDTA2020  \
# 0     The Battery-Governors Island-Ellis Island-Libe...  MN0191     MN01
# ...

# %%
m = gpd.sjoin(gdf, ct, how='inner')

# %%
m
# Out:
#      BoroCode_left County Name_left CountyFIPS NTA2020_left  \
# 0                3         Brooklyn        047       BK0101
# 1                3         Brooklyn        047       BK0102
# 3                3         Brooklyn        047       BK0104
# 0                3         Brooklyn        047       BK0101
# 3                3         Brooklyn        047       BK0104
# ..             ...              ...        ...          ...
# 256              5    Staten Island        085       SI0305
# 255              5    Staten Island        085       SI0304
# 256              5    Staten Island        085       SI0305
# 256              5    Staten Island        085       SI0305
# 259              5    Staten Island        085       SI9591
#
#                                NTAName_left   NTAAbbrev NTAType CDTA2020_left  \
# 0                                Greenpoint       Grnpt       0          BK01
# 1                              Williamsburg    Wllmsbrg       0          BK01
# ...

# %%
m.columns
# Out:
# Index(['BoroCode_left', 'County Name_left', 'CountyFIPS', 'NTA2020_left',
#        'NTAName_left', 'NTAAbbrev', 'NTAType', 'CDTA2020_left', 'CDTAName',
#        'Shape_Leng_left', 'Shape_Area_left', 'geometry', 'index_right',
#        'CTLabel', 'BoroCode_right', 'BoroName', 'CT2020', 'BoroCT2020',
#        'CDEligibil', 'NTAName_right', 'NTA2020_right', 'CDTA2020_right',
#        'CDTANAME', 'GEOID', 'Shape_Leng_right', 'Shape_Area_right',
#        'Total Population', 'Below Poverty Level', 'Above Poverty Level',
#        'geoid', 'County Name_right', 'tract_x', 'Less than 9th grade',
#        '9th to 12th grade, no diploma', 'High school diploma', 'Some college',
#        'Associate degree', 'Bachelor degree', 'Graduate degree',
#        'High school graduate, or higher', 'Bachelor degree, or higher',
#        'County', 'tract_y'],
#       dtype='object')

# %%
m = m.drop(['BoroCode_left', 'County Name_left', 'NTA2020_left', 'NTAAbbrev', 'NTAType', 'CDTA2020_left', 'CDTAName',
       'geometry', 'index_right',
       'CTLabel', 'BoroCode_right','CT2020', 'BoroCT2020',
       'CDEligibil', 'NTA2020_right', 'CDTA2020_right',
       'CDTANAME', 'GEOID', 'Shape_Leng_right', 'Shape_Area_right',
       'County Name_right', 'tract_x',
       'tract_y'], axis=1)

# %%
m =  m.groupby(['NTAName_left'], as_index=False).mean()

# %%
m
# Out:
#                                NTAName_left  Shape_Leng_left  Shape_Area_left  \
# 0                                  Allerton     17837.937333     1.575392e+07
# 1                           Alley Pond Park     48184.402299     2.613240e+07
# 2    Annadale-Huguenot-Prince's Bay-Woodrow     67592.595333     1.804283e+08
# 3                   Arden Heights-Rossville     38159.860824     6.777396e+07
# 4                         Astoria (Central)     21571.990905     2.108482e+07
# ..                                      ...              ...              ...
# 254             Windsor Terrace-South Slope     21234.300305     1.531205e+07
# 255                               Woodhaven     21956.420913     2.372750e+07
# 256                       Woodlawn Cemetery     18168.590667     1.788638e+07
# 257                                Woodside     31737.888428     3.294947e+07
# 258         Yankee Stadium-Macombs Dam Park      9673.853546     2.808903e+06
#
# ...

# %%
m.columns
# Out:
# Index(['NTAName_left', 'Shape_Leng_left', 'Shape_Area_left',
#        'Total Population', 'Below Poverty Level', 'Above Poverty Level',
#        'Less than 9th grade', '9th to 12th grade, no diploma',
#        'High school diploma', 'Some college', 'Associate degree',
#        'Bachelor degree', 'Graduate degree', 'High school graduate, or higher',
#        'Bachelor degree, or higher'],
#       dtype='object')

# %%
# Group the DataFrame by some column(s)
grouped = m.groupby('NTAName_left')

# Check if any group has a total population of 0 and list those groups
zero_pop_groups = []
for name, group in grouped:
    if group['Total Population'].sum() == 0:
        zero_pop_groups.append(name)
print("Groups with 0 total population:", zero_pop_groups)
# Out:
# Groups with 0 total population: ['Hoffman & Swinburne Islands', 'Jamaica Bay (West)']

# %%
# Filter out the groups with 0 total population
grouped = m[m['Total Population'] != 0].groupby('NTAName_left')

# Define the columns to average
cols_to_average = ['Below Poverty Level', 
                   'Above Poverty Level', 'Less than 9th grade', '9th to 12th grade, no diploma', 
                   'High school diploma', 'Some college', 'Associate degree', 'Bachelor degree', 
                   'Graduate degree', 'High school graduate, or higher', 'Bachelor degree, or higher']

# Define a function to calculate the weighted average for each group
def calc_weighted_avg(group):
    if group['Total Population'].sum() == 0:
        return pd.Series(index=cols_to_average)
    else:
        return pd.Series(np.average(group[cols_to_average], weights=group['Total Population'], axis=0), index=cols_to_average)

# Apply the function to each group and add the resulting weighted averages as new columns
df_weighted = grouped.apply(calc_weighted_avg).reset_index()

# %%
df_weighted
# Out:
#                                NTAName_left  Below Poverty Level  \
# 0                                  Allerton           656.533333
# 1                           Alley Pond Park           353.727273
# 2    Annadale-Huguenot-Prince's Bay-Woodrow           313.846154
# 3                   Arden Heights-Rossville           375.000000
# 4                         Astoria (Central)           347.814815
# ..                                      ...                  ...
# 252             Windsor Terrace-South Slope           276.083333
# 253                               Woodhaven           365.047619
# 254                       Woodlawn Cemetery           143.000000
# 255                                Woodside           358.961538
# 256         Yankee Stadium-Macombs Dam Park          2734.600000
#
#      Above Poverty Level  Less than 9th grade  9th to 12th grade, no diploma  \
# 0             278.266667           521.533333                     126.066667
# ...

# %%
df_weighted.rename(columns={'Below Poverty Level': 'Below Poverty Level WA', 
'Above Poverty Level': 'Above Poverty Level WA', 
'Less than 9th grade': 'Less than 9th grade WA',
'9th to 12th grade, no diploma': '9th to 12th grade, no diploma WA', 
'High school diploma': 'High school diploma WA',
'Some college' : 'Some college WA',
'Associate degree': 'Associate degree WA', 
'Bachelor degree': 'Bachelor degree WA', 
'Graduate degree': 'Graduate degree WA',
'High school graduate, or higher': 'High school graduate, or higher WA', 
'Bachelor degree, or higher': 'Bachelor degree, or higher WA'}, inplace=True)

# %%
merge = pd.merge(m, df_weighted, on='NTAName_left')

# %%
merge
# Out:
#                                NTAName_left  Shape_Leng_left  Shape_Area_left  \
# 0                                  Allerton     17837.937333     1.575392e+07
# 1                           Alley Pond Park     48184.402299     2.613240e+07
# 2    Annadale-Huguenot-Prince's Bay-Woodrow     67592.595333     1.804283e+08
# 3                   Arden Heights-Rossville     38159.860824     6.777396e+07
# 4                         Astoria (Central)     21571.990905     2.108482e+07
# ..                                      ...              ...              ...
# 252             Windsor Terrace-South Slope     21234.300305     1.531205e+07
# 253                               Woodhaven     21956.420913     2.372750e+07
# 254                       Woodlawn Cemetery     18168.590667     1.788638e+07
# 255                                Woodside     31737.888428     3.294947e+07
# 256         Yankee Stadium-Macombs Dam Park      9673.853546     2.808903e+06
#
# ...

# %%
merge= merge.rename(columns={'NTAName_left': 'NTAName', 'Shape_Leng_left_x':'Shape_Leng', 'Shape_Area_left_x':'Shape_Area', 'Total Population_x':'Total Population'})

# %%
merge
# Out:
#                                     NTAName  Shape_Leng_left  Shape_Area_left  \
# 0                                  Allerton     17837.937333     1.575392e+07
# 1                           Alley Pond Park     48184.402299     2.613240e+07
# 2    Annadale-Huguenot-Prince's Bay-Woodrow     67592.595333     1.804283e+08
# 3                   Arden Heights-Rossville     38159.860824     6.777396e+07
# 4                         Astoria (Central)     21571.990905     2.108482e+07
# ..                                      ...              ...              ...
# 252             Windsor Terrace-South Slope     21234.300305     1.531205e+07
# 253                               Woodhaven     21956.420913     2.372750e+07
# 254                       Woodlawn Cemetery     18168.590667     1.788638e+07
# 255                                Woodside     31737.888428     3.294947e+07
# 256         Yankee Stadium-Macombs Dam Park      9673.853546     2.808903e+06
#
# ...

# %%
#merge.to_csv('Pov&EA.csv', index=False)
