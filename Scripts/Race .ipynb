# %%
import pandas as pd 
import numpy as np 
import geopandas as gpd 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
# %matplotlib inline

# %%
gdf = gpd.read_file('/Users/ananyarajesh/Downloads/nynta2020_23a/nynta2020.shp')

# %%
gdf.rename(columns={'BoroName': 'Borough'}, inplace=True)

# %%
gdf
# Out:
#      BoroCode        Borough CountyFIPS NTA2020                      NTAName  \
# 0           3       Brooklyn        047  BK0101                   Greenpoint
# 1           3       Brooklyn        047  BK0102                 Williamsburg
# 2           3       Brooklyn        047  BK0103           South Williamsburg
# 3           3       Brooklyn        047  BK0104            East Williamsburg
# 4           3       Brooklyn        047  BK0201             Brooklyn Heights
# ..        ...            ...        ...     ...                          ...
# 257         5  Staten Island        085  SI0391      Freshkills Park (South)
# 258         5  Staten Island        085  SI9561               Fort Wadsworth
# 259         5  Staten Island        085  SI9591  Hoffman & Swinburne Islands
# 260         5  Staten Island        085  SI9592                 Miller Field
# 261         5  Staten Island        085  SI9593             Great Kills Park
#
#       NTAAbbrev NTAType CDTA2020  \
# ...

# %%
df = pd.read_excel("/Users/ananyarajesh/Downloads/acs_demo_06to10_ntas.xlsx")

# %%
df
# Out:
#      GeoType                                           GeogName GeoID  \
# 0    NTA2010                            Allerton-Pelham Gardens  BX31
# 1    NTA2010                         Bedford Park-Fordham North  BX05
# 2    NTA2010                                            Belmont  BX06
# 3    NTA2010                                          Bronxdale  BX07
# 4    NTA2010                                 Claremont-Bathgate  BX01
# ..       ...                                                ...   ...
# 190  NTA2010                                  Rossville-Woodrow  SI32
# 191  NTA2010                                 Stapleton-Rosebank  SI37
# 192  NTA2010  Todt Hill-Emerson Hill-Heartland Village-Light...  SI24
# 193  NTA2010          West New Brighton-New Brighton-St. George  SI22
# 194  NTA2010                                        Westerleigh  SI07
#
#            Borough  Pop1E   Pop1M  Pop1C  Pop1P  Pop1Z  MaleE  ...  AsnOAsnE  \
# ...

# %%
df.columns
# Out:
# Index(['GeoType', 'GeogName', 'GeoID', 'Borough', 'Pop1E', 'Pop1M', 'Pop1C',
#        'Pop1P', 'Pop1Z', 'MaleE',
#        ...
#        'AsnOAsnE', 'AsnOAsnM', 'AsnOAsnC', 'AsnOAsnP', 'AsnOAsnZ', 'Asn2plE',
#        'Asn2plM', 'Asn2plC', 'Asn2plP', 'Asn2plZ'],
#       dtype='object', length=484)

# %%
df10 = df[['GeogName', 'GeoID', 'Borough', 'Pop1E', 'MaleE', 'FemE', 'Hsp1E', 'NHspE', 'WtNHE', 'BlNHE', 'AIANNHE', 'AsnNHE', 'NHPINHE', 'OthNHE', 'Rc2plNHE']]

# %%
df10
# Out:
#                                               GeogName GeoID        Borough  \
# 0                              Allerton-Pelham Gardens  BX31          Bronx
# 1                           Bedford Park-Fordham North  BX05          Bronx
# 2                                              Belmont  BX06          Bronx
# 3                                            Bronxdale  BX07          Bronx
# 4                                   Claremont-Bathgate  BX01          Bronx
# ..                                                 ...   ...            ...
# 190                                  Rossville-Woodrow  SI32  Staten Island
# 191                                 Stapleton-Rosebank  SI37  Staten Island
# 192  Todt Hill-Emerson Hill-Heartland Village-Light...  SI24  Staten Island
# 193          West New Brighton-New Brighton-St. George  SI22  Staten Island
# 194                                        Westerleigh  SI07  Staten Island
#
# ...

# %%
df21 = pd.read_excel("/Users/ananyarajesh/Downloads/demo_2021acs5yr_nta.xlsx")

# %%
df21
# Out:
#      GeoType  NTAType                     GeogName   GeoID        Borough  \
# 0    NTA2020        0                   Greenpoint  BK0101       Brooklyn
# 1    NTA2020        0                 Williamsburg  BK0102       Brooklyn
# 2    NTA2020        0           South Williamsburg  BK0103       Brooklyn
# 3    NTA2020        0            East Williamsburg  BK0104       Brooklyn
# 4    NTA2020        0             Brooklyn Heights  BK0201       Brooklyn
# ..       ...      ...                          ...     ...            ...
# 257  NTA2020        9      Freshkills Park (North)  SI0291  Staten Island
# 258  NTA2020        9      Freshkills Park (South)  SI0391  Staten Island
# 259  NTA2020        9  Hoffman & Swinburne Islands  SI9591  Staten Island
# 260  NTA2020        9                 Miller Field  SI9592  Staten Island
# 261  NTA2020        9             Great Kills Park  SI9593  Staten Island
#
#      Pop_1E  Pop_1M  Pop_1C  Pop_1P  Pop_1Z  ...  AsnOAsnE  AsnOAsnM  \
# ...

# %%
df21 = df21[['GeogName', 'GeoID', 'Borough', 'Pop_1E', 'MaleE', 'FemE', 'Hsp1E', 'NHspE', 'WtNHE', 'BlNHE', 'AIANNHE', 'AsnNHE', 'NHPINHE', 'OthNHE', 'Rc2plNHE']]

# %%
df21
# Out:
#                         GeogName   GeoID        Borough  Pop_1E  MaleE   FemE  \
# 0                     Greenpoint  BK0101       Brooklyn   37518  18545  18973
# 1                   Williamsburg  BK0102       Brooklyn   63316  31861  31455
# 2             South Williamsburg  BK0103       Brooklyn   47065  23651  23414
# 3              East Williamsburg  BK0104       Brooklyn   53478  25752  27726
# 4               Brooklyn Heights  BK0201       Brooklyn   24775  11517  13258
# ..                           ...     ...            ...     ...    ...    ...
# 257      Freshkills Park (North)  SI0291  Staten Island       0      0      0
# 258      Freshkills Park (South)  SI0391  Staten Island      23     23      0
# 259  Hoffman & Swinburne Islands  SI9591  Staten Island       0      0      0
# 260                 Miller Field  SI9592  Staten Island     260     59    201
# 261             Great Kills Park  SI9593  Staten Island       0      0      0
#
# ...

# %%
merged_df10 = df10.merge(gdf, on='Borough')

# %%
merged_df10
# Out:
#                       GeogName GeoID        Borough  Pop1E  MaleE   FemE  \
# 0      Allerton-Pelham Gardens  BX31          Bronx  31376  15142  16234
# 1      Allerton-Pelham Gardens  BX31          Bronx  31376  15142  16234
# 2      Allerton-Pelham Gardens  BX31          Bronx  31376  15142  16234
# 3      Allerton-Pelham Gardens  BX31          Bronx  31376  15142  16234
# 4      Allerton-Pelham Gardens  BX31          Bronx  31376  15142  16234
# ...                        ...   ...            ...    ...    ...    ...
# 11709              Westerleigh  SI07  Staten Island  23966  11758  12208
# 11710              Westerleigh  SI07  Staten Island  23966  11758  12208
# 11711              Westerleigh  SI07  Staten Island  23966  11758  12208
# 11712              Westerleigh  SI07  Staten Island  23966  11758  12208
# 11713              Westerleigh  SI07  Staten Island  23966  11758  12208
#
#        Hsp1E  NHspE  WtNHE  BlNHE  ...  CountyFIPS  NTA2020  \
# ...

# %%
merged_df21 = df21.merge(gdf, on='Borough')

# %%
merged_df21
# Out:
#                GeogName   GeoID        Borough  Pop_1E  MaleE   FemE  Hsp1E  \
# 0            Greenpoint  BK0101       Brooklyn   37518  18545  18973   5498
# 1            Greenpoint  BK0101       Brooklyn   37518  18545  18973   5498
# 2            Greenpoint  BK0101       Brooklyn   37518  18545  18973   5498
# 3            Greenpoint  BK0101       Brooklyn   37518  18545  18973   5498
# 4            Greenpoint  BK0101       Brooklyn   37518  18545  18973   5498
# ...                 ...     ...            ...     ...    ...    ...    ...
# 15985  Great Kills Park  SI9593  Staten Island       0      0      0      0
# 15986  Great Kills Park  SI9593  Staten Island       0      0      0      0
# 15987  Great Kills Park  SI9593  Staten Island       0      0      0      0
# 15988  Great Kills Park  SI9593  Staten Island       0      0      0      0
# 15989  Great Kills Park  SI9593  Staten Island       0      0      0      0
#
#        NHspE  WtNHE  BlNHE  ...  CountyFIPS  NTA2020  \
# ...

# %%
grouped10 = merged_df10.groupby(['NTAName', 'Borough'], as_index=False).mean()
grouped10
# Out:
#                                     NTAName        Borough         Pop1E  \
# 0                                  Allerton          Bronx  35940.131579
# 1                           Alley Pond Park         Queens  37916.706897
# 2    Annadale-Huguenot-Prince's Bay-Woodrow  Staten Island  24392.105263
# 3                   Arden Heights-Rossville  Staten Island  24392.105263
# 4                         Astoria (Central)         Queens  37916.706897
# ..                                      ...            ...           ...
# 257             Windsor Terrace-South Slope       Brooklyn  48368.274510
# 258                               Woodhaven         Queens  37916.706897
# 259                       Woodlawn Cemetery          Bronx  35940.131579
# 260                                Woodside         Queens  37916.706897
# 261         Yankee Stadium-Macombs Dam Park          Bronx  35940.131579
#
#             MaleE          FemE         Hsp1E         NHspE         WtNHE  \
# ...

# %%
grouped21 = merged_df21.groupby(['NTAName', 'Borough'], as_index=False).mean()
grouped21
# Out:
#                                     NTAName        Borough        Pop_1E  \
# 0                                  Allerton          Bronx  30068.448980
# 1                           Alley Pond Park         Queens  28912.831325
# 2    Annadale-Huguenot-Prince's Bay-Woodrow  Staten Island  21443.217391
# 3                   Arden Heights-Rossville  Staten Island  21443.217391
# 4                         Astoria (Central)         Queens  28912.831325
# ..                                      ...            ...           ...
# 257             Windsor Terrace-South Slope       Brooklyn  39309.565217
# 258                               Woodhaven         Queens  28912.831325
# 259                       Woodlawn Cemetery          Bronx  30068.448980
# 260                                Woodside         Queens  28912.831325
# 261         Yankee Stadium-Macombs Dam Park          Bronx  30068.448980
#
#             MaleE          FemE         Hsp1E         NHspE         WtNHE  \
# ...

# %%
grouped21.columns
# Out:
# Index(['NTAName', 'Borough', 'Pop_1E', 'MaleE', 'FemE', 'Hsp1E', 'NHspE',
#        'WtNHE', 'BlNHE', 'AIANNHE', 'AsnNHE', 'NHPINHE', 'OthNHE', 'Rc2plNHE',
#        'BoroCode', 'Shape_Leng', 'Shape_Area'],
#       dtype='object')

# %% [markdown]
# grouped10.to_csv('2010-NTA-demographics.csv', index=False)

# %% [markdown]
# grouped21.to_csv('2021-NTA-demographics.csv', index=False)

# %%
merged_df21.columns
# Out:
# Index(['GeogName', 'GeoID', 'Borough', 'Pop_1E', 'MaleE', 'FemE', 'Hsp1E',
#        'NHspE', 'WtNHE', 'BlNHE', 'AIANNHE', 'AsnNHE', 'NHPINHE', 'OthNHE',
#        'Rc2plNHE', 'BoroCode', 'CountyFIPS', 'NTA2020', 'NTAName', 'NTAAbbrev',
#        'NTAType', 'CDTA2020', 'CDTAName', 'Shape_Leng', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %%
grouped21
# Out:
#                                     NTAName        Borough        Pop_1E  \
# 0                                  Allerton          Bronx  30068.448980
# 1                           Alley Pond Park         Queens  28912.831325
# 2    Annadale-Huguenot-Prince's Bay-Woodrow  Staten Island  21443.217391
# 3                   Arden Heights-Rossville  Staten Island  21443.217391
# 4                         Astoria (Central)         Queens  28912.831325
# ..                                      ...            ...           ...
# 257             Windsor Terrace-South Slope       Brooklyn  39309.565217
# 258                               Woodhaven         Queens  28912.831325
# 259                       Woodlawn Cemetery          Bronx  30068.448980
# 260                                Woodside         Queens  28912.831325
# 261         Yankee Stadium-Macombs Dam Park          Bronx  30068.448980
#
#             MaleE          FemE         Hsp1E         NHspE         WtNHE  \
# ...

# %%
inc = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/income-censustracts.csv')

# %%
inc
# Out:
#             geoid    Tract County Name State  Median Income  Population
# 0     36005000100     1.00       Bronx    NY            NaN        6661
# 1     36005000200     2.00       Bronx    NY        72194.0        4453
# 2     36005000400     4.00       Bronx    NY       111250.0        6000
# 3     36005001600    16.00       Bronx    NY        49866.0        6038
# 4     36005001901    19.01       Bronx    NY        53065.0        2168
# ...           ...      ...         ...   ...            ...         ...
# 2322  36085030302   303.02    Richmond    NY        96163.0        6663
# 2323  36085031901   319.01    Richmond    NY        43569.0        3422
# 2324  36085031902   319.02    Richmond    NY       107009.0        5298
# 2325  36085032300   323.00    Richmond    NY       116875.0        1105
# 2326  36085990100  9901.00    Richmond    NY            NaN           0
#
# [2327 rows x 6 columns]

# %%
incg =  inc.groupby(['County Name'], as_index=False).mean()

# %%
incg
# Out:
#   County Name         geoid       Tract  Median Income   Population
# 0       Bronx  3.600502e+10  247.674155   60246.678466  4067.207756
# 1       Kings  3.604705e+10  508.442770   89900.035480  3369.391304
# 2    New York  3.606101e+10  141.589484  151712.302491  5384.280645
# 3      Queens  3.608106e+10  568.046317   90949.882789  3300.833103
# 4    Richmond  3.608502e+10  228.324444  108563.863248  3914.238095

# %%
grouped21 = grouped21.rename(columns={'Borough': 'County Name'})

# %%
grouped21['County Name'] = grouped21['County Name'].replace({'Staten Island': ' Richmond', 'Manhattan': ' New York', 'Brooklyn': ' Kings',  'Queens': ' Queens',  'Bronx': ' Bronx'})

# %%
grouped21
# Out:
#                                     NTAName County Name        Pop_1E  \
# 0                                  Allerton       Bronx  30068.448980
# 1                           Alley Pond Park      Queens  28912.831325
# 2    Annadale-Huguenot-Prince's Bay-Woodrow    Richmond  21443.217391
# 3                   Arden Heights-Rossville    Richmond  21443.217391
# 4                         Astoria (Central)      Queens  28912.831325
# ..                                      ...         ...           ...
# 257             Windsor Terrace-South Slope       Kings  39309.565217
# 258                               Woodhaven      Queens  28912.831325
# 259                       Woodlawn Cemetery       Bronx  30068.448980
# 260                                Woodside      Queens  28912.831325
# 261         Yankee Stadium-Macombs Dam Park       Bronx  30068.448980
#
#             MaleE          FemE         Hsp1E         NHspE         WtNHE  \
# ...

# %%
grouped21.columns
# Out:
# Index(['NTAName', 'County Name', 'Pop_1E', 'MaleE', 'FemE', 'Hsp1E', 'NHspE',
#        'WtNHE', 'BlNHE', 'AIANNHE', 'AsnNHE', 'NHPINHE', 'OthNHE', 'Rc2plNHE',
#        'BoroCode', 'Shape_Leng', 'Shape_Area'],
#       dtype='object')

# %%
grouped21 = grouped21.rename(columns={'Pop_1E': 'Population',
                                      'MaleE': 'Male_Pop',
                                     'FemE': 'Female_Pop',
                                     'Hsp1E': 'Hsp_Pop',
                                     'NHspE': 'Not_Hsp_Pop',
                                     'WtNHE': 'White_Pop', 
                                     'BlNHE': 'Black_Pop', 
                                     'AIANNHE': 'AmericanIndian_AlaskaNative_Pop', 
                                     'AsnNHE': 'Asian_Pop', 
                                     'NHPINHE': 'NativeHawaiian_Pop', 
                                     'OthNHE': 'Other_Pop',
                                     'Rc2plNHE': 'Two+_Pop'})

# %%
grouped21
# Out:
#                                     NTAName County Name  Total Population  \
# 0                                  Allerton       Bronx      30068.448980
# 1                           Alley Pond Park      Queens      28912.831325
# 2    Annadale-Huguenot-Prince's Bay-Woodrow    Richmond      21443.217391
# 3                   Arden Heights-Rossville    Richmond      21443.217391
# 4                         Astoria (Central)      Queens      28912.831325
# ..                                      ...         ...               ...
# 257             Windsor Terrace-South Slope       Kings      39309.565217
# 258                               Woodhaven      Queens      28912.831325
# 259                       Woodlawn Cemetery       Bronx      30068.448980
# 260                                Woodside      Queens      28912.831325
# 261         Yankee Stadium-Macombs Dam Park       Bronx      30068.448980
#
#          Male_Pop    Female_Pop       Hsp_Pop   Not_Hsp_Pop     White_Pop  \
# ...

# %%
#grouped21.to_csv('Race.csv', index=False)
