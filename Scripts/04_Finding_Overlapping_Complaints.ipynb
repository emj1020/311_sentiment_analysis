# %%
#import packages
import pandas as pd
import requests
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import urllib.request, json
import requests
import urllib.parse
import datetime
import nltk
nltk.download([
        "names",
        "stopwords",
        "averaged_perceptron_tagger",
        "vader_lexicon",
        "punkt",
        'wordnet'])
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re, string

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     /Users/lizjohnson/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/lizjohnson/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/lizjohnson/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/lizjohnson/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/lizjohnson/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/lizjohnson/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def get_data(url, uniqueid, startdatetime, enddatetime, cat_clnm, subcat_clnm, subsubcat_clnm, datetime_clnm):
    '''
    Inputs: 
    url - string value of SODA API url
    startdatetime & enddatetime - string values of the format 'YYYY-MM-DDTHH:MM:SS', i.e. '2019-12-31T23:59:59.000' 
                                for the beginning and end of timeframe of interest
    datetime_clnm - string value of the column name in the data for the datetime of complaint inquiry
    
    Output:
    gdf - GeoDataFrame of 311 inquiries. Geometry is point location of 311 inquiry.
    '''
    query = (url +'?'
            "$select= count(*) as count,%s as cat, %s as subcat, %s as subsubcat"
            "&$where=%s between '"+startdatetime+"' and '"+enddatetime+"'"
            "&$group=cat,subcat,subsubcat"
            "&$order=count DESC"
            "&$limit=500000"
            )%(cat_clnm,subcat_clnm,subsubcat_clnm,datetime_clnm)
    query = query.replace(" ", "%20")
    print(query)
    response = urllib.request.urlopen(query)
    data = json.loads(response.read())
    
    return data

# %%
all311 = 'https://data.cityofnewyork.us/resource/erm2-nwe9.json'
uniqueid = 'unique_key'
cat_clnm = 'agency_name'
subcat_clnm = 'complaint_type'
subsubcat_clnm = 'descriptor'
datetime_clnm = 'created_date'

data = get_data(all311, uniqueid, '2019-01-01T00:00:00.000', '2020-01-01T00:00:00.000', cat_clnm, subcat_clnm, subsubcat_clnm, datetime_clnm)
# Out:
# https://data.cityofnewyork.us/resource/erm2-nwe9.json?$select=%20count(*)%20as%20count,agency_name%20as%20cat,%20complaint_type%20as%20subcat,%20descriptor%20as%20subsubcat&$where=created_date%20between%20'2019-01-01T00:00:00.000'%20and%20'2020-01-01T00:00:00.000'&$group=cat,subcat,subsubcat&$order=count%20DESC&$limit=500000

# %%
agg_311_cats = pd.DataFrame(data, columns = data[0].keys())
agg_311_cats.head()
# Out:
#     count                                                cat
# 0  214808                           Department of Sanitation  \
# 1  147964                    New York City Police Department
# 2  137887  Department of Housing Preservation and Develop...
# 3   98815                    New York City Police Department
# 4   77815                    New York City Police Department
#
#                                 subcat                            subsubcat
# 0  Request Large Bulky Item Collection  Request Large Bulky Item Collection
# 1                  Noise - Residential                     Loud Music/Party
# 2                       HEAT/HOT WATER                      ENTIRE BUILDING
# 3                     Blocked Driveway                            No Access
# 4              Noise - Street/Sidewalk                     Loud Music/Party

# %%
len(agg_311_cats)
# Out:
# 1977

# %%
agg_311_cats.dtypes
# Out:
# count        object
# cat          object
# subcat       object
# subsubcat    object
# dtype: object

# %%
agg_311_cats['count'] = agg_311_cats['count'].astype(int)

# %%
complaint_type_agg = agg_311_cats[['subcat','count']].groupby(by = 'subcat').sum().reset_index()
complaint_type_agg.sort_values(by = 'count',ascending = False).head(10)
# Out:
#                                   subcat   count
# 258                  Noise - Residential  232850
# 286  Request Large Bulky Item Collection  214808
# 163                       HEAT/HOT WATER  212565
# 181                      Illegal Parking  198346
# 73                      Blocked Driveway  137736
# 259              Noise - Street/Sidewalk   97914
# 313                     Street Condition   88460
# 314               Street Light Condition   68211
# 349                         Water System   63703
# 334                 UNSANITARY CONDITION   57867

# %%
complaint_type_agg.sort_values(by = 'count',ascending = False).tail(10)
# Out:
#                              subcat  count
# 208  Misc. Comments' and (select...      1
# 209  Misc. Comments' and 6049=60...      1
# 210  Misc. Comments' and 7702=77...      1
# 211  Misc. Comments' waitfor del...      1
# 212  Misc. Comments'&quot;`0&amp...      1
# 213  Misc. Comments'(select*from...      1
# 214  Misc. Comments');declare @q...      1
# 215  Misc. Comments')waitfor del...      1
# 216  Misc. Comments'+(function()...      1
# 369  {!xmlparser v='&lt;!DOCTYPE...      1

# %%
len(complaint_type_agg[complaint_type_agg['count']<100])
# Out:
# 192

# %%
len(complaint_type_agg)
# Out:
# 370

# %%
complaint_type_filtered = complaint_type_agg[complaint_type_agg['count']>100]
complaint_type_filtered.sort_values(by = 'count',ascending = False).tail(10)
# Out:
#                                     subcat  count
# 71                     Bike Rack Condition    151
# 274                               Pet Shop    150
# 132                            Elder Abuse    144
# 190                                LinkNYC    136
# 165                   Harboring Bees/Wasps    134
# 172  Home Delivered Meal - Missed Delivery    112
# 307   Special Natural Area District (SNAD)    111
# 278                  Posting Advertisement    110
# 300                Senior Center Complaint    108
# 323                              Tattooing    104

# %%
complaint_type_filtered[complaint_type_filtered['subcat'].str.contains('SCRIE')]
# Out:
#     subcat  count
# 292  SCRIE   2516

# %%
complaint_type_filtered[complaint_type_filtered['subcat'].str.contains('DRIE')]
# Out:
#     subcat  count
# 113   DRIE    657

# %%
complaint_type_filtered[complaint_type_filtered['subcat'].str.contains('DOF')]
# Out:
#                              subcat  count
# 100     DOF Parking - Payment Issue   1704
# 101      DOF Parking - Request Copy    291
# 102    DOF Parking - Request Status    229
# 103     DOF Parking - Tax Exemption    217
# 104      DOF Property - Owner Issue    901
# 105    DOF Property - Payment Issue   2609
# 106   DOF Property - Property Value    390
# 107       DOF Property - RPIE Issue    273
# 108  DOF Property - Reduction Issue   5737
# 109     DOF Property - Request Copy   3471
# 110   DOF Property - Update Account   2490

# %%
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('SCRIE','Senior Citizen Rent Increase') 
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('DRIE','Disability Rent Increase') 
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('RPIE','Real Property Income and Expense') 
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('DOF','Department of Finance')
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('DCA','Department of Consumer Affairs')
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('DOH','Department of Finance')
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('DEP','Department of Environmental Protection')
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('DPR','Department of Parks and Recreation')
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('DPR','Department of Parks and Recreation')
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('DPR','Department of Parks and Recreation')
complaint_type_filtered['subcat'] = complaint_type_filtered['subcat'].str.replace('HPD','Department of Housing Preservation and Development')

# %%
complaint_type_filtered[complaint_type_filtered['subcat'].str.contains('DOF')]
# Out:
# Empty DataFrame
# Columns: [subcat, count]
# Index: []

# %%
complaints = complaint_type_filtered['subcat'].to_list()
print(len(complaints))
# Out:
# 176

# %% [markdown]
# ## Text pre-processing
#
# Steps include (1) removing punctuation, (2) lowercasing, and (3) removing stop words.

# %%
# # Initialize the Porter stemmer
porter=PorterStemmer()
stop_words = set(stopwords.words('english'))
processed_comps = {}

# Preprocess the complaint types
for item in complaints:
    og_complaint = item
    # Convert the key to lowercase and remove punctuation
    item = re.sub('/', ' ', item)
    item = re.sub('-', ' ', item)
    item = item.lower().translate(str.maketrans('', '', string.punctuation))
    # Create an empty list to store the processed values
    words = item.split()
    words_no_stopwords = [word for word in words if word not in stop_words]
    item_no_stopwords = ' '.join(words_no_stopwords)
#     processed_item = porter.stem(item_no_stopwords)
    
    processed_comps[og_complaint] = item_no_stopwords

# %%
processed_comps
# Out:
# {'APPLIANCE': 'appliance',
#  'Abandoned Vehicle': 'abandoned vehicle',
#  'Adopt-A-Basket': 'adopt basket',
#  'Advocate-Prop Refunds/Credits': 'advocate prop refunds credits',
#  'Air Quality': 'air quality',
#  'Animal Abuse': 'animal abuse',
#  'Animal in a Park': 'animal park',
#  'Animal-Abuse': 'animal abuse',
#  'Asbestos': 'asbestos',
#  'BEST/Site Safety': 'best site safety',
#  'Beach/Pool/Sauna Complaint': 'beach pool sauna complaint',
#  'Benefit Card Replacement': 'benefit card replacement',
#  'Bike Rack Condition': 'bike rack condition',
#  'Bike/Roller/Skate Chronic': 'bike roller skate chronic',
#  'Blocked Driveway': 'blocked driveway',
#  'Boilers': 'boilers',
#  'Borough Office': 'borough office',
#  'Bridge Condition': 'bridge condition',
#  'Broken Parking Meter': 'broken parking meter',
#  'Building Marshals office': 'building marshals office',
#  'Building/Use': 'building use',
#  'Bus Stop Shelter Complaint': 'bus stop shelter complaint',
#  'Bus Stop Shelter Placement': 'bus stop shelter placement',
#  'Collection Truck Noise': 'collection truck noise',
#  'Construction Safety Enforcement': 'construction safety enforcement',
#  'Consumer Complaint': 'consumer complaint',
#  'Cranes and Derricks': 'cranes derricks',
#  'Curb Condition': 'curb condition',
#  'Department of Consumer Affairs / Department of Finance New License Application Request': 'department consumer affairs department finance new license application request',
#  'Department of Environmental Protection Street Condition': 'department environmental protection street condition',
#  'Department of Finance Parking - Payment Issue': 'department finance parking payment issue',
#  'Department of Finance Parking - Request Copy': 'department finance parking request copy',
#  'Department of Finance Parking - Request Status': 'department finance parking request status',
#  'Department of Finance Parking - Tax Exemption': 'department finance parking tax exemption',
#  'Department of Finance Property - Owner Issue': 'department finance property owner issue',
#  'Department of Finance Property - Payment Issue': 'department finance property payment issue',
#  'Department of Finance Property - Property Value': 'department finance property property value',
#  'Department of Finance Property - Real Property Income and Expense Issue': 'department finance property real property income expense issue',
#  'Department of Finance Property - Reduction Issue': 'department finance property reduction issue',
#  'Department of Finance Property - Request Copy': 'department finance property request copy',
#  'Department of Finance Property - Update Account': 'department finance property update account',
#  'DOOR/WINDOW': 'door window',
#  'Department of Parks and Recreation Internal': 'department parks recreation internal',
#  'Disability Rent Increase': 'disability rent increase',
#  'Damaged Tree': 'damaged tree',
#  'Day Care': 'day care',
#  'Dead/Dying Tree': 'dead dying tree',
#  'Derelict Bicycle': 'derelict bicycle',
#  'Derelict Vehicle': 'derelict vehicle',
#  'Derelict Vehicles': 'derelict vehicles',
#  'Dirty Conditions': 'dirty conditions',
#  'Drinking': 'drinking',
#  'Drinking Water': 'drinking water',
#  'Drug Activity': 'drug activity',
#  'ELECTRIC': 'electric',
#  'ELEVATOR': 'elevator',
#  'Elder Abuse': 'elder abuse',
#  'Electrical': 'electrical',
#  'Electronics Waste Appointment': 'electronics waste appointment',
#  'Elevator': 'elevator',
#  'Emergency Response Team (ERT)': 'emergency response team ert',
#  'Executive Inspections': 'executive inspections',
#  'FLOORING/STAIRS': 'flooring stairs',
#  'Facades': 'facades',
#  'Ferry Complaint': 'ferry complaint',
#  'Ferry Inquiry': 'ferry inquiry',
#  'Food Establishment': 'food establishment',
#  'Food Poisoning': 'food poisoning',
#  'For Hire Vehicle Complaint': 'hire vehicle complaint',
#  'For Hire Vehicle Report': 'hire vehicle report',
#  'Forms': 'forms',
#  'Found Property': 'found property',
#  'GENERAL': 'general',
#  'General': 'general',
#  'General Construction/Plumbing': 'general construction plumbing',
#  'Graffiti': 'graffiti',
#  'Green Taxi Complaint': 'green taxi complaint',
#  'HEAT/HOT WATER': 'heat hot water',
#  'Department of Housing Preservation and Development Literature Request': 'department housing preservation development literature request',
#  'Harboring Bees/Wasps': 'harboring bees wasps',
#  'Hazardous Materials': 'hazardous materials',
#  'Highway Condition': 'highway condition',
#  'Home Delivered Meal - Missed Delivery': 'home delivered meal missed delivery',
#  'Homeless Encampment': 'homeless encampment',
#  'Homeless Person Assistance': 'homeless person assistance',
#  'Housing - Low Income Senior': 'housing low income senior',
#  'Housing Options': 'housing options',
#  'Illegal Animal Kept as Pet': 'illegal animal kept pet',
#  'Illegal Fireworks': 'illegal fireworks',
#  'Illegal Parking': 'illegal parking',
#  'Illegal Tree Damage': 'illegal tree damage',
#  'Indoor Air Quality': 'indoor air quality',
#  'Indoor Sewage': 'indoor sewage',
#  'Industrial Waste': 'industrial waste',
#  'Investigations and Discipline (IAD)': 'investigations discipline iad',
#  'Lead': 'lead',
#  'LinkNYC': 'linknyc',
#  'Literature Request': 'literature request',
#  'Litter Basket / Request': 'litter basket request',
#  'Lost Property': 'lost property',
#  'Maintenance or Facility': 'maintenance facility',
#  'Missed Collection (All Materials)': 'missed collection materials',
#  'Mobile Food Vendor': 'mobile food vendor',
#  'Mold': 'mold',
#  'Mosquitoes': 'mosquitoes',
#  'New Tree Request': 'new tree request',
#  'Noise': 'noise',
#  'Noise - Commercial': 'noise commercial',
#  'Noise - Helicopter': 'noise helicopter',
#  'Noise - House of Worship': 'noise house worship',
#  'Noise - Park': 'noise park',
#  'Noise - Residential': 'noise residential',
#  'Noise - Street/Sidewalk': 'noise street sidewalk',
#  'Noise - Vehicle': 'noise vehicle',
#  'Non-Emergency Police Matter': 'non emergency police matter',
#  'Non-Residential Heat': 'non residential heat',
#  'OUTSIDE BUILDING': 'outside building',
#  'Other Enforcement': 'enforcement',
#  'Overflowing Litter Baskets': 'overflowing litter baskets',
#  'Overgrown Tree/Branches': 'overgrown tree branches',
#  'PAINT/PLASTER': 'paint plaster',
#  'PLUMBING': 'plumbing',
#  'Panhandling': 'panhandling',
#  'Pet Shop': 'pet shop',
#  'Plumbing': 'plumbing',
#  'Poison Ivy': 'poison ivy',
#  'Posting Advertisement': 'posting advertisement',
#  'Public Payphone Complaint': 'public payphone complaint',
#  'Quality of Life': 'quality life',
#  'Question': 'question',
#  'Recycling Enforcement': 'recycling enforcement',
#  'Request Large Bulky Item Collection': 'request large bulky item collection',
#  'Rodent': 'rodent',
#  'Root/Sewer/Sidewalk Condition': 'root sewer sidewalk condition',
#  'SAFETY': 'safety',
#  'Senior Citizen Rent Increase': 'senior citizen rent increase',
#  'Safety': 'safety',
#  'Sanitation Condition': 'sanitation condition',
#  'Scaffold Safety': 'scaffold safety',
#  'School Maintenance': 'school maintenance',
#  'Senior Center Complaint': 'senior center complaint',
#  'Sewer': 'sewer',
#  'Sidewalk Condition': 'sidewalk condition',
#  'Smoking': 'smoking',
#  'Snow': 'snow',
#  'Special Natural Area District (SNAD)': 'special natural area district snad',
#  'Special Operations': 'special operations',
#  'Special Projects Inspection Team (SPIT)': 'special projects inspection team spit',
#  'Standing Water': 'standing water',
#  'Street Condition': 'street condition',
#  'Street Light Condition': 'street light condition',
#  'Street Sign - Damaged': 'street sign damaged',
#  'Street Sign - Dangling': 'street sign dangling',
#  'Street Sign - Missing': 'street sign missing',
#  'Sustainability Enforcement': 'sustainability enforcement',
#  'Sweeping/Inadequate': 'sweeping inadequate',
#  'Sweeping/Missed': 'sweeping missed',
#  'Tattooing': 'tattooing',
#  'Taxi Complaint': 'taxi complaint',
#  'Taxi Compliment': 'taxi compliment',
#  'Taxi Report': 'taxi report',
#  'Traffic': 'traffic',
#  'Traffic Signal Condition': 'traffic signal condition',
#  'UNSANITARY CONDITION': 'unsanitary condition',
#  'Unleashed Dog': 'unleashed dog',
#  'Unsanitary Animal Pvt Property': 'unsanitary animal pvt property',
#  'Unsanitary Condition': 'unsanitary condition',
#  'Unsanitary Pigeon Condition': 'unsanitary pigeon condition',
#  'Urinating in Public': 'urinating public',
#  'Vacant Lot': 'vacant lot',
#  'Vending': 'vending',
#  'Violation of Park Rules': 'violation park rules',
#  'WATER LEAK': 'water leak',
#  'Water Conservation': 'water conservation',
#  'Water Quality': 'water quality',
#  'Water System': 'water system'}

# %%
#manually update a few
processed_comps.update({'Green Taxi Complaint':'taxi'})
processed_comps.update({'Taxi Complaint':'taxi'})
processed_comps.update({'Taxi Compliment':'taxi'})
processed_comps.update({'Taxi Report':'taxi'})
processed_comps.update({'Bus Stop Shelter Placement':'bus stop shelter'})
processed_comps.update({'Bus Stop Shelter Complaint':'bus stop shelter'})
processed_comps.update({'Collection Truck Noise':'noise'})
processed_comps.update({'Noise - Commercial':'noise'})
processed_comps.update({'Noise - Helicopter':'noise'})
processed_comps.update({'Noise - House of Worship':'noise'})
processed_comps.update({'Noise - Park':'noise'})
processed_comps.update({'Noise - Residential':'noise'})
processed_comps.update({'Noise - Street/Sidewalk':'noise'})
processed_comps.update({'Noise - Vehicle':'noise'})
processed_comps.update({'Noise':'noise'})
processed_comps.update({'Root/Sewer/Sidewalk Condition':'sewer'})
processed_comps.update({'Damaged Tree':'tree'})
processed_comps.update({'Dead/Dying Tree':'tree'})
processed_comps.update({'Illegal Tree Damage':'tree'})
processed_comps.update({'New Tree Request':'tree'})
processed_comps.update({'Scaffold Safety':'scaffold'})
processed_comps.update({'Water Quality':'water quality'})
processed_comps.update({'Drinking Water':'water quality'})
processed_comps.update({'Air Quality':'air quality'})
processed_comps.update({'Derelict Vehicle':'abandoned vehicle'})
processed_comps.update({'Derelict Vehicles':'abandoned vehicle'})
processed_comps.update({'Abandoned Vehicle':'abandoned vehicle'})
processed_comps.update({'School Maintenance':'school'})
processed_comps.update({'Violation of Park Rules': 'violation park rule'})
processed_comps.update({'Asbestos': 'asbestos'})
processed_comps.update({'Indoor Air Quality': 'air quality',})
processed_comps.update({'Indoor Sewage': 'sewage'})
processed_comps.update({'Industrial Waste': 'waste'})
processed_comps.update({'Electronics Waste Appointment': 'waste'})
processed_comps.update({'Request Large Bulky Item Collection': 'bulky item'})
processed_comps.update({'Construction Safety Enforcement': 'construction'})
processed_comps.update({'Construction Safety Enforcement': 'construction'})
processed_comps.update({'Tattooing': 'tattoo'})
processed_comps.update({'Missed Collection (All Materials)':'missed collection'})
processed_comps.update({'Homeless Person Assistance': 'homeless assistance'})

# %%
complaints_final = set(list(processed_comps.values()))
len(complaints_final)
# Out:
# 149

# %%
#import the call complaints
call_comps = pd.read_csv('../Outputs/311calls_complaints_vadar_results.csv', index_col = 0)
call_comps.head()
# Out:
#    count                    cat
# 0  84545  Department of Finance  \
# 1  76516      3-1-1 Call Center
# 2  60523  Department of Finance
# 3  57674                    NaN
# 4  57213                    NaN
#
#                                               subcat
# 0  Parking Ticket Lookup - Ticket or Plate Number...  \
# 1                   Service Request Status - General
# 2  Property Tax Account Assistance and Bill Infor...
# 3                                 Bulk Item Disposal
# 4  Heat or Hot Water Complaint in a Residential B...
#
#                                            subsubcat
# 0  Status of a parking ticket. Must know ticket o...  \
# 1    Status of most Service Requests filed with 311.
# 2  Help with questions about the property tax bil...
# 3  Learn how to get rid of bulk items. Schedule, ...
# 4  Report a problem with heat or hot water in a r...
#
#                                        combined_cats
# 0  Department of Finance Parking Ticket Lookup - ...  \
# 1  3-1-1 Call Center Service Request Status - Gen...
# 2  Department of Finance Property Tax Account Ass...
# 3   Bulk Item Disposal Learn how to get rid of bu...
# 4   Heat or Hot Water Complaint in a Residential ...
#
#                                  combined_cats_lower
# 0  department of finance parking ticket lookup - ...  \
# 1  3-1-1 call center service request status - gen...
# 2  department of finance property tax account ass...
# 3   bulk item disposal learn how to get rid of bu...
# 4   heat or hot water complaint in a residential ...
#
#                                      processed_comps
# 0  department finance parking vehicles ticket loo...  \
# 1  call center service request status general sta...
# 2  department finance property building tax accou...
# 3  bulk item disposal learn get rid bulk items sc...
# 4  heat hot water complaint residential building ...
#
#                                     sentiment_scores    neg    neu    pos
# 0  {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'comp...  0.000  0.874  0.126  \
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 2  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...  0.000  0.876  0.124
# 3  {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'comp...  0.111  0.889  0.000
# 4  {'neg': 0.308, 'neu': 0.692, 'pos': 0.0, 'comp...  0.308  0.692  0.000
#
#    compound
# 0    0.1531
# 1    0.0000
# 2    0.4019
# 3   -0.2500
# 4   -0.5994

# %%
len(call_comps[call_comps['count']>100])
# Out:
# 2772

# %%
call_comps = call_comps[call_comps['count']>100]
call_comps['subcat'] = call_comps['subcat'].str.replace('SCRIE','Senior Citizen Rent Increase Exemption') 
call_comps['subcat'] = call_comps['subcat'].str.replace('DRIE','Disability Rent Increase Exemption') 
call_comps['subcat'] = call_comps['subcat'].str.replace('RPIE','Real Property Income and Expense') 
call_comps['subcat'] = call_comps['subcat'].str.replace('DOF','Department of Finance')
call_comps['subcat'] = call_comps['subcat'].str.replace('DCA','Department of Consumer Affairs')
call_comps['subcat'] = call_comps['subcat'].str.replace('DOH','Department of Finance')
call_comps['subcat'] = call_comps['subcat'].str.replace('DEP','Department of Environmental Protection')
call_comps['subcat'] = call_comps['subcat'].str.replace('DPR','Department of Parks and Recreation')
call_comps['subcat'] = call_comps['subcat'].str.replace('DPR','Department of Parks and Recreation')
call_comps['subcat'] = call_comps['subcat'].str.replace('DPR','Department of Parks and Recreation')
call_comps['subcat'] = call_comps['subcat'].str.replace('HPD','Department of Housing Preservation and Development')

call_cats = call_comps.subcat.unique().tolist()
print(len(call_cats))
# Out:
# 2518

# %%
# # Initialize the Porter stemmer
porter=PorterStemmer()
stop_words = set(stopwords.words('english'))
processed_callcomps = {}

# Preprocess the complaint types
for item in call_cats:
    og_complaint = item
    # Convert the key to lowercase and remove punctuation
    item = re.sub('/', ' ', item)
    item = re.sub('-', ' ', item)
    item = item.lower().translate(str.maketrans('', '', string.punctuation))
    # Create an empty list to store the processed values
    words = item.split()
    words_no_stopwords = [word for word in words if word not in stop_words]
    item_no_stopwords = ' '.join(words_no_stopwords)
#     processed_item = porter.stem(item_no_stopwords)
    
    processed_callcomps[og_complaint] = item_no_stopwords

# %%
processed_callcomps
# Out:
# {'Parking Ticket Lookup - Ticket or Plate Number Known': 'parking ticket lookup ticket plate number known',
#  'Service Request Status - General': 'service request status general',
#  'Property Tax Account Assistance and Bill Information': 'property tax account assistance bill information',
#  'Bulk Item Disposal': 'bulk item disposal',
#  'Heat or Hot Water Complaint in a Residential Building': 'heat hot water complaint residential building',
#  'Noise from Neighbor': 'noise neighbor',
#  'Blocked Driveway': 'blocked driveway',
#  'Parking Ticket or Camera Violation Status': 'parking ticket camera violation status',
#  'Service Request Status': 'service request status',
#  'Apartment Maintenance Complaint': 'apartment maintenance complaint',
#  'Vehicle Blocking Driveway Complaint': 'vehicle blocking driveway complaint',
#  'Find a Towed Vehicle - Plate Number Known': 'find towed vehicle plate number known',
#  'Bulk Item Pick Up - Appointment': 'bulk item pick appointment',
#  'Birth Certificate Order': 'birth certificate order',
#  'Missed Garbage, Recycling, or Organics Collection': 'missed garbage recycling organics collection',
#  'City Worker or Agency Complaint or Compliment': 'city worker agency complaint compliment',
#  'Heat or Hot Water Complaint in Entire Residential Building': 'heat hot water complaint entire residential building',
#  'Illegal Parking': 'illegal parking',
#  'Towed Vehicle': 'towed vehicle',
#  'Division Transfer': 'division transfer',
#  'Illegal Parking Complaint': 'illegal parking complaint',
#  'Bulk Item Disposal Information': 'bulk item disposal information',
#  'CFC and Freon Removal': 'cfc freon removal',
#  'Buses and Subways': 'buses subways',
#  'Heat or Hot Water Complaint in Apartment': 'heat hot water complaint apartment',
#  'Parking Ticket or Camera Violation Payment': 'parking ticket camera violation payment',
#  'Find a Police Precinct or PSA by Location': 'find police precinct psa location',
#  'City Agency or Worker Feedback': 'city agency worker feedback',
#  'Property Tax Bill': 'property tax bill',
#  'CFC and Freon Removal - Appointment': 'cfc freon removal appointment',
#  'Alert Information Provided': 'alert information provided',
#  'Birth Certificate from 1910 to Present': 'birth certificate 1910 present',
#  'Housing Court for Tenants and Landlords': 'housing court tenants landlords',
#  'Directory Assistance': 'directory assistance',
#  'Parking Ticket or Camera Violation Dispute': 'parking ticket camera violation dispute',
#  'Property Tax Bill Assistance': 'property tax bill assistance',
#  'Illegal Dumping': 'illegal dumping',
#  'Parking Ticket or Camera Violation Assistance': 'parking ticket camera violation assistance',
#  'Contact Information - Directory Assistance': 'contact information directory assistance',
#  'Abandoned Vehicle': 'abandoned vehicle',
#  'Dangerous Location or Situation': 'dangerous location situation',
#  'Recycling and Trash Collection Schedules': 'recycling trash collection schedules',
#  'Police Precincts and PSAs': 'police precincts psas',
#  'Jail System Complaint': 'jail system complaint',
#  'Property Tax Payment Assistance': 'property tax payment assistance',
#  'Find a Towed Vehicle - Plate Number Unknown - NYPD': 'find towed vehicle plate number unknown nypd',
#  'Missed Garbage Collection': 'missed garbage collection',
#  'Find a Police Precinct or PSA by Name': 'find police precinct psa name',
#  'Towed Vehicle Reclaim from NYPD': 'towed vehicle reclaim nypd',
#  'E-Waste Pickup Appointment': 'e waste pickup appointment',
#  'Bus or Subway - Information and Complaint': 'bus subway information complaint',
#  'Hot Transfer 911': 'hot transfer 911',
#  'Garbage, Recycling, and Organics Collection': 'garbage recycling organics collection',
#  'Noise from Street or Sidewalk': 'noise street sidewalk',
#  'Department of Finance Business Centers': 'department finance business centers',
#  'Housing Court Information for Tenant and Landlord Disputes': 'housing court information tenant landlord disputes',
#  'Electronics Disposal': 'electronics disposal',
#  'Outside of 311 Jurisdiction': 'outside 311 jurisdiction',
#  'Department of Housing Preservation and Development Building Information and Code Enforcement Borough Service Centers': 'department housing preservation development building information code enforcement borough service centers',
#  'Traffic or Pedestrian Signal Complaint': 'traffic pedestrian signal complaint',
#  'Property Deed or Record': 'property deed record',
#  'Fair Fares NYC Card Replacement': 'fair fares nyc card replacement',
#  'Public School Calendar': 'public school calendar',
#  'Building Construction Complaint': 'building construction complaint',
#  'Rent Freeze Program Assistance': 'rent freeze program assistance',
#  'City-Issued Violation or Summons': 'city issued violation summons',
#  'Illegal Dumping - Past': 'illegal dumping past',
#  'Parking Ticket Payment Problem or Penalty Adjustment': 'parking ticket payment problem penalty adjustment',
#  'Language Assistance': 'language assistance',
#  'Fire Hydrant Complaint': 'fire hydrant complaint',
#  'Status of a Birth Certificate Order': 'status birth certificate order',
#  'Homeless Shelter Complaint': 'homeless shelter complaint',
#  'NYCHA Public Housing Maintenance Complaint': 'nycha public housing maintenance complaint',
#  'Find a Towed Vehicle - Accident, Filming, Street Event, or Construction': 'find towed vehicle accident filming street event construction',
#  'Rent Freeze Program Renewal': 'rent freeze program renewal',
#  'Traffic or Pedestrian Signal Condition': 'traffic pedestrian signal condition',
#  'Injured or Sick Animal': 'injured sick animal',
#  'Recycling Rules': 'recycling rules',
#  'Inmate Location and Information': 'inmate location information',
#  'Abandoned Vehicle With Plates on Public Property': 'abandoned vehicle plates public property',
#  'Parking Meter Complaint': 'parking meter complaint',
#  'Noise from Construction': 'noise construction',
#  'Homeless Shelter Complaint - Shelter Client': 'homeless shelter complaint shelter client',
#  'Taxi Lost and Found': 'taxi lost found',
#  'Free Tax Preparation - In Person Assistance': 'free tax preparation person assistance',
#  'Residential Public Area Maintenance Complaint': 'residential public area maintenance complaint',
#  'Mattress or Box Spring Disposal Information and Appointment': 'mattress box spring disposal information appointment',
#  'Noise from Vehicle': 'noise vehicle',
#  'Mental Health Support and NYC Well': 'mental health support nyc well',
#  'Missed Recycling Collection': 'missed recycling collection',
#  'School Calendar and Closures': 'school calendar closures',
#  'SNAP (Food Stamps)': 'snap food stamps',
#  'Abandoned Derelict Vehicle Without Plates on Public Property': 'abandoned derelict vehicle without plates public property',
#  'Homeless Shelters': 'homeless shelters',
#  'Bulk Item Pick Up - Appointment Status': 'bulk item pick appointment status',
#  'Pay a Parking Ticket - Online': 'pay parking ticket online',
#  'Pothole on Street': 'pothole street',
#  'Property Tax Exemption Assistance': 'property tax exemption assistance',
#  'Property Tax Bill or Payment Problem': 'property tax bill payment problem',
#  'Blocked Sidewalk or Street': 'blocked sidewalk street',
#  'Noise from Construction After Hours': 'noise construction hours',
#  'Fair Fares NYC': 'fair fares nyc',
#  'Dead Animal': 'dead animal',
#  'Elevator or Escalator Complaint': 'elevator escalator complaint',
#  'Power Outage': 'power outage',
#  'Child Care Financial Assistance': 'child care financial assistance',
#  'Legal Assistance': 'legal assistance',
#  'IDNYC - Make an Appointment': 'idnyc make appointment',
#  'Social Security': 'social security',
#  'Rat or Mouse Complaint': 'rat mouse complaint',
#  'NYCHA Borough Management Office': 'nycha borough management office',
#  'Sidewalk Violation and Repair': 'sidewalk violation repair',
#  'Streetlight Condition': 'streetlight condition',
#  'Death Certificate': 'death certificate',
#  "Senior Citizen Homeowners' Exemption (SCHE)": 'senior citizen homeowners exemption sche',
#  'Birth Certificate Change': 'birth certificate change',
#  'Immigration and Citizenship': 'immigration citizenship',
#  'Homeless Outreach': 'homeless outreach',
#  'School Tax Relief for Homeowners (STAR)': 'school tax relief homeowners star',
#  'MetroCard - Information and Complaint': 'metrocard information complaint',
#  'Rodent Complaint - Other Location': 'rodent complaint location',
#  'Mattress or Box Spring Disposal': 'mattress box spring disposal',
#  'Parking Meter Defective or Damaged': 'parking meter defective damaged',
#  'Tree Pruning': 'tree pruning',
#  'Rent Freeze Program for Seniors': 'rent freeze program seniors',
#  'Water and Sewer Bill': 'water sewer bill',
#  'Lawyer Referral': 'lawyer referral',
#  'IDNYC Municipal ID Card': 'idnyc municipal id card',
#  'Property Tax Exemption Initial Application - SCHE': 'property tax exemption initial application sche',
#  'Comment for the Mayor': 'comment mayor',
#  'City-Issued Summons - Information': 'city issued summons information',
#  'Fair Fares NYC Complaint or Inquiry': 'fair fares nyc complaint inquiry',
#  'Parking Signs and Rules': 'parking signs rules',
#  'Lost Property in a Taxi - Medallion Number Known': 'lost property taxi medallion number known',
#  'Illegal Conversion of Residential Space': 'illegal conversion residential space',
#  'Traffic Condition': 'traffic condition',
#  'Pothole or Cave-In on Street': 'pothole cave street',
#  'Sewer Backup': 'sewer backup',
#  'Date and Time': 'date time',
#  'Division Referral': 'division referral',
#  'Residential Building-Wide Maintenance Complaint': 'residential building wide maintenance complaint',
#  'Building Construction Without Permit': 'building construction without permit',
#  'Rent Regulated Apartments': 'rent regulated apartments',
#  'Fair Fares NYC Assistance or Complaint': 'fair fares nyc assistance complaint',
#  'Property Tax Payment': 'property tax payment',
#  'Labor Law Information or Complaint': 'labor law information complaint',
#  'Electronic Disposal Information': 'electronic disposal information',
#  'NYC311': 'nyc311',
#  'Elevator or Escalator Defective or Without Permit': 'elevator escalator defective without permit',
#  'Fight a Parking Ticket - Online': 'fight parking ticket online',
#  'Trees and Sidewalks Repair': 'trees sidewalks repair',
#  'Removal of Large Branch or Entire Tree - City Tree or Property': 'removal large branch entire tree city tree property',
#  "Driver's License": 'drivers license',
#  'Missed Bulk Garbage Collection': 'missed bulk garbage collection',
#  'Property Tax Assistance - Senior Citizen Homeowner Exemption (SCHE)': 'property tax assistance senior citizen homeowner exemption sche',
#  'Water Leak in a Building': 'water leak building',
#  'City Government Jobs': 'city government jobs',
#  'Stray Animal': 'stray animal',
#  'Tenant Harassment': 'tenant harassment',
#  'Dead Animal on Street or Sidewalk - Priority': 'dead animal street sidewalk priority',
#  'IDNYC - Documents Required to Apply': 'idnyc documents required apply',
#  'Public Assistance or Welfare': 'public assistance welfare',
#  'Dirty Sidewalk': 'dirty sidewalk',
#  'Division Information Provided': 'division information provided',
#  'City Claim': 'city claim',
#  'Find an Arrested Person': 'find arrested person',
#  'Residential Garbage Rules': 'residential garbage rules',
#  'Christmas Tree Collection': 'christmas tree collection',
#  'Senior Citizen Rent Increase Exemption - Status Lookup': 'senior citizen rent increase exemption status lookup',
#  'City Parking Permit for People with Disabilities': 'city parking permit people disabilities',
#  'Alternate Side Parking and Street Cleaning': 'alternate side parking street cleaning',
#  'Traffic Ticket': 'traffic ticket',
#  'Streetlight Complaint': 'streetlight complaint',
#  'Labor Law': 'labor law',
#  'Co-op and Condo Property Tax Abatement': 'co op condo property tax abatement',
#  'Water and Sewer Bill Information': 'water sewer bill information',
#  'Fallen Tree or Branch': 'fallen tree branch',
#  'Traffic - Emergency Condition': 'traffic emergency condition',
#  'Sewer Backup Complaint - Priority': 'sewer backup complaint priority',
#  'Time and Date Information': 'time date information',
#  'Locate an Elected Official': 'locate elected official',
#  'Department of Motor Vehicles (DMV)': 'department motor vehicles dmv',
#  'Harassment': 'harassment',
#  'Property Record - Update Owner Information - Residential or Commercial Property': 'property record update owner information residential commercial property',
#  'Discrimination': 'discrimination',
#  'Social Security - Benefits Application and Assistance': 'social security benefits application assistance',
#  'Park Maintenance Complaint': 'park maintenance complaint',
#  'Inmate Medical Concern': 'inmate medical concern',
#  'Taxi Complaint': 'taxi complaint',
#  'Civil Service Exam Information': 'civil service exam information',
#  'Find an Event - General': 'find event general',
#  'Federal Tax Assistance for Individuals - IRS': 'federal tax assistance individuals irs',
#  'Status of Active Street or Sidewalk Construction Permits': 'status active street sidewalk construction permits',
#  'New York State Tax Information': 'new york state tax information',
#  'Booted Vehicle': 'booted vehicle',
#  'Electrical Complaint': 'electrical complaint',
#  'Affordable Housing': 'affordable housing',
#  'Property Tax Benefit - STAR for New Applicants': 'property tax benefit star new applicants',
#  'Birth Certificate Correction or Change': 'birth certificate correction change',
#  'Property Record - Search or Request Document - 1966 to Present': 'property record search request document 1966 present',
#  'Business Tax Assistance': 'business tax assistance',
#  'Mediation': 'mediation',
#  'Food Protection Course': 'food protection course',
#  'Medicaid': 'medicaid',
#  'Homeless Person In Need of Immediate Attention': 'homeless person need immediate attention',
#  'Stolen Property': 'stolen property',
#  'Recycling Rules - Metal': 'recycling rules metal',
#  'Homeless Shelter Intake for Single Adults': 'homeless shelter intake single adults',
#  'Illegal Building Conversion or Occupancy': 'illegal building conversion occupancy',
#  'Postal Service': 'postal service',
#  'Fight a Parking Ticket - In Person': 'fight parking ticket person',
#  'Parking Ticket or Camera Violation Appeal': 'parking ticket camera violation appeal',
#  'Pay a Parking Ticket - By Mail': 'pay parking ticket mail',
#  'File Claim Against the City': 'file claim city',
#  'Fight a Parking Ticket - Appeal Hearing Decision': 'fight parking ticket appeal hearing decision',
#  'Find a Public Hospital': 'find public hospital',
#  'Police Officer Complaint': 'police officer complaint',
#  'Illegal Dumping - Chronic': 'illegal dumping chronic',
#  'Lost Property in a Taxi - Medallion Number Unknown': 'lost property taxi medallion number unknown',
#  'Mayor': 'mayor',
#  'Building Water Complaint': 'building water complaint',
#  'Water Complaint - Apartment': 'water complaint apartment',
#  'Dead Tree': 'dead tree',
#  'Postal Service Consumer Hotline': 'postal service consumer hotline',
#  'Water Main Break - Priority': 'water main break priority',
#  'Department of Motor Vehicles - Assistance and Office Locations': 'department motor vehicles assistance office locations',
#  'Inmate Health and Mental Health Complaints and Concerns': 'inmate health mental health complaints concerns',
#  'Street Sweeping Complaint': 'street sweeping complaint',
#  'Special Waste Disposal': 'special waste disposal',
#  'Dog License': 'dog license',
#  'Eviction Prevention and HomeBase': 'eviction prevention homebase',
#  'Alarm In Progress': 'alarm progress',
#  'Water Leak in Apartment': 'water leak apartment',
#  'Homelessness Prevention through HomeBase': 'homelessness prevention homebase',
#  'Wood Disposal, Chipping, and Pickup - Brooklyn and Queens': 'wood disposal chipping pickup brooklyn queens',
#  'Vehicle Accident': 'vehicle accident',
#  'School Closing and Delay Information': 'school closing delay information',
#  'Child Abuse': 'child abuse',
#  'Animal - Injured or Sick - Large Wildlife, Large or Unusual Bird, or Endangered Species': 'animal injured sick large wildlife large unusual bird endangered species',
#  'Leaf Disposal': 'leaf disposal',
#  'Driver License Information': 'driver license information',
#  'Report Discrimination': 'report discrimination',
#  'Cold Water Complaint - Dirty': 'cold water complaint dirty',
#  'Lien Sale': 'lien sale',
#  'Drug Use': 'drug use',
#  'Pay a Parking Ticket - Department of Finance Business Centers': 'pay parking ticket department finance business centers',
#  'Elections and Voting': 'elections voting',
#  'Death Certificate from 1949 to Present': 'death certificate 1949 present',
#  'One Shot Deal': 'one shot deal',
#  'ParkNYC Parking Payment': 'parknyc parking payment',
#  'Animal Abuse': 'animal abuse',
#  'Homeless Person Outreach Assistance': 'homeless person outreach assistance',
#  'Firehouses': 'firehouses',
#  'Car Accident': 'car accident',
#  'Property Tax Exemption - Transfer from Basic STAR to Enhanced STAR': 'property tax exemption transfer basic star enhanced star',
#  'Parking Permit - Disability - General Information and Application Status': 'parking permit disability general information application status',
#  'Trees and Sidewalk Repair for 1, 2 and 3 Family Residential Property': 'trees sidewalk repair 1 2 3 family residential property',
#  'Hospitals': 'hospitals',
#  'Property Pickup for Former Rikers Island Inmates': 'property pickup former rikers island inmates',
#  'Property Tax Exemption Information': 'property tax exemption information',
#  'Rent Information Line': 'rent information line',
#  'Housing Options for Seniors': 'housing options seniors',
#  'Bulk Item Pick Up - Appointment Cancellation and Rescheduling': 'bulk item pick appointment cancellation rescheduling',
#  'Sidewalk Violation Dismissal - Property Owner Fixed': 'sidewalk violation dismissal property owner fixed',
#  'Identity Theft': 'identity theft',
#  'Christmas Day': 'christmas day',
#  'Electronic Benefit Transfer (EBT) Card': 'electronic benefit transfer ebt card',
#  'Property Tax Assistance - School Tax Relief (STAR)': 'property tax assistance school tax relief star',
#  'Vehicle Registration or License Plate': 'vehicle registration license plate',
#  'Senior Citizen Rent Increase Exemption - Application for Seniors Not Enrolled': 'senior citizen rent increase exemption application seniors enrolled',
#  'Garbage or Recycling Storage Complaint': 'garbage recycling storage complaint',
#  'Property Tax Bill - Request Copy': 'property tax bill request copy',
#  'Department of Education Feedback': 'department education feedback',
#  'Wood Disposal': 'wood disposal',
#  'Noise from Store or Business': 'noise store business',
#  'Senior Citizen Rent Increase Exemption - Assistance - Renewal Applicant': 'senior citizen rent increase exemption assistance renewal applicant',
#  'IDNYC - Complaints, Status, and Inquiries': 'idnyc complaints status inquiries',
#  'Marriage Record': 'marriage record',
#  'Special Waste Disposal Locations and Rules': 'special waste disposal locations rules',
#  'IDNYC Documents Required to Apply': 'idnyc documents required apply',
#  'Catch Basin Complaint': 'catch basin complaint',
#  'Non-Driver ID Card': 'non driver id card',
#  'Broken Sidewalk': 'broken sidewalk',
#  'Find a Park': 'find park',
#  'Heat and Utility Bill Assistance': 'heat utility bill assistance',
#  'Mold Complaint - Apartment': 'mold complaint apartment',
#  'Gas Leak': 'gas leak',
#  'CFC and Freon Removal - Appointment Cancellation': 'cfc freon removal appointment cancellation',
#  'Senior Citizen Rent Increase Exemption - Application for Renewal': 'senior citizen rent increase exemption application renewal',
#  'Garbage Disposal Complaint': 'garbage disposal complaint',
#  'Street Sign Complaint': 'street sign complaint',
#  'Trespassing - In Progress': 'trespassing progress',
#  'Wild Animal': 'wild animal',
#  '211 Information': '211 information',
#  'Noise': 'noise',
#  'Drinking Water': 'drinking water',
#  'Trespassing': 'trespassing',
#  'Marriage Record from 1950 to Present': 'marriage record 1950 present',
#  'Parking Meters': 'parking meters',
#  'Mold Complaint': 'mold complaint',
#  'Service Request Status - Department of Housing Preservation and Development Status Not Found': 'service request status department housing preservation development status found',
#  'Motor Vehicle Registration and License Plates': 'motor vehicle registration license plates',
#  'Passport Information': 'passport information',
#  'Health Insurance Application Assistance - GetCoveredNYC': 'health insurance application assistance getcoverednyc',
#  'NYC311 Feedback': 'nyc311 feedback',
#  'Garbage or Debris in Street': 'garbage debris street',
#  'Building Violation': 'building violation',
#  'Status of a Birth Certificate Correction or Change': 'status birth certificate correction change',
#  'Interpreting Parking or Traffic Sign or Regulation': 'interpreting parking traffic sign regulation',
#  'Water Leak on Street or Sidewalk': 'water leak street sidewalk',
#  'Hospital or Clinic Complaint': 'hospital clinic complaint',
#  'Noise from Bar or Club': 'noise bar club',
#  'Housing Options - Senior - Low-Income': 'housing options senior low income',
#  'Alternate Side Parking or Street Cleaning Information': 'alternate side parking street cleaning information',
#  'Rosh Hashanah': 'rosh hashanah',
#  'Events': 'events',
#  'Catch Basin Clogged or Blocked': 'catch basin clogged blocked',
#  'Parking Ticket Dispute Information': 'parking ticket dispute information',
#  'Animal - Injured or Sick - Stray Dog or Cat': 'animal injured sick stray dog cat',
#  'Housing Rules for Owners and Tenants': 'housing rules owners tenants',
#  'IDNYC Complaints, Status, and Questions': 'idnyc complaints status questions',
#  'Water Complaint - No Water in a Private Home or Commercial Building': 'water complaint water private home commercial building',
#  'Passports': 'passports',
#  'Cave-In In Street': 'cave street',
#  'Standing Dead Tree Removal - City Tree': 'standing dead tree removal city tree',
#  'NYC Well - General Information': 'nyc well general information',
#  'City Agency Record or FOIL Request': 'city agency record foil request',
#  'Lost or Found Property': 'lost found property',
#  'Parking Permit - Disability - City Application': 'parking permit disability city application',
#  'Gas Service and Billing': 'gas service billing',
#  'Noise from Club or Bar': 'noise club bar',
#  'Social Security - Card Application or Replacement': 'social security card application replacement',
#  'Agency Charges Collected by the Department of Finance': 'agency charges collected department finance',
#  'IDNYC - Card Corrections, Changes, and Lost Cards': 'idnyc card corrections changes lost cards',
#  'Booted Vehicle Information': 'booted vehicle information',
#  'Parking Ticket Payment Plan': 'parking ticket payment plan',
#  'Pay Property Tax - Online': 'pay property tax online',
#  'CFC and Freon Removal - Appointment Confirmation and Tag Number': 'cfc freon removal appointment confirmation tag number',
#  'Marriage License': 'marriage license',
#  'Ambulance Patient Location': 'ambulance patient location',
#  'General Information - NYC Courts': 'general information nyc courts',
#  'Find a Towed Vehicle - Blocking a Driveway': 'find towed vehicle blocking driveway',
#  'Manhattan Resident Parking Tax Exemption': 'manhattan resident parking tax exemption',
#  'Traffic Ticket Information': 'traffic ticket information',
#  'Social Security Fraud': 'social security fraud',
#  'Water Main Break': 'water main break',
#  'Parking Ticket Hearing or Appeal Status': 'parking ticket hearing appeal status',
#  'Alarm': 'alarm',
#  'E-ZPass': 'e zpass',
#  'Police Officer Misconduct': 'police officer misconduct',
#  'Planned Water Shutdowns': 'planned water shutdowns',
#  'Access-A-Ride': 'access ride',
#  'Non-Driver State ID Card': 'non driver state id card',
#  'Property Tax Reduction - Co-op or Condo - General Information': 'property tax reduction co op condo general information',
#  'Property Tax Refund Request': 'property tax refund request',
#  'Water Pressure or Temperature Complaint': 'water pressure temperature complaint',
#  'Food Service Establishment Permit - Renew or Status': 'food service establishment permit renew status',
#  'SNAP (Food Stamps) - Status': 'snap food stamps status',
#  'Telemarketing Fraud Complaint': 'telemarketing fraud complaint',
#  'Fire Hazard': 'fire hazard',
#  'ParkNYC User Account Assistance': 'parknyc user account assistance',
#  'ABCs of Housing - Housing Rules and Regulations for NYC Owners and Tenants': 'abcs housing housing rules regulations nyc owners tenants',
#  'Reclaim a Towed Vehicle - NYPD': 'reclaim towed vehicle nypd',
#  'New York City Housing Lottery': 'new york city housing lottery',
#  'Parks': 'parks',
#  'Fight a Parking Ticket - By Mail': 'fight parking ticket mail',
#  'Immigration Help': 'immigration help',
#  'Curb Complaint': 'curb complaint',
#  'Manhole Cover Complaint': 'manhole cover complaint',
#  'Restaurant Permit': 'restaurant permit',
#  'Illegal Eviction or Lockout': 'illegal eviction lockout',
#  'Developmentally Delayed Infant Services': 'developmentally delayed infant services',
#  'General Corporation Tax': 'general corporation tax',
#  'Department of Education Worker or Agency Complaint or Compliment': 'department education worker agency complaint compliment',
#  'One Shot Deal - Short Term Emergency Assistance': 'one shot deal short term emergency assistance',
#  'Bed Bug Complaint': 'bed bug complaint',
#  'Elected Officials': 'elected officials',
#  'NYC Well - Peer Support': 'nyc well peer support',
#  'Pests': 'pests',
#  'New York State Business Permit or License': 'new york state business permit license',
#  'State Parking Permit for People with Disabilities': 'state parking permit people disabilities',
#  'Domestic Violence': 'domestic violence',
#  'Court': 'court',
#  'Improper Trash Disposal': 'improper trash disposal',
#  'Arrested Person Location - Brooklyn': 'arrested person location brooklyn',
#  'Lost Property in a Taxi - Medallion Number Not Found by 311': 'lost property taxi medallion number found 311',
#  'Parking Ticket Lookup - Ticket and Plate Number Unknown': 'parking ticket lookup ticket plate number unknown',
#  'Recycling Rules - Plastic': 'recycling rules plastic',
#  'Dirty Yard or Alley': 'dirty yard alley',
#  'Animal - Nuisance Wildlife': 'animal nuisance wildlife',
#  'SNAP (Food Stamps) - General Information': 'snap food stamps general information',
#  'Divorce Record': 'divorce record',
#  'Homeless Encampment': 'homeless encampment',
#  'Lien Sale Information': 'lien sale information',
#  'Air Conditioners for People with Medical Conditions': 'air conditioners people medical conditions',
#  'Find a Food Pantry or Soup Kitchen': 'find food pantry soup kitchen',
#  'Status of a Birth Certificate for a Newborn Baby': 'status birth certificate newborn baby',
#  'Telemarketing Fraud': 'telemarketing fraud',
#  'Disabled Vehicle': 'disabled vehicle',
#  'Fire Hydrant Running': 'fire hydrant running',
#  'Pre-Kindergarten - General Information': 'pre kindergarten general information',
#  'E-Waste Pickup Appointment Cancellation, Status and Rescheduling': 'e waste pickup appointment cancellation status rescheduling',
#  'Inmate Property Pickup': 'inmate property pickup',
#  'Property Tax Exemption Application Status': 'property tax exemption application status',
#  'Speed Camera Violation - Lookup Status - Notice of Liability Number or Plate Number Known': 'speed camera violation lookup status notice liability number plate number known',
#  'Adult Protective Services': 'adult protective services',
#  'Recycling Bin Sticker - Outdoor Blue': 'recycling bin sticker outdoor blue',
#  'Access-A-Ride Information or Complaint': 'access ride information complaint',
#  'Building Registration': 'building registration',
#  'Missed Bulk Recycling Collection': 'missed bulk recycling collection',
#  'Dispute New Sidewalk Violation - Reinspection Request': 'dispute new sidewalk violation reinspection request',
#  'Parking and Camera Violations Refund Form': 'parking camera violations refund form',
#  'Bag of Garbage or Loose Debris in Street': 'bag garbage loose debris street',
#  'Find a Community Board by Location': 'find community board location',
#  '3-K for All': '3 k',
#  'Unemployment Insurance': 'unemployment insurance',
#  'Car Service Complaint': 'car service complaint',
#  'Parking Permit - Disability - State Application': 'parking permit disability state application',
#  'Bed Bug Complaint - Apartment, Hotel or Single Room Occupancy': 'bed bug complaint apartment hotel single room occupancy',
#  'Child Care Financial Assistance - Voucher Information': 'child care financial assistance voucher information',
#  'IDNYC Card Corrections, Changes, and Lost Cards': 'idnyc card corrections changes lost cards',
#  'Store Complaint': 'store complaint',
#  'Restaurant, Deli, or Food Cart Complaint': 'restaurant deli food cart complaint',
#  'Retail Store Complaint': 'retail store complaint',
#  'Rent Freeze Program for Tenants with Disabilities': 'rent freeze program tenants disabilities',
#  'Lawyer Referral for Seniors': 'lawyer referral seniors',
#  'Fire Hazard Complaint': 'fire hazard complaint',
#  'Lost or Stolen Fair Fares MetroCard': 'lost stolen fair fares metrocard',
#  'Department of Parks and Recreation Special Events Application': 'department parks recreation special events application',
#  'Senior Citizen Rent Increase Exemption - Assistance - Senior Participant': 'senior citizen rent increase exemption assistance senior participant',
#  'Action NYC - Immigration Legal Help Appointment': 'action nyc immigration legal help appointment',
#  "Washington's Birthday Information": 'washingtons birthday information',
#  'Fire Hydrant Running Full': 'fire hydrant running full',
#  'Accessible Taxi Dispatch': 'accessible taxi dispatch',
#  'IDNYC - Enrollment Centers': 'idnyc enrollment centers',
#  'Pay Property Tax - By Mail': 'pay property tax mail',
#  'NYCHA Borough Management Office - Brooklyn': 'nycha borough management office brooklyn',
#  'Traffic - Non-Emergency Condition': 'traffic non emergency condition',
#  'Job Center Complaint': 'job center complaint',
#  'Con Ed Power Outage or Blackout': 'con ed power outage blackout',
#  'New Tree Request - City Street': 'new tree request city street',
#  'Affordable Housing Opportunities and Application Information': 'affordable housing opportunities application information',
#  'Tenant Harassment Assistance': 'tenant harassment assistance',
#  'Homeless Shelter Intake for Families with Children': 'homeless shelter intake families children',
#  'Drug Sale': 'drug sale',
#  'Department of Sanitation Worker or Vehicle Complaint': 'department sanitation worker vehicle complaint',
#  'Street Resurfacing Request': 'street resurfacing request',
#  'Verizon Telephone, Internet, and Cable Service': 'verizon telephone internet cable service',
#  'NYCHA Borough Management Office - Manhattan': 'nycha borough management office manhattan',
#  'Eviction Prevention Assistance - Legal Services at Housing Court': 'eviction prevention assistance legal services housing court',
#  'Ambulance Patient Locator': 'ambulance patient locator',
#  'Status of Request for Death Certificate from 1949 to Present': 'status request death certificate 1949 present',
#  'HEAP': 'heap',
#  'Tree Planting': 'tree planting',
#  'Pay a Parking Ticket - Mobile App': 'pay parking ticket mobile app',
#  'Water in Basement - Less Than One Foot': 'water basement less one foot',
#  'Recycling Bin Sticker - Outdoor Green': 'recycling bin sticker outdoor green',
#  'Parking Ticket or Camera Violation Payment Plan': 'parking ticket camera violation payment plan',
#  'Verizon Telephone Pole or Wire Complaint': 'verizon telephone pole wire complaint',
#  'Business Background Check': 'business background check',
#  'Blocked Sidewalk or Street - Basketball Hoop or Personal Property': 'blocked sidewalk street basketball hoop personal property',
#  'Parking Ticket or Camera Violation Copy': 'parking ticket camera violation copy',
#  'Electric Service and Billing': 'electric service billing',
#  'Public Utility Complaint': 'public utility complaint',
#  'General Information for People with Disabilities': 'general information people disabilities',
#  'Smoking Complaint': 'smoking complaint',
#  'Toll Bridge or Tunnel - Within NYC': 'toll bridge tunnel within nyc',
#  'Parking Meter Information': 'parking meter information',
#  'Family Court': 'family court',
#  'Animal - Found or Stray - Dog or Large Wildlife': 'animal found stray dog large wildlife',
#  'Noise from Air Conditioner or Ventilation Equipment': 'noise air conditioner ventilation equipment',
#  'Good Friday Information': 'good friday information',
#  'Food Cart Vendor License or Permit': 'food cart vendor license permit',
#  'Property Value and Assessment': 'property value assessment',
#  'Medical Emergency': 'medical emergency',
#  'NOPV - Annual Notice of Property Value Information': 'nopv annual notice property value information',
#  'Medical or Health Related Emergency': 'medical health related emergency',
#  'Unemployment Insurance Information': 'unemployment insurance information',
#  'Property Tax Account History - Request Copy': 'property tax account history request copy',
#  "Senior Citizen Homeowners' Exemption (SCHE) Renewal": 'senior citizen homeowners exemption sche renewal',
#  'Cable Complaint': 'cable complaint',
#  'Noise from Dog': 'noise dog',
#  'Martin Luther King Jr. Day Information': 'martin luther king jr day information',
#  'Police Report': 'police report',
#  'Park Event Permit': 'park event permit',
#  'Day Care Permit and Operation': 'day care permit operation',
#  'Missing Person': 'missing person',
#  'Building Unstable - Priority': 'building unstable priority',
#  'Vacant Lot Complaint': 'vacant lot complaint',
#  'Animal - Possibly Rabid': 'animal possibly rabid',
#  'Sidewalk Violation Search': 'sidewalk violation search',
#  'Manhole Cover Noise or Defect - Street': 'manhole cover noise defect street',
#  'Disability Access': 'disability access',
#  'Noise from Dog or Other Animal': 'noise dog animal',
#  'Arrested Person Location - Manhattan': 'arrested person location manhattan',
#  'Columbus Day': 'columbus day',
#  'IDNYC - General Information': 'idnyc general information',
#  'Chemical Complaint': 'chemical complaint',
#  'DOB NOW': 'dob',
#  'Towed Vehicle Information': 'towed vehicle information',
#  'Abandoned Pet': 'abandoned pet',
#  'Medicare': 'medicare',
#  'Health Insurance': 'health insurance',
#  'Pay a Parking Ticket - PayNearMe': 'pay parking ticket paynearme',
#  'New York State Licensed Professional or Business Complaint': 'new york state licensed professional business complaint',
#  'New York Police Department (NYPD)': 'new york police department nypd',
#  'Homeless Shelter Resident Assistance': 'homeless shelter resident assistance',
#  'Homeless - Chronic or Encampment': 'homeless chronic encampment',
#  'Animal - Injured or Sick - Common Bird or Small Wildlife': 'animal injured sick common bird small wildlife',
#  'NYC Care': 'nyc care',
#  'State Tax': 'state tax',
#  'Red Light Camera Violation Lookup - Notice of Liability Number or Plate Number Known': 'red light camera violation lookup notice liability number plate number known',
#  'Drug Activity Use Inside - In Progress': 'drug activity use inside progress',
#  'Bridges': 'bridges',
#  'Heat Complaint in NYCHA Building': 'heat complaint nycha building',
#  'Animal - Vicious': 'animal vicious',
#  'Assistance for Homeless People in Shelters': 'assistance homeless people shelters',
#  'Dog or Animal Waste': 'dog animal waste',
#  'Donate or Find Goods': 'donate find goods',
#  'Arrested Person Location - Bronx': 'arrested person location bronx',
#  'Property Tax Exemption Renewal Application - SCHE': 'property tax exemption renewal application sche',
#  'Veterans Day': 'veterans day',
#  '311 Complaint or Compliment': '311 complaint compliment',
#  'Building Construction Unauthorized After Hours': 'building construction unauthorized hours',
#  'Flooding Street': 'flooding street',
#  'Fire Hydrant Leaking': 'fire hydrant leaking',
#  'Department of Consumer Affairs Online Licensing Service - Technical Assistance': 'department consumer affairs online licensing service technical assistance',
#  'Commercial Garbage Disposal Complaint': 'commercial garbage disposal complaint',
#  'Election Day': 'election day',
#  'Pre-Kindergarten Enrollment': 'pre kindergarten enrollment',
#  'Sidewalk Construction Permit': 'sidewalk construction permit',
#  'Tree Pruning - Hitting Building': 'tree pruning hitting building',
#  'Day Care Center Permit and Operations': 'day care center permit operations',
#  'Drug Activity Use or Sale Outside - In Progress': 'drug activity use sale outside progress',
#  'Street Repair Complaint': 'street repair complaint',
#  'Water Meter Broken or Leaking - Priority': 'water meter broken leaking priority',
#  'Home Care': 'home care',
#  'Lead in Drinking Water': 'lead drinking water',
#  'Federal Tax': 'federal tax',
#  'Towed Vehicle Reclaim from Marshal or Sheriff': 'towed vehicle reclaim marshal sheriff',
#  'Food Protection Course for Businesses that Serve or Process Food - Online': 'food protection course businesses serve process food online',
#  'Cooling Assistance Program - Air Conditioner': 'cooling assistance program air conditioner',
#  'Street, Highway, Bridge, and Tunnel Closures': 'street highway bridge tunnel closures',
#  'Street Vendor Complaint': 'street vendor complaint',
#  'Electrical Complaint in Apartment': 'electrical complaint apartment',
#  'Home Improvement Contractor License - Renew or Status': 'home improvement contractor license renew status',
#  '311 Call Center': '311 call center',
#  'Taxi Inquiry or Complaint from Taxi Driver or Taxi Licensee': 'taxi inquiry complaint taxi driver taxi licensee',
#  'New York State Professional or Business License or Permit': 'new york state professional business license permit',
#  'Food Safety Complaint - Deli or Restaurant': 'food safety complaint deli restaurant',
#  'Technical Assistance - Health Department Online Licensing or Obtain PIN': 'technical assistance health department online licensing obtain pin',
#  'Thanksgiving Day': 'thanksgiving day',
#  'Building Construction or Alteration Permit': 'building construction alteration permit',
#  'School Finder': 'school finder',
#  'Rabid Animal': 'rabid animal',
#  'Jury Duty': 'jury duty',
#  'People with Disabilities Services': 'people disabilities services',
#  'Disorderly Person or Group': 'disorderly person group',
#  'Con Ed Electric Customer Service': 'con ed electric customer service',
#  'Garbage or Recycling Storage Complaint - Outside Building': 'garbage recycling storage complaint outside building',
#  'Drug and Alcohol Treatment': 'drug alcohol treatment',
#  'SafeLink Cell Phone Program': 'safelink cell phone program',
#  'NOPV - Assessed Value, Exemption, Tax Class - Request an Appeal': 'nopv assessed value exemption tax class request appeal',
#  'Child Care': 'child care',
#  'Medicaid - Existing Applicant or Enrollee': 'medicaid existing applicant enrollee',
#  'Smoking Complaint - Residence': 'smoking complaint residence',
#  'Department of Housing Preservation and Development Section 8': 'department housing preservation development section 8',
#  'Tree Work Permit': 'tree work permit',
#  'Unstable Building': 'unstable building',
#  'Street or Highway Sign Installation, Removal, or Relocation': 'street highway sign installation removal relocation',
#  'Disabled Vehicle on Street': 'disabled vehicle street',
#  'Child Support': 'child support',
#  'General Vendor License': 'general vendor license',
#  'Blocked Street - Construction': 'blocked street construction',
#  'Citizenship Appointment': 'citizenship appointment',
#  'Manhattan Resident Parking Tax Exemption Information and Assistance': 'manhattan resident parking tax exemption information assistance',
#  'Investigate a Business Licensed by Department of Consumer Affairs': 'investigate business licensed department consumer affairs',
#  'Littering': 'littering',
#  'Criminal Mischief': 'criminal mischief',
#  'Community Boards': 'community boards',
#  'NOPV - Market Value - Request a Review': 'nopv market value request review',
#  'NYCHA Borough Management Office - Bronx': 'nycha borough management office bronx',
#  'Noise from Park': 'noise park',
#  'National Grid Metro NY': 'national grid metro ny',
#  'Taxpayer Advocate': 'taxpayer advocate',
#  'Criminal Court Information': 'criminal court information',
#  'Pest Control Complaint in Apartment': 'pest control complaint apartment',
#  'Dog Waste - Street, Sidewalk or Adjoining Area': 'dog waste street sidewalk adjoining area',
#  'FOIL - City Document Request': 'foil city document request',
#  'Outdoor Electrical System Complaint': 'outdoor electrical system complaint',
#  '3-K Enrollment': '3 k enrollment',
#  'Dead Animal on Private Property': 'dead animal private property',
#  'Veterans Property Tax Exemption': 'veterans property tax exemption',
#  'Tax Reduction and Construction Exemption and Abatement Programs - Residential Properties': 'tax reduction construction exemption abatement programs residential properties',
#  'Memorial Day Information': 'memorial day information',
#  "Administration for Children's Services Case Status": 'administration childrens services case status',
#  'Telemarketing Do Not Call Registry': 'telemarketing call registry',
#  'Airports': 'airports',
#  'School Transportation Complaint': 'school transportation complaint',
#  'Department of Consumer Affairs Online Licensing': 'department consumer affairs online licensing',
#  'Bees or Wasps Complaint': 'bees wasps complaint',
#  'Financial Counseling': 'financial counseling',
#  'Name Change': 'name change',
#  'Family Court Information': 'family court information',
#  'Animal - Unwanted Pet': 'animal unwanted pet',
#  'Benefit Card Replacement for Cash Assistance or Food Stamp Client': 'benefit card replacement cash assistance food stamp client',
#  'Nursing Home Complaint': 'nursing home complaint',
#  'Water in Basement - More Than One Foot - Priority': 'water basement one foot priority',
#  'Elder Abuse': 'elder abuse',
#  'Taxi Driver or Licensee Assistance': 'taxi driver licensee assistance',
#  'Fight a Parking Ticket - Mobile App': 'fight parking ticket mobile app',
#  'Food Protection Course for Businesses that Serve or Process Food - Classroom': 'food protection course businesses serve process food classroom',
#  "New Year's Day": 'new years day',
#  'Inmate Visit': 'inmate visit',
#  'Day Care Center Complaint': 'day care center complaint',
#  'Sidewalk Violation Information': 'sidewalk violation information',
#  'Stop Work Order Information or Violation - Priority': 'stop work order information violation priority',
#  'Indoor Air Quality - Chemical Odors Vapors or Soot': 'indoor air quality chemical odors vapors soot',
#  'Home Improvement Contractor License': 'home improvement contractor license',
#  'Find a Consulate': 'find consulate',
#  'Residential Heat and Hot Water Requirements': 'residential heat hot water requirements',
#  'NYCHA Public Housing Section 8': 'nycha public housing section 8',
#  'Disability Rent Increase Exemption - Status Lookup': 'disability rent increase exemption status lookup',
#  'Food Pantries and Soup Kitchens': 'food pantries soup kitchens',
#  'SNAP (Food Stamps) - Benefits Schedule': 'snap food stamps benefits schedule',
#  'Idling Vehicle': 'idling vehicle',
#  'CityFHEPS Tenant Information': 'cityfheps tenant information',
#  'Building Construction Outside Approved Plans': 'building construction outside approved plans',
#  'Telemarketing Do Not Call Registration': 'telemarketing call registration',
#  'Criminal Court': 'criminal court',
#  'School Districts': 'school districts',
#  'Libraries': 'libraries',
#  'Unwanted Pet': 'unwanted pet',
#  "New Year's Holiday Information": 'new years holiday information',
#  'Traffic Conditions - New York Metro Area': 'traffic conditions new york metro area',
#  'NYC Agency Commissioner and Senior Staff Information': 'nyc agency commissioner senior staff information',
#  'Borough-Block-Lot (BBL) Lookup': 'borough block lot bbl lookup',
#  'Senior Citizen Rent Increase Exemption - Assistance - New Applicant': 'senior citizen rent increase exemption assistance new applicant',
#  'Street Flooding': 'street flooding',
#  'Pet Spaying or Neutering': 'pet spaying neutering',
#  'Fireworks Complaint': 'fireworks complaint',
#  'Agency Charge Collected by the Department of Finance': 'agency charge collected department finance',
#  'Building Construction Site Unsafe - Priority': 'building construction site unsafe priority',
#  'Building Permit Status': 'building permit status',
#  'Child Care Financial Assistance - Eligibility Information and Application By Mail': 'child care financial assistance eligibility information application mail',
#  'Reckless Driving': 'reckless driving',
#  'Residential Construction Tax Benefit Programs': 'residential construction tax benefit programs',
#  'Litter Basket Request': 'litter basket request',
#  'Recycling Rules - Paper': 'recycling rules paper',
#  'Missed Organics Collection': 'missed organics collection',
#  'Recycling Rules - Glass': 'recycling rules glass',
#  'Real Property Income and Expense (Real Property Income and Expense)': 'real property income expense real property income expense',
#  'SNAP (Food Stamps) - Find a Food Stamp Center': 'snap food stamps find food stamp center',
#  'Tree Pruning - Blocking Sidewalk or Street': 'tree pruning blocking sidewalk street',
#  'Drug Activity Use - Not In Progress': 'drug activity use progress',
#  'School Zones': 'school zones',
#  'Con Edison Worksites': 'con edison worksites',
#  'Property Tax Assistance - Appeal Denial, Removal, or Reduction': 'property tax assistance appeal denial removal reduction',
#  'Order of Protection': 'order protection',
#  'Financial Empowerment Center': 'financial empowerment center',
#  'Water Shutdowns': 'water shutdowns',
#  'Student Records': 'student records',
#  'Parking Ticket Fine or Code Explanation': 'parking ticket fine code explanation',
#  'Dust': 'dust',
#  'Disability Rent Increase Exemption - Initial Application': 'disability rent increase exemption initial application',
#  'Real Property Income and Expense (Real Property Income and Expense) Information and Assistance': 'real property income expense real property income expense information assistance',
#  'Arrested Person Location - Queens': 'arrested person location queens',
#  'Summer Jobs for Youth': 'summer jobs youth',
#  'IDNYC - Change or Look Up Appointment': 'idnyc change look appointment',
#  'Day After Thanksgiving': 'day thanksgiving',
#  'Blocked Building Exit or Fire Escape': 'blocked building exit fire escape',
#  'Help Recovering Unpaid Wages': 'help recovering unpaid wages',
#  'Taxi Driver License': 'taxi driver license',
#  'Lost or Seized Pet': 'lost seized pet',
#  'Dangerous Animal': 'dangerous animal',
#  'Consulate or Embassy': 'consulate embassy',
#  'Dispute Mediation Service - Brooklyn': 'dispute mediation service brooklyn',
#  'Street Sign Request': 'street sign request',
#  'Social Security - Report Fraud': 'social security report fraud',
#  'Dog License - Apply or Renew': 'dog license apply renew',
#  'Street Vendor - Unlicensed or Operating in Prohibited Area': 'street vendor unlicensed operating prohibited area',
#  'NYCHA Public Housing Application': 'nycha public housing application',
#  'Plate Condition - Street': 'plate condition street',
#  'Property Record - Update Document - 1966 to Present': 'property record update document 1966 present',
#  'Business Tax Payment': 'business tax payment',
#  'Blocked Sidewalk - Advertising Sign, Merchandise or Garbage': 'blocked sidewalk advertising sign merchandise garbage',
#  'Find Cross Streets': 'find cross streets',
#  'Domestic Violence Hotline - Victims Assistance': 'domestic violence hotline victims assistance',
#  'Paid Safe and Sick Leave': 'paid safe sick leave',
#  'Find a School': 'find school',
#  'Adult Education': 'adult education',
#  "Child Care Financial Assistance - Children's Services Clients": 'child care financial assistance childrens services clients',
#  'Health Insurance for Adults - Medicaid': 'health insurance adults medicaid',
# ...
#  'Disposal of Leaves': 'disposal leaves',
#  'Trespassing - Past or Chronic': 'trespassing past chronic',
#  'Mosquitoes': 'mosquitoes',
#  'Food Poisoning Complaint - 1 or 2 People Sick': 'food poisoning complaint 1 2 people sick',
#  'Vehicle Accident Report': 'vehicle accident report',
#  'Street Sign - Missing': 'street sign missing',
#  'Domestic Partnership': 'domestic partnership',
#  'Health and Mental Hygiene Literature': 'health mental hygiene literature',
#  'Public Housing Application Information and Assistance': 'public housing application information assistance',
#  'Start a Small Business': 'start small business',
#  "City Agency Commissioners and Mayor's Senior Staff": 'city agency commissioners mayors senior staff',
#  'Service Request Status - DOB Status Not Found': 'service request status dob status found',
#  'Water Complaint - Low Water Pressure in a Private Home or Commercial Building': 'water complaint low water pressure private home commercial building',
#  'Civil Court for Disputes Under $25,000': 'civil court disputes 25000',
#  'Unincorporated Business Tax': 'unincorporated business tax',
#  'Child Care Financial Assistance - Recertification': 'child care financial assistance recertification',
#  'Ventilation or Exhaust System Complaint': 'ventilation exhaust system complaint',
#  'Health Insurance for Seniors': 'health insurance seniors',
#  'Property Record - Mortgage Satisfaction': 'property record mortgage satisfaction',
#  'Street Sign - Damaged': 'street sign damaged',
#  'Stop Work Order': 'stop work order',
#  'Weekend Street Closures': 'weekend street closures',
#  'Noise from Jackhammer': 'noise jackhammer',
#  'Tree Pruning - Hitting Power or Phone Line': 'tree pruning hitting power phone line',
#  "Lincoln's Birthday Information": 'lincolns birthday information',
#  'Standing Water': 'standing water',
#  'Blocked Street - Garbage, Merchandise, Dumpster or Trash Can': 'blocked street garbage merchandise dumpster trash',
#  'Department of Housing Preservation and Development Section 8 for Tenants': 'department housing preservation development section 8 tenants',
#  'Asbestos Complaint': 'asbestos complaint',
#  'Animal - Stray or Found - Healthy Cat': 'animal stray found healthy cat',
#  'Pre-Kindergarten - Apply - Full Day': 'pre kindergarten apply full day',
#  'Stolen Vehicle': 'stolen vehicle',
#  'NYPD General Information': 'nypd general information',
#  'NYC Schools Account': 'nyc schools account',
#  'Home Care - Medicaid Funded for Adult Households': 'home care medicaid funded adult households',
#  'Food Service Establishment Permit - Apply': 'food service establishment permit apply',
#  'New York City Traffic Rules': 'new york city traffic rules',
#  'Food Safety Complaint': 'food safety complaint',
#  'Noise from Alarm': 'noise alarm',
#  'Charter Schools': 'charter schools',
#  'CityFHEPS Tenant Assistance': 'cityfheps tenant assistance',
#  'Commercial Rent Tax': 'commercial rent tax',
#  'Pipe Scaffold or Sidewalk Shed Complaint': 'pipe scaffold sidewalk shed complaint',
#  'Home Care Complaint': 'home care complaint',
#  'Child Care Financial Assistance - General Information': 'child care financial assistance general information',
#  'NYC Well - Drug Treatment - Heroin, Pain Relievers, or Other Drugs': 'nyc well drug treatment heroin pain relievers drugs',
#  'Ice on Roadway - Non-Storm Condition': 'ice roadway non storm condition',
#  'Find a Public Swimming Pool': 'find public swimming pool',
#  'Property Record - Update Owner Information - Condo Unit': 'property record update owner information condo unit',
#  'Animal Spay-Neuter Services - ASPCA': 'animal spay neuter services aspca',
#  'Alternate Side Parking Calendar Request': 'alternate side parking calendar request',
#  'Loose Trash': 'loose trash',
#  'Help Starting a Small Business': 'help starting small business',
#  'Special Education': 'special education',
#  'Snow': 'snow',
#  'Find a Medicaid Office': 'find medicaid office',
#  'Speed Cameras': 'speed cameras',
#  'Find an Event in a Park': 'find event park',
#  'Financial Assistance for Home Heating Emergencies and Utility Shutoffs': 'financial assistance home heating emergencies utility shutoffs',
#  'Street Plate Complaint': 'street plate complaint',
#  'Property Tax Exemption Application - Veterans': 'property tax exemption application veterans',
#  'Traffic Rules': 'traffic rules',
#  'School Transfer': 'school transfer',
#  'Marriage License - Manhattan': 'marriage license manhattan',
#  'Non-Residential Building Maintenance Complaint': 'non residential building maintenance complaint',
#  'Car Dealer Complaint': 'car dealer complaint',
#  'SAFE Disposal Events': 'safe disposal events',
#  'General Vendor License - Apply': 'general vendor license apply',
#  'Pothole or Cave-In on Highway': 'pothole cave highway',
#  'FOIL - Copy of Department of Transportation Service Request or Other DOT Record': 'foil copy department transportation service request dot record',
#  'Medicare Assistance': 'medicare assistance',
#  'Letter of Exemplification - Birth Certificate': 'letter exemplification birth certificate',
#  'Beaches': 'beaches',
#  'NYC Ferry': 'nyc ferry',
#  'Asbestos Complaint - Disturbed - Priority': 'asbestos complaint disturbed priority',
#  'Fire Hydrant Defective': 'fire hydrant defective',
#  "Children's Services Case Status - For Parents": 'childrens services case status parents',
#  'Public Housing Assistance Status - All Boroughs': 'public housing assistance status boroughs',
#  'Property Tax Payment Plan': 'property tax payment plan',
#  'Five Boro Bike Tour': 'five boro bike tour',
#  'Broken Sidewalk - 3 or Fewer Residential Units': 'broken sidewalk 3 fewer residential units',
#  'Year-Round Food Cart Vendor License - Apply': 'year round food cart vendor license apply',
#  'Construction Site Safety': 'construction site safety',
#  'Chemical Odor - Priority': 'chemical odor priority',
#  'Property Tax Exemption for Non-Profits': 'property tax exemption non profits',
#  'Home Improvement Contractor License - Apply': 'home improvement contractor license apply',
#  'Homeless Shelter Intake for Adult Families': 'homeless shelter intake adult families',
#  'Department of Design and Construction (DDC) Services and Projects': 'department design construction ddc services projects',
#  'Lead Paint': 'lead paint',
#  'Overgrown Grass or Weeds': 'overgrown grass weeds',
#  'Case Assistance and Management for Seniors': 'case assistance management seniors',
#  'Homeless Street Condition': 'homeless street condition',
#  'Fence Complaint': 'fence complaint',
#  'Blocked Sidewalk - High Grass or Weeds': 'blocked sidewalk high grass weeds',
#  'Zoning Information Desk': 'zoning information desk',
#  'Water Meter': 'water meter',
#  'Heat Complaint in Non-Residential Building': 'heat complaint non residential building',
#  'Swimming Pools': 'swimming pools',
#  'Lost Item in Sidewalk Grating': 'lost item sidewalk grating',
#  'Animal - Injured or Sick Pet': 'animal injured sick pet',
#  'Home Delivered Meals for Seniors': 'home delivered meals seniors',
#  'Parking and Camera Violation Advocate': 'parking camera violation advocate',
#  'Building Violation Status and Information - Queens': 'building violation status information queens',
#  'Disability Rent Increase Exemption - Assistance - Renewal Applicant': 'disability rent increase exemption assistance renewal applicant',
#  'Manhole Cover Missing - Priority': 'manhole cover missing priority',
#  'County Clerk - Manhattan': 'county clerk manhattan',
#  'Child Care Financial Assistance - Public Assistance Families': 'child care financial assistance public assistance families',
#  'Pothole on Highway': 'pothole highway',
#  'Agency Service Request Copy': 'agency service request copy',
#  'Chained Bike': 'chained bike',
#  'Day Care Center Referrals': 'day care center referrals',
#  'Speed Reducer Request': 'speed reducer request',
#  'Ambulance Billing for FDNY': 'ambulance billing fdny',
#  'Food Protection Certificate Status or Replacement': 'food protection certificate status replacement',
#  'Construction Dust Outdoor Air Quality Complaint': 'construction dust outdoor air quality complaint',
#  'Removal of Branches or Entire Tree - Private Property': 'removal branches entire tree private property',
#  'Internet Service and Online Business Complaint': 'internet service online business complaint',
#  'Reclaim a Towed Vehicle - Marshal or Sheriff': 'reclaim towed vehicle marshal sheriff',
#  'Dog or Animal Waste - Private Property': 'dog animal waste private property',
#  'Senior Citizen Rent Increase Exemption - Appeal a Denial or Revocation': 'senior citizen rent increase exemption appeal denial revocation',
#  'Department of Health Clinics': 'department health clinics',
#  'NYCHA Borough Management Office - Queens and Staten Island': 'nycha borough management office queens staten island',
#  'School Transportation': 'school transportation',
#  'Summer, Overnight or Day Camp Referrals - General': 'summer overnight day camp referrals general',
#  'FDNY Certificates of Fitness': 'fdny certificates fitness',
#  'Public Advocate Information': 'public advocate information',
#  'Adult Vaccination and Immunization': 'adult vaccination immunization',
#  'Graffiti': 'graffiti',
#  'Property Tax Exemption - Personal Exemption Removal': 'property tax exemption personal exemption removal',
#  'Fair Hearing for Public Assistance, Food Stamps, Medicaid, and Energy Assistance': 'fair hearing public assistance food stamps medicaid energy assistance',
#  'NOPV - Property and Vacant Land Description - Request Update': 'nopv property vacant land description request update',
#  'Boiler Complaint': 'boiler complaint',
#  'Service Request Follow-Up': 'service request follow',
#  'Building Construction Site Debris Falling - Priority': 'building construction site debris falling priority',
#  'Animal - Stray or Found - Healthy Small Wildlife': 'animal stray found healthy small wildlife',
#  'Drug Activity Sale - Not in Progress': 'drug activity sale progress',
#  'Arrest Warrant': 'arrest warrant',
#  'Service Request Status - Department of Environmental Protection Status Not Found': 'service request status department environmental protection status found',
#  'Order of Protection Information': 'order protection information',
#  'Water Drainage Complaint': 'water drainage complaint',
#  'Dispute Mediation Service - Bronx': 'dispute mediation service bronx',
#  'Department of Consumer Affairs Violation Business Assistance': 'department consumer affairs violation business assistance',
#  'Yellow Taxi Fare Information': 'yellow taxi fare information',
#  'Used Car Dealer Complaint': 'used car dealer complaint',
#  'Inmate Visit Schedule': 'inmate visit schedule',
#  'Poison Control Center': 'poison control center',
#  'Unusable Bicycle Chained to Public Property': 'unusable bicycle chained public property',
#  'Graffiti Cleanup Request - by Owner': 'graffiti cleanup request owner',
#  'Carbon Monoxide': 'carbon monoxide',
#  'Family Homelessness and Eviction Prevention Supplement (FHEPS)': 'family homelessness eviction prevention supplement fheps',
#  'Senior Citizen Rent Increase Exemption - Assistance - Landlord': 'senior citizen rent increase exemption assistance landlord',
#  'Federal Tax Assistance - Refund Information': 'federal tax assistance refund information',
#  'Unleashed Dog': 'unleashed dog',
#  'Property Tax Payment Plan Application': 'property tax payment plan application',
#  'ParkNYC General Information': 'parknyc general information',
#  'Tow Truck Complaint - Street': 'tow truck complaint street',
#  'Boiler Defective or Without Permit': 'boiler defective without permit',
#  'Speed Camera Violation Payment Problem or Penalty Adjustment': 'speed camera violation payment problem penalty adjustment',
#  'Indoor Air Quality - Ventilation': 'indoor air quality ventilation',
#  'Request Lead Test Kit for Drinking Water': 'request lead test kit drinking water',
#  'Parking Permit - Disability - City Renewal': 'parking permit disability city renewal',
#  'Benefit Card Account Balance or Pin Change': 'benefit card account balance pin change',
#  'Lawyer Complaint': 'lawyer complaint',
#  'Home Delivered Meals for Seniors - Request Enrollment': 'home delivered meals seniors request enrollment',
#  'Food Protection Course for Soup Kitchen and Summer Camp Workers': 'food protection course soup kitchen summer camp workers',
#  'Public Assistance, Medicaid or Food Stamp Fraud': 'public assistance medicaid food stamp fraud',
#  'Food Poisoning': 'food poisoning',
#  'Public Advocate': 'public advocate',
#  'Cable Complaint - Billing': 'cable complaint billing',
#  'FDNY Certificate of Fitness': 'fdny certificate fitness',
#  'Disability Rent Increase Exemption - Renewal Application': 'disability rent increase exemption renewal application',
#  'Find a Senior Center': 'find senior center',
#  'Barbecuing': 'barbecuing',
#  'City-Issued Summons - Request Status or Copy': 'city issued summons request status copy',
#  'Case Assistance for Seniors': 'case assistance seniors',
#  'Citi Bike': 'citi bike',
#  'Home Improvement Contractor License Verification': 'home improvement contractor license verification',
#  'Cable Complaint - Service': 'cable complaint service',
#  'Immunization Record': 'immunization record',
#  'Litter Basket Complaint': 'litter basket complaint',
#  'City and State Jury Duty - Manhattan': 'city state jury duty manhattan',
#  'Car Service Driver Complaint - Unsafe Driving': 'car service driver complaint unsafe driving',
#  'Employee Paid Safe and Sick Leave Information': 'employee paid safe sick leave information',
#  'Snow or Ice on Street or Highway': 'snow ice street highway',
#  'Parole': 'parole',
#  'Quit Smoking': 'quit smoking',
#  'Sidewalk Violation Dismissal - City Fixed': 'sidewalk violation dismissal city fixed',
#  'Bank Complaint': 'bank complaint',
#  'Garbage or Recycling Storage Complaint in Residential Building': 'garbage recycling storage complaint residential building',
#  'Wood Disposal and Pickup - Manhattan, Bronx and Staten Island': 'wood disposal pickup manhattan bronx staten island',
#  'Department of Housing Preservation and Development Section 8 - General Information': 'department housing preservation development section 8 general information',
#  'Public Assistance, Medicaid, or Supplemental Nutrition Assistance Program (SNAP) Fraud': 'public assistance medicaid supplemental nutrition assistance program snap fraud',
#  'Home Care - Seniors': 'home care seniors',
#  'Unpaid Wage Recovery': 'unpaid wage recovery',
#  'Basement Apartment Conversion Pilot Program': 'basement apartment conversion pilot program',
#  'Sidewalk Tree Consultation Request': 'sidewalk tree consultation request',
#  'Vacant Building Complaint': 'vacant building complaint',
#  'John F. Kennedy Airport - General Information Requests': 'john f kennedy airport general information requests',
#  'Property Tax Assistance - Disabled Homeowner Exemption (DHE)': 'property tax assistance disabled homeowner exemption dhe',
#  'Tow Truck Complaint': 'tow truck complaint',
#  'Animal Bite': 'animal bite',
#  'Business Tax Refund': 'business tax refund',
#  'Health Insurance Application Assistance': 'health insurance application assistance',
#  'Sewage Leak or Odor Indoors': 'sewage leak odor indoors',
#  'Planned Bridge, Highway, Tunnel and Street Closures - Manhattan': 'planned bridge highway tunnel street closures manhattan',
#  'Staten Island Ferry': 'staten island ferry',
#  'Family Justice Centers': 'family justice centers',
#  'Broken Sidewalk - City-Owned': 'broken sidewalk city owned',
#  'Street Sign - Dangling': 'street sign dangling',
#  'Taxis': 'taxis',
#  'Inadequate Street Sweeping': 'inadequate street sweeping',
#  'Alcohol Drinking Complaint': 'alcohol drinking complaint',
#  'Taxi Complaint - Rude or Discourteous': 'taxi complaint rude discourteous',
#  'Adult Immunization Clinic': 'adult immunization clinic',
#  'Manhole Flooding': 'manhole flooding',
#  'Loose Garbage': 'loose garbage',
#  'Property Tax Reduction - Co-op or Condo - Renew Abatement': 'property tax reduction co op condo renew abatement',
#  'ACCESS HRA': 'access hra',
#  ...}

# %%
callcomplaints_final = set(list(processed_callcomps.values()))
len(callcomplaints_final)
# Out:
# 2499

# %% [markdown]
# ### Lets try to map the call complaints to the 311 service request subcats
#
# The logic here is:
#
# 1. If subcat contains 1 word, search for word in the processed_callcomps. If the word exists, make key = subcat and value = proccessed_callcomps and append it to the mapping dictionary
#
# 2. If subcat is between 2 and 3 words, each word must appear in processed_callcomps to be appending in the mapping dictionary
#
# 3. If subcat is more than 3 words, at least 50% of the words must appear in the proccessed_callcomps to append in the mapping dictionary
#
# 4. else append to the list of unmapped_callcomps

# %%
mapping = {}
unmapped_callcomps = []

for callcomp in callcomplaints_final:
    callcomp_words = callcomp.split()
    already_mapped = False
    for comp in complaints_final:
        comp_words = comp.split()
        if len(comp_words)<= len(callcomp_words):
            if len(comp_words) == 1:
                if comp_words[0] in callcomp_words:
                    if comp in mapping:
                        if callcomp not in mapping[comp]:
                            mapping[comp].append(callcomp)
                        already_mapped = True
                    else:
                        mapping[comp] = [callcomp]
                        already_mapped = True
            elif (len(comp_words) <= 3) and (len(comp_words) > 1):
                matching_words = [word for word in comp_words if word in callcomp_words]
                if len(matching_words) == len(comp_words):
                    if comp in mapping:
                        if callcomp not in mapping[comp]:
                            mapping[comp].append(callcomp)
                        already_mapped = True
                    else:
                        mapping[comp] = [callcomp]
                        already_mapped = True
            else:
                matching_words = [word for word in comp_words if word in callcomp_words]
                if len(matching_words) >= int(len(comp_words)/2)+1:
                    if comp in mapping:
                        if callcomp not in mapping[comp]:
                            mapping[comp].append(callcomp)
                        already_mapped = True
                    else:
                        mapping[comp] = [callcomp]
                        already_mapped = True
            if already_mapped:
                break
        elif len(comp_words)> len(callcomp_words):
            if len(callcomp_words) == 1:
                if callcomp_words[0] in comp_words:
                    if comp in mapping:
                        if callcomp not in mapping[comp]:
                            mapping[comp].append(callcomp)
                        already_mapped = True
                    else:
                        mapping[comp] = [callcomp]
                        already_mapped = True
            elif (len(callcomp_words) <= 3) and (len(callcomp_words) > 1):
                matching_words = [word for word in callcomp_words if word in comp_words]
                if len(matching_words) == len(callcomp_words):
                    if comp in mapping:
                        if callcomp not in mapping[comp]:
                            mapping[comp].append(callcomp)
                        already_mapped = True
                    else:
                        mapping[comp] = [callcomp]
                        already_mapped = True
            else:
                matching_words = [word for word in callcomp_words if word in comp_words]
                if len(matching_words) >= int(len(callcomp_words)/2)+1:
                    if comp in mapping:
                        if callcomp not in mapping[comp]:
                            mapping[comp].append(callcomp)
                        already_mapped = True
                    else:
                        mapping[comp] = [callcomp]
                        already_mapped = True
            if already_mapped:
                break
    else:
        unmapped_callcomps.append(callcomp)

# %%
mapping
# Out:
# {'linknyc': ['linknyc', 'linknyc complaint'],
#  'lead': ['lead paint complaint apartment residential building 3 units',
#   'lead paint complaint 1 2 family home',
#   'lead paint complaint public housing',
#   'lead safety',
#   'lead paint complaint renovation repair',
#   'lead paint',
#   'lead poisoning prevention children'],
#  'school': ['child immunization clinic school medical exam',
#   'school calendar closures',
#   'school immunization requirements',
#   'high school enrollment',
#   'school closing delay information',
#   'public school registration complaint',
#   'elementary school enrollment',
#   'public school bullying complaint',
#   'school enrollment centers',
#   'new york city school tax credit',
#   'school food complaint',
#   'private parochial school information',
#   'school tax relief homeowners star',
#   'school districts',
#   'elementary middle school enrollment new students',
#   'public school discipline suspension complaint',
#   'school transportation complaint',
#   'elementary school student school program enrolled',
#   'public school safety complaint',
#   'become school safety agent',
#   'public school special education complaint',
#   'school construction',
#   'high school enrollment new students',
#   'public school transfer complaint',
#   'school special education complaint',
#   'parent support hotline p311 public school families',
#   'school zones',
#   'higher education complaint vocational trade school new york state',
#   'pre kindergarten school complaint',
#   'school crossing guard request',
#   'middle school enrollment',
#   'school finder',
#   'child immunization clinic school medical exam referral',
#   'school testing',
#   'public school health complaint',
#   'school transfer request',
#   'school eligibility',
#   'find school district location',
#   'charter school information',
#   'school construction complaint',
#   'school maintenance complaint',
#   'find school',
#   'school parent support p311',
#   'public school transportation complaint',
#   'school bullying',
#   'school transportation',
#   'summer school elementary middle school',
#   'summer school',
#   'public school teaching learning complaint',
#   'school program',
#   'public school calendar',
#   'find school district name',
#   'find school zone',
#   'property tax assistance school tax relief star',
#   'immunization requirements school enrollment',
#   'private parochial school complaint',
#   'school program complaint',
#   'school safety complaint',
#   'public school building repair maintenance complaint',
#   'school transfer',
#   'public school heat complaint'],
#  'street sign dangling': ['street sign dangling'],
#  'panhandling': ['panhandling', 'panhandling progress'],
#  'construction': ['blocked sidewalk construction',
#   'pre construction markings',
#   'building construction complaint',
#   'building construction site debris',
#   'safe construction tenants',
#   'sidewalk construction permit',
#   'department design construction ddc services projects',
#   'status active street sidewalk construction permits',
#   'residential construction tax benefit programs',
#   'blocked sidewalk street construction dumpster',
#   'dust indoor construction commercial non residential building',
#   'building construction site debris falling priority',
#   'sidewalk construction permit queens',
#   'street highway construction rules',
#   'building construction alteration permit staten island',
#   'building construction alteration permit queens',
#   'building construction alteration permit bronx',
#   'street construction permit brooklyn',
#   'building construction without permit',
#   'building construction site unsafe priority',
#   'street construction permit',
#   'building construction alteration permit manhattan',
#   'building construction unauthorized hours',
#   'sidewalk construction permit bronx',
#   'sidewalk construction permit manhattan',
#   'tax reduction construction exemption abatement programs residential properties',
#   'street construction permit queens',
#   'sidewalk construction permit staten island',
#   'construction dust residential building children live',
#   'commercial construction tax benefit programs',
#   'tax reduction construction exemption abatement programs commercial office properties',
#   'building construction unprotected neighboring property priority',
#   'blocked street construction',
#   'building construction alteration permit',
#   'find towed vehicle accident filming street event construction',
#   'street construction permit manhattan',
#   'construction site sign requirements',
#   'building construction alteration permit brooklyn',
#   'sidewalk construction permit brooklyn'],
#  'noise': ['noise garbage truck',
#   'noise bar club',
#   'noise alarm',
#   'manhole cover noise defect street',
#   'noise store business',
#   'noise',
#   'noise ice cream truck',
#   'noise large party large crowd',
#   'noise air conditioner ventilation equipment',
#   'noise vehicle',
#   'noise dog animal',
#   'noise house worship',
#   'noise park',
#   'noise construction hours',
#   'noise helicopter',
#   'noise garbage truck private carter',
#   'noise club bar',
#   'noise garbage truck dsny',
#   'noise jackhammer',
#   'noise lawn equipment',
#   'noise lawn care equipment',
#   'noise street sidewalk',
#   'noise large party crowd',
#   'noise neighbor',
#   'noise code brochure',
#   'noise airplane',
#   'noise boat',
#   'alarm noise past chronic',
#   'noise dog',
#   'noise construction'],
#  'water leak': ['water leak building',
#   'water leak apartment',
#   'water leak street sidewalk',
#   'water leak public area residential building'],
#  'drug activity': ['drug activity use progress',
#   'drug activity use inside progress',
#   'drug activity use sale outside progress',
#   'drug activity sale indoor progress',
#   'drug activity sale progress'],
#  'traffic': ['traffic conditions new york metro area',
#   'truck traffic rules routes',
#   'traffic violation fight ticket appeal hearing decision',
#   'traffic ticket information',
#   'high grass weeds unlandscaped traffic island median',
#   'traffic non emergency condition',
#   'new york city traffic rules',
#   'streetlight traffic signal graffiti information',
#   'high grass weeds landscaped traffic island median',
#   'interpreting parking traffic sign regulation',
#   'traffic pedestrian signal complaint',
#   'traffic violation pay ticket',
#   'traffic pedestrian signal request',
#   'traffic pedestrian signal pole priority',
#   'traffic safety',
#   'traffic pedestrian signal new timing review',
#   'traffic rules',
#   'traffic emergency condition',
#   'traffic pedestrian signal condition',
#   'traffic ticket',
#   'traffic pedestrian signal wires exposed priority',
#   'traffic condition',
#   'service request status dot traffic signal'],
#  'urinating public': ['defecating urinating public'],
#  'department parks recreation internal': ['department parks recreation special events application',
#   'parks'],
#  'street sign damaged': ['street sign damaged'],
#  'food establishment': ['temporary food service establishment permit apply',
#   'temporary food service establishment permit',
#   'food service establishment permit apply',
#   'temporary food service establishment permit renew status',
#   'food service establishment permit renew status',
#   'restaurant food establishment inspection report',
#   'rodent complaint restaurant food service establishment'],
#  'department finance parking tax exemption': ['manhattan resident parking tax exemption',
#   'manhattan resident parking tax exemption information assistance',
#   'manhattan resident parking tax exemption form'],
#  'ferry complaint': ['nyc ferry lost item complaint',
#   'staten island ferry complaint'],
#  'rodent': ['rodent complaint location',
#   'rodent complaint nycha housing',
#   'rodent complaint school'],
#  'street sign missing': ['street sign missing'],
#  'department finance property real property income expense issue': ['real property income expense real property income expense information assistance',
#   'real property income expense real property income expense'],
#  'sewer': ['water sewer bill payment phone',
#   'water sewer bill account information update',
#   'water sewer bill payment person',
#   'catch basin sewer odor',
#   'sewage wastewater catch basin sewer',
#   'water sewer bill dispute',
#   'sewer odor',
#   'water sewer bill payment',
#   'water sewer service line protection program',
#   'water sewer rate',
#   'water sewer bill payment online',
#   'sewer backup complaint priority',
#   'sewer backup',
#   'water tap permit sewer pipe map',
#   'water sewer bill',
#   'sewer backup flood clean',
#   'broken sewer line',
#   'water sewer lien sale',
#   'water sewer rate information',
#   'water sewer bill information'],
#  'disability rent increase': ['disability rent increase exemption assistance approved applicant',
#   'disability rent increase exemption assistance renewal applicant',
#   'disability rent increase exemption status lookup',
#   'disability rent increase exemption appeal denial approval',
#   'department finance enrollment events senior citizen rent increase exemption disability rent increase exemption',
#   'senior citizen rent increase exemption request extension time due disability impairment',
#   'disability rent increase exemption initial application',
#   'senior citizen rent increase exemption disability rent increase exemption information guide',
#   'disability rent increase exemption assistance landlord',
#   'disability rent increase exemption assistance new applicant',
#   'senior citizen rent increase exemption disability rent increase exemption landlord express access portal leap',
#   'disability rent increase exemption enrollment assistance',
#   'disability rent increase exemption renewal application'],
#  'tree': ['standing dead tree removal city tree',
#   'tree bed information',
#   'tree pruning hitting power phone line',
#   'tree destruction',
#   'tree pruning blocking sidewalk street',
#   'tree pruning dead branch tree',
#   'removal branches entire tree private property',
#   'new tree complaint',
#   'sidewalk tree consultation request',
#   'christmas tree disposal',
#   'missed christmas tree collection',
#   'christmas tree collection',
#   'christmas tree dropoff mulchfest',
#   'report tree destruction',
#   'bicycle chained tree public property',
#   'tree stump removal',
#   'removal large branch entire tree city tree property',
#   'dead tree',
#   'tree stump',
#   'tree pruning general information',
#   'removal small branch city tree',
#   'standing dead tree removal private property',
#   'fallen tree branch',
#   'tree planting',
#   'tree sidewalk repair commercial co op condo large residential property',
#   'tree pruning blocking streetlight',
#   'tree work permit',
#   'tree pruning hitting building',
#   'new tree request city street',
#   'tree pruning',
#   'tree bed care'],
#  'mosquitoes': ['mosquitoes'],
#  'missed collection': ['missed bulk recycling collection',
#   'missed garbage recycling organics collection',
#   'missed recycling collection',
#   'missed organics collection',
#   'missed garbage collection',
#   'missed bulk garbage collection'],
#  'borough office': ['nycha borough management office bronx',
#   'nycha borough management office queens staten island',
#   'nycha borough management office',
#   'nycha borough management office manhattan',
#   'hearings division borough office locations',
#   'nycha borough management office brooklyn'],
#  'taxi': ['taxi lost found',
#   'taxi complaint route complaint',
#   'lost property taxi medallion number found 311',
#   'green boro taxi complaint pick refused',
#   'taxi hire vehicle congestion surcharge',
#   'taxi complaint unsafe driving observed non passenger',
#   'taxi driver complaint accessible taxi passenger',
#   'yellow taxi fare information',
#   'yellow green taxi receipt copy',
#   'lost property green taxi license number unknown',
#   'taxi driver licensee assistance',
#   'yellow taxi insurance information request non passenger',
#   'lost property green taxi license number known',
#   'taxi receipt copy',
#   'taxi limousine commission website',
#   'lost property taxi medallion number known',
#   'wheelchair accessible taxi dispatch',
#   'taxi complaint broken missing equipment',
#   'taxi driver license',
#   'found property taxi',
#   'taxi complaint unsafe driving observed passenger',
#   'accessible taxi dispatch',
#   'yellow taxi insurance information request passenger',
#   'green boro taxi complaint rude discourteous',
#   'lost property taxi medallion number unknown',
#   'taxi complaint rude discourteous',
#   'taxi complaint',
#   'taxi complaint credit card fare tip complaint',
#   'accessible taxi dispatch passenger wheelchair',
#   'taxi car service insurance information',
#   'taxi limousine commissions website',
#   'taxi complaint fare e zpass tip complaint',
#   'taxi complaint pick refused',
#   'taxi inquiry complaint taxi driver taxi licensee'],
#  'asbestos': ['asbestos complaint',
#   'asbestos work notification',
#   'asbestos complaint disturbed priority',
#   'asbestos complaint disturbed',
#   'asbestos handler certification',
#   'asbestos abatement work notification',
#   'asbestos health effects'],
#  'illegal parking': ['illegal parking complaint improper use parking permit',
#   'illegal parking complaint intercity buses',
#   'illegal parking complaint',
#   'illegal parking'],
#  'senior citizen rent increase': ['senior citizen rent increase exemption new landlord building manager',
#   'senior citizen rent increase exemption initial application phone assistance',
#   'senior citizen rent increase exemption certification senior citizen rent increase exemption renewal without renewal lease',
#   'senior citizen rent increase exemption assistance senior participant',
#   'senior citizen rent increase exemption submit updated contact information new lease',
#   'senior citizen rent increase exemption ombudsperson assistance',
#   'senior citizen rent increase exemption assistance landlord',
#   'senior citizen rent increase exemption move death',
#   'senior citizen rent increase exemption application renewal',
#   'senior citizen rent increase exemption application adjust tax abatement credit tenant',
#   'senior citizen rent increase exemption application adjust tax abatement credit landlord',
#   'senior citizen rent increase exemption appeal denial revocation',
#   'senior citizen rent increase exemption status lookup',
#   'senior citizen rent increase exemption mitchell lama residents hdfc shareholders',
#   'senior citizen rent increase exemption assistance new applicant',
#   'senior citizen rent increase exemption application seniors enrolled',
#   'senior citizen rent increase exemption assistance renewal applicant'],
#  'department finance property request copy': ['nopv annual notice property value request copy',
#   'property tax account history request copy',
#   'nopv annual notice property value request translated copy',
#   'property tax bill request copy'],
#  'elevator': ['elevator escalator complaint',
#   'elevator escalator code permit',
#   'elevator interior maintenance complaint residential building',
#   'person stuck elevator',
#   'elevator escalator code permit information',
#   'elevator escalator inspection',
#   'elevator escalator defective without permit'],
#  'enforcement': ['enforcement actions unpaid parking camera violation judgments',
#   'notice housing code enforcement issues residential property owners',
#   'sidewalk cleaning enforcement times sticker',
#   'housing code enforcement notice residential property owners',
#   'immigration customs enforcement ice raids',
#   'department housing preservation development building information code enforcement borough service centers'],
#  'general': ['nypd general information',
#   'taxpayer advocate general information inquiry',
#   'secondhand dealer general license renew status',
#   'general vendor license renew status',
#   'parknyc general information',
#   'general corporation tax',
#   'john f kennedy airport general information requests',
#   'find event general',
#   'service request status general',
#   'general vendor license apply',
#   'summer overnight day camp referrals general',
#   'general information nyc courts',
#   'pre kindergarten general information',
#   'department housing preservation development section 8 general information',
#   'child care financial assistance general information',
#   'idnyc general information',
#   'general contractor registration',
#   'parking permit disability general information application status',
#   'summer jobs youth general',
#   'general information people disabilities',
#   'business registration sole proprietors general partnerships',
#   'property tax reduction co op condo general information',
#   'nyc well general information',
#   'general vendor license',
#   'snap food stamps general information',
#   'nyc business website general information',
#   'secondhand dealer general license apply',
#   'business new york city general information',
#   'illegal conversion unsafe living conditions general information',
#   'secondhand dealer general license',
#   'homeless shelter complaint general public',
#   'laguardia airport general information requests',
#   'united nations general assembly'],
#  'department housing preservation development literature request': ['department housing preservation development section 8 landlord tenant fraud',
#   'landlord information removing department housing preservation development violation bronx',
#   'department housing preservation development section 8 housing quality standards hqs inspections',
#   'department housing preservation development section 8 tenants',
#   'department housing preservation development section 8 landlords',
#   'landlord information removing department housing preservation development violation queens',
#   'department housing preservation development section 8',
#   'landlord information removing department housing preservation development violation brooklyn',
#   'department housing preservation development section 8 tenant assistance',
#   'department housing preservation development violation removal landlords',
#   'landlord information removing department housing preservation development violation manhattan',
#   'department housing preservation development section 8 landlord assistance'],
#  'literature request': ['health mental hygiene literature request'],
#  'day care': ['adult day care',
#   'day care center permit operations',
#   'day care center complaint',
#   'day care permit operation',
#   'day care center referrals'],
#  'heat hot water': ['residential heat hot water requirements',
#   'heat hot water complaint apartment',
#   'heat hot water complaint residential building',
#   'heat hot water complaint entire residential building'],
#  'drinking': ['drinking outside',
#   'illness caused drinking water',
#   'lead drinking water',
#   'request lead test kit drinking water',
#   'alcohol drinking complaint',
#   'drinking water information',
#   'drinking water'],
#  'sweeping inadequate': ['inadequate street sweeping'],
#  'homeless encampment': ['homeless encampment', 'homeless chronic encampment'],
#  'elder abuse': ['elder abuse brooklyn limited information anonymous report',
#   'elder abuse queens',
#   'elder abuse',
#   'elder abuse brooklyn senior customer information available',
#   'elder abuse manhattan',
#   'elder abuse bronx'],
#  'beach pool sauna complaint': ['beach complaint', 'pool sauna complaint'],
#  'snow': ['snow ice sidewalk commercial residential',
#   'snow',
#   'snow removal employment',
#   'snow ice roadway report',
#   'snow ice street highway',
#   'snow ice sidewalk shoveling rules',
#   'snow ice sidewalk commercial residential storm delays',
#   'snow ice roadway replowing spreading request',
#   'snow shoveling assistance',
#   'snow ice sidewalk'],
#  'graffiti': ['graffiti cleanup request owner',
#   'report graffiti past chronic',
#   'graffiti',
#   'graffiti removal status check',
#   'graffiti building owners',
#   'graffiti cleanup request residential commercial building'],
#  'food poisoning': ['food poisoning complaint 1 2 people sick',
#   'food poisoning complaint 3 people sick',
#   'food poisoning'],
#  'plumbing': ['plumbing complaint commercial building',
#   'plumbing work past without permit',
#   'plumbing work without permit'],
#  'homeless assistance': ['assistance homeless people shelters',
#   'homeless person outreach assistance',
#   'homeless shelter resident assistance',
#   'shelter assistance runaway homeless youth'],
#  'abandoned vehicle': ['abandoned vehicle plates public property',
#   'abandoned vehicle without plates private property',
#   'abandoned derelict vehicle without plates public property',
#   'abandoned vehicle'],
#  'smoking': ['quit smoking',
#   'smoking complaint',
#   'quit smoking assistance',
#   'smoking complaint residence',
#   'smoking complaint nycha',
#   'residential building smoking policy disclosure law',
#   'smoking complaint building',
#   'quit smoking medication medicaid enrollees'],
#  'unleashed dog': ['unleashed dog park',
#   'unleashed dog',
#   'unleashed dog locations',
#   'unleashed dog apartment building'],
#  'department finance parking request status': ['service request status department consumer affairs',
#   'service request status department housing preservation development status found'],
#  'electrical': ['electrical complaint',
#   'outdoor electrical system complaint',
#   'electrical wiring complaint',
#   'electrical complaint apartment',
#   'electrical wiring installation permit'],
#  'sewage': ['indoor sewage leaks odors complaint tenants',
#   'sewage leak odor indoors'],
#  'waste': ['special waste disposal',
#   'e waste pickup appointment cancellation status rescheduling',
#   'special waste disposal locations rules',
#   'commercial waste private carters information',
#   'commercial waste disposal',
#   'dog waste street sidewalk adjoining area',
#   'dog animal waste private property',
#   'dog animal waste',
#   'e waste pickup appointment',
#   'medical waste disposal'],
#  'animal park': ['wild stray injured animal park',
#   'dead animal park public beach'],
#  'tattoo': ['tattoo license',
#   'tattoo full term license renew status',
#   'tattoo artist infection control course',
#   'infection control course tattoo artists',
#   'tattoo full term license apply'],
#  'lost property': ['lost found property'],
#  'safety': ['food safety complaint food market warehouse processor',
#   'food safety complaint location',
#   'worker safety',
#   'food safety complaint',
#   'construction site safety information',
#   'child safety',
#   'safety netting complaint',
#   'fire safety inspection',
#   'construction site safety',
#   'food safety complaint deli restaurant',
#   'restaurant food cart food safety complaint',
#   'food safety complaint cafeteria bakery',
#   'fire safety education unit',
#   'worker safety information complaint',
#   'construction site safety job training requirements',
#   'fire safety',
#   'bike rules safety',
#   'food safety complaint food cart stand truck'],
#  'housing options': ['housing options senior frail disabled alzheimers dementia',
#   'housing options seniors'],
#  'benefit card replacement': ['benefit card replacement medicaid client',
#   'benefit card replacement cash assistance food stamp client'],
#  'vacant lot': ['vacant lot complaint',
#   'vehicle stored residential property vacant lot',
#   'vacant lot complaint unclean',
#   'vehicle storage residential property vacant lot'],
#  'air quality': ['indoor air quality ventilation',
#   'indoor air quality chemical odors vapors soot',
#   'construction dust outdoor air quality complaint',
#   'indoor air quality complaint odor neighbor',
#   'air quality'],
#  'curb condition': ['painted curb condition'],
#  'department consumer affairs department finance new license application request': ['department consumer affairs online licensing',
#   'department consumer affairs license replacement',
#   'consumer affairs license complaint sign',
#   'department consumer affairs license complaint sign',
#   'pin request consumer affairs license'],
#  'home delivered meal missed delivery': ['home delivered meals seniors missed delivery'],
#  'non residential heat': ['heat complaint non residential building'],
#  'blocked driveway': ['blocked driveway'],
#  'electric': ['con ed electric customer service', 'electric service billing'],
#  'animal abuse': ['animal abuse'],
#  'bus stop shelter': ['bus stop shelter complaint'],
#  'hazardous materials': ['hazardous materials information',
#   'hazardous materials'],
#  'appliance': ['gas appliance pipe permit'],
#  'department finance parking request copy': ['foil copy department transportation service request dot record',
#   'pay parking ticket department finance business centers'],
#  'poison ivy': ['poison ivy', 'poison ivy complaint private property'],
#  'illegal animal kept pet': ['illegal animal kept pet', 'illegal animal'],
#  'senior center complaint': ['senior center complaint'],
#  'outside building': ['garbage recycling storage complaint outside building',
#   'building construction outside approved plans'],
#  'department finance property property value': ['nopv annual notice property value information',
#   'nopv revised notice property value information'],
#  'street condition': ['plate condition street', 'homeless street condition'],
#  'litter basket request': ['litter basket request'],
#  'water quality': ['water quality report'],
#  'mold': ['mold',
#   'mold complaint',
#   'mold complaint apartment',
#   'health effects mold',
#   'mold complaint commercial location'],
#  'housing low income senior': ['housing options senior low income'],
#  'illegal fireworks': ['illegal fireworks progress'],
#  'department environmental protection street condition': ['service request status department environmental protection status found',
#   'department environmental protection public outreach'],
#  'scaffold': ['suspended hanging scaffold complaint priority',
#   'scaffold sidewalk shed complaint',
#   'pipe scaffold sidewalk shed complaint'],
#  'advocate prop refunds credits': ['taxpayer advocate property tax refunds credits complaint'],
#  'vending': ['mobile food vending operating information'],
#  'bridge condition': ['non toll bridge complaint pedestrian walkway condition'],
#  'quality life': ['service request status nypd quality life'],
#  'standing water': ['standing water']}

# %%
len(set(unmapped_callcomps))
# Out:
# 1926

# %%
set(unmapped_callcomps)
# Out:
# {'marriage officiant registration',
#  'business financial assistance',
#  'department health clinics',
#  'drug use',
#  'sanitation sign request',
#  'fair housing information',
#  'county clerk manhattan',
#  'airports',
#  'lien sale information',
#  'police precincts psas',
#  'foil city document request',
#  'verizon telephone internet cable service',
#  'city issued summons hearing online',
#  'unwanted ad menu',
#  'child support',
#  'service request follow',
#  'fire hazard complaint',
#  'rent freeze program landlords',
#  'exchange refund return complaint',
#  'division information provided',
#  'organics collection large multi unit buildings private schools non profit organizations',
#  'youth employment working papers',
#  'nycha fees charges',
#  'store complaint',
#  'job training jobseeker assistance',
#  'police report request',
#  'crime stopper tip',
#  'fair fares nyc assistance complaint',
#  'staten island ferry information statistics',
#  'food protection certificate replacement inquiries',
#  'property tax assistance veteran exemption',
#  'property tax reduction co op condo renew abatement',
#  'agency service request copy',
#  'internet service online business complaint',
#  'broken sidewalk commercial property',
#  'mattress box spring disposal',
#  'property tax payment assistance',
#  'building storefront sign complaint',
#  'anti bullying assistance',
#  'licensed plumber electrician complaint',
#  'city issued violation summons',
#  'divorce separation queens',
#  'kindergarten enrollment',
#  'suicide',
#  'alcoholic beverage licensing information',
#  'professional license',
#  'flu vaccine shot',
#  'utility hardware defect street',
#  'buses subways',
#  'prevailing wage complaint',
#  'property tax bill',
#  'fdny permit inspection',
#  'boiler defective without permit',
#  'medical records hospital',
#  'dob licensing',
#  'locate firehouse brooklyn',
#  'individual corporation disputes 25000 dollars queens',
#  'wild animal',
#  'nopv market value request review status',
#  'domestic violence hotline victims assistance',
#  'change business name address register new business',
#  'green thumb program information',
#  'temporary street fair vendor permit renew status',
#  'home care complaint',
#  'certificate occupancy complaint',
#  'pigeon droppings odor',
#  'community boards',
#  '311 complaint compliment',
#  'drones',
#  '311 call center',
#  'home repair assistance seniors',
#  'co op condo property tax abatement',
#  'mortgage assistance program',
#  'health insurance seniors medicare',
#  'window guard',
#  'dog license changes replace found',
#  'pay speed camera violation online',
#  'public beach complaint',
#  'status birth certificate newborn baby',
#  'city employment check',
#  'health insurance',
#  'alcohol license',
#  'vehicle registration license plate',
#  'labor law',
#  'bulk item pick appointment',
#  'wood disposal',
#  'blocked sidewalk street basketball hoop personal property',
#  'family justice center bronx',
#  'information health care providers',
#  'nyc311 customer satisfaction survey',
#  'homeowners night',
#  'thanksgiving day',
#  'pay parking ticket online',
#  'homeless shelters',
#  'plumber license',
#  'animal odor',
#  'non residential building maintenance complaint',
#  'restaurant odor',
#  'health insurance children child health plus',
#  'access ride',
#  'idnyc benefits',
#  'service request status',
#  'financial counseling',
#  'city planning zoning',
#  'poison control center english',
#  'home improvement permit',
#  'affordable housing opportunities application information',
#  'special one time assistance sota tenants',
#  'city issued summons request hearing phone',
#  'legionnaires disease',
#  'apostille birth death certificate',
#  'certificate good conduct new york city resident',
#  'towing guide',
#  'paternity acknowledgment',
#  'sexually transmitted infection test',
#  'carbon monoxide',
#  'stop work orders',
#  'garbage disposal complaint',
#  'speed camera violation lookup status notice liability number plate number known',
#  'hud owned buildings',
#  'directory assistance',
#  'property tax exemption assistance',
#  'nursing home complaint',
#  'statue liberty visitor information',
#  'pay speed camera violation mobile app',
#  'sidewalk violation repair',
#  'musician performer permit',
#  'building permit status',
#  'electronics disposal',
#  'fight bus lane camera violation person',
#  'towed vehicle information',
#  'lien sale payment agreement property taxes related charges',
#  'sidewalk utility hardware complaint',
#  'street sign request',
#  'sidewalk repair protest',
#  'new york state tax information',
#  'credit debit card stuck parking meter',
#  'year round food cart vendor license apply',
#  'medicaid complaint',
#  'communicable diseases information reports',
#  'planned bridge highway tunnel street closures queens',
#  'ready rent free affordable housing application assistance',
#  'surrogate court brooklyn',
#  'hate crimes hotline',
#  'reclaim towed vehicle marshal sheriff',
#  'nyc agency commissioner senior staff information',
#  'pedestrian signal walk dont walk displaying',
#  'check cashing establishment complaint',
#  'letter incarceration',
#  'bankruptcy court',
#  'new york state business permit license',
#  'idnyc enrollment centers',
#  'property tax automatic payment banks website',
#  'motor vehicle registration license plates',
#  'adopt animal',
#  '211 information',
#  'summer overnight day camp license operation',
#  'manhole cover missing priority',
#  'chemical spill',
#  'postal service consumer hotline',
#  'head start',
#  'department consumer affairs online licensing service technical assistance',
#  'federal employer id number ein',
#  'benefit card account balance pin change',
#  'proof death',
#  'nopv market value request review',
#  'property tax payment plan',
#  'business tax refund',
#  'basement apartment conversion pilot program bacpp',
#  'building plan exam',
#  'passports',
#  'bicycle helmet distribution information',
#  'eviction prevention assistance legal services housing court',
#  'parking permit disability temporary vehicle change',
#  'dead animal highway evenings saturdays',
#  'storefront awning marquee canopy storm enclosure complaint',
#  'public assistance medicaid snap fraud',
#  'parole information violation manhattan staten island',
#  'garbage recycling organics collection',
#  'healthy homes',
#  'discrimination',
#  'radiation equipment permit apply',
#  'specialized high schools',
#  'developmentally delayed infant services',
#  'jury duty',
#  'garbage recycling storage complaint',
#  'food drug administration recall information',
#  'stolen vehicle',
#  'foster care agency complaint',
#  'nycha rent payment',
#  'youth services counseling youth connect',
#  'blocked sidewalk street',
#  'home delivered meals seniors request enrollment',
#  'block party street fair event permit',
#  'fight parking ticket person',
#  'housing court tenants landlords',
#  'find public hospital',
#  'dead animal street sidewalk priority',
#  'smoke alarm battery giveaway',
#  'lawyer referral',
#  'city comptroller complaint',
#  'pay phone complaint',
#  'nyc care',
#  'boiler inspection notice violation',
#  'status death certificate correction change',
#  'street sign complaint',
#  'abcs housing housing rules regulations nyc owners tenants',
#  'state court information',
#  'letter incarceration inmate former inmate',
#  'garbage recycling bins',
#  'car dealer complaint',
#  'paternity acknowledgment form',
#  'department finance reasonable accommodation people disabilities',
#  'fire hydrant running full',
#  'broadcast television rescan',
#  'property tax exemption application veterans',
#  'injured sick animal',
#  'dangerous animal',
#  'social security new york state supplement program ssp',
#  'car service driver complaint fare tip',
#  'snap food stamps find food stamp center',
#  'recycling bin sticker indoor green',
#  'fire hydrant open request non recreational use',
#  'cribs families need',
#  'bus lane camera violation payment problem penalty adjustment',
#  'illegal dumping tip form',
#  'pest control complaint apartment',
#  'basement apartment conversion pilot program spanish assistance',
#  'buy parking card online',
#  'pay speed camera violation paynearme',
#  'street line marking missing repaving',
#  'fire',
#  'metro north railroad',
#  'property value assessment',
#  'serving legal papers',
#  'building registration',
#  'labor day',
#  'find pre kindergarten program',
#  'federal tax',
#  'fight speed camera violation mail',
#  'food allergy poster',
#  'student transportation information',
#  'tax fraud evasion',
#  'immigration citizenship',
#  'parking ticket copy',
#  'medical transportation medicaid clients',
#  'working papers youth employment',
#  'tobacco retail dealer license',
#  'fight bus lane camera violation online',
#  'property deed record fraud',
#  'rent security deposits interest',
#  'passport information',
#  'sidewalk violation information',
#  'veterans property tax exemption',
#  'contact locate city marshal',
#  'disability access information city agency',
#  'biking rollerblading skating complaint',
#  'small claims court brooklyn',
#  'curb cut application brooklyn',
#  'alert information provided',
#  'bail information',
#  'catch basin cover missing priority',
#  'certificate conduct',
#  'new years holiday information',
#  'file claim city',
#  'stop unwanted mail',
#  'loose garbage',
#  'drag racing creating hazard progress',
#  'health insurance disabled apply medicaid low cost insurance',
#  'find police precinct psa location',
#  'nycha public housing section 8 landlords',
#  'outside 311 jurisdiction',
#  'healthy homes information',
#  'housing mentally ill homeless',
#  'planned water shutdowns',
#  'nyc well suicide crisis prevention',
#  'home health care information complaint',
#  'birth certificate puerto rico',
#  'utility hardware defect sidewalk',
#  'bulk item disposal information',
#  'property tax assistance exemption',
#  'street sweeping complaint',
#  'homeless outreach',
#  'street flooding',
#  'garage driveway permit',
#  'cross connection water backflow prevention',
#  'donate animal shelters',
#  'real property transfer tax',
#  'dumpster overflowing',
#  'streetlight wiring exposed priority',
#  'coat drive',
#  'job training',
#  'tenant harassment legal assistance',
#  'pest control',
#  'wecare services public assistance clients',
#  'living communities linc rent program landlords',
#  'inspection information food service establishments',
#  'status building permit manhattan',
#  'idnyc make appointment',
#  'criminal mischief',
#  'zoning information desk',
#  'unusable bicycle chained public property',
#  'death certificate',
#  'county clerk queens',
#  'access nyc',
#  'cfc freon removal appointment',
#  'mayor',
#  'cigarette sale complaint',
#  'city clerk online support',
#  'city contracts',
#  'garage parking lot complaint',
#  'lost stolen fair fares metrocard',
#  'department motor vehicles dmv',
#  'fair fares nyc',
#  'dangerous location situation',
#  'veterans day',
#  'criminal record',
#  'martin luther king jr day information',
#  'death certificate 1949 present',
#  'find arrested person',
#  'property tax automatic payment application cancellation',
#  'new car dealer complaint',
#  'cuny admissions services',
#  'cooling centers',
#  'visitor rules travel directions',
#  'lien sale',
#  'telemarketing call registry',
#  'automated water meter installation',
#  'fire hydrant leaning missing',
#  'unstable building',
#  'debt collection agency complaint',
#  'social security benefits application assistance',
#  'garbage recycling collection businesses',
#  'nyc jobs',
#  'check cashing business complaint',
#  'building violation status information brooklyn',
#  'property value appeal',
#  'elections voting',
#  'building water complaint',
#  'trees sidewalk repair 1 2 3 family residential property',
#  'animal abandoned pet',
#  'food protection course',
#  'flu shot prevention',
#  'animal vicious',
#  'department sanitation worker vehicle complaint',
#  'employment agency license',
#  'services intellectually developmentally disabled persons brooklyn',
#  'traveling abroad',
#  'suspicious package',
#  'housing used short term rental vacation rentals illegal home sharing',
#  'amtrak train information complaint',
#  'commercial vehicle parked residential driveway',
#  'idnyc documents required apply',
#  'minority woman owned business enterprise mwbe program',
#  'dead animal highway days sundays holidays',
#  'free credit report',
#  'raccoon control',
#  'harassment',
#  'senior centers',
#  'paid safe sick leave information sheet employees',
#  'medicare assistance',
#  'property tax exemption renewal application dhe',
#  'donate buy sell assistive medical devices',
#  'city agency commissioners mayors senior staff',
#  'parking ticket camera violation appeal',
#  'early intervention services developmentally delayed infants bronx',
#  'parking ticket lookup ticket plate number known',
#  'job center complaint',
#  'federal government jobs',
#  'special one time assistance sota tenant information',
#  'tow truck complaint street',
#  'trademarks patents',
#  'disorderly person creating hazard progress',
#  'bed bug complaint apartment hotel single room occupancy',
#  'investigate alcohol license',
#  'restaurant permit',
#  'adult probation supervision',
#  'find library brooklyn',
#  'parking ticket fine code explanation',
#  'water meter inspector check',
#  'hate crime',
#  'buildings information system',
#  'new jersey transit information complaint',
#  'restaurant deli food cart complaint',
#  'curb defect city owned',
#  'retail laundry license',
#  'sale minor complaint',
#  'telephone bill complaint',
#  'divorce record',
#  'broken sidewalk city owned',
#  'food allergies restaurants poster',
#  'road test scheduling',
#  'nyc radio television',
#  'parking ticket camera violation clearance',
#  'idnyc municipal id card',
#  'recycling violation',
#  'damage street utility work',
#  'toys tots',
#  'recycling rules metal',
#  'child care financial assistance center network unable assist complaint',
#  'new york city marathon',
#  'building violation status information queens',
#  'parking ticket dispute information',
#  'transit violation',
#  'disabled vehicle',
#  'special exit prevention supplement seps rent assistance program',
#  'ventilation exhaust system complaint',
#  'cfc freon removal',
#  'find sprinkler area park',
#  'alzheimers care',
#  'agency charges collected department finance',
#  'job training placement seniors',
#  'residential public area maintenance complaint',
#  'public charge rule',
#  'pet spaying neutering',
#  'lewd act',
#  'find workforce1 career center',
#  'bag garbage loose debris street',
#  'find community board name',
#  'annual boiler inspection',
#  'nyc coolroofs job training placement',
#  'private parochial schools',
#  'city state jury duty queens',
#  'metroplus health plan',
#  'gambling',
#  'recycling rules glass',
#  'civil service exam information',
#  'new york city housing lottery',
#  'alzheimers care information',
#  'become firefighter emergency medical technician emt paramedic',
#  'boiler inspection',
#  'tobacco retail dealer license apply',
#  'blind visually impaired people advice information',
#  'volunteer seniors',
#  'telecom equipment',
#  'manhole flooding',
#  'towed vehicle reclaim marshal sheriff',
#  'poison control center',
#  'staten island railway information complaint',
#  'snap food stamps benefits schedule',
#  'unauthorized cigarette sales',
#  'speed reducer request',
#  'truck commercial vehicle permit',
#  'city worker retiree benefits',
#  'blind low vision people advice information',
#  'eviction prevention assistance mentally physically impaired homebound senior',
#  'breaking park rules',
#  'report public housing nycha section 8 landlord tenant fraud',
#  'fight parking ticket mobile app',
#  'litter basket complaint overflowing',
#  'bulk item pick appointment cancellation rescheduling',
#  'co op condo complaint',
#  'workers compensation business helpline',
#  'services intellectually developmentally disabled persons bronx',
#  'health insurance children',
#  'port authority bus terminal information',
#  'lost item garbage',
#  'lincolns birthday information',
#  'cold water complaint odor taste',
#  'chimney ventilation smoke',
#  'raccoon control homeowners',
#  'landmark building complaint',
#  'excavation undermining nearby building priority',
#  'towed vehicle reclaim nypd',
#  'rent freeze program seniors',
#  'health insurance application assistance',
#  'chronically ill disabled children education information referrals',
#  'service requests',
#  'damaged malfunctioning fair fares metrocard',
#  'sprinklers',
#  'dispute sidewalk repair protest process',
#  'city state jury duty manhattan',
#  'unemployment insurance information',
#  'debt collection agency license renew status',
#  'disability access',
#  'pothole cave highway',
#  'ddc project inquiries complaints',
#  'property tax exemption renewal application sche',
#  'paternity test',
#  'dirty yard alley',
#  'motor vehicle disposal',
#  'indoor animal odor complaint residence',
#  'business tax information',
#  'nycha public housing application',
#  'snap food stamps complaint',
#  'property tax bill payment problem',
#  'year round food cart vendor permit renew status',
#  'safelink cell phone program',
#  'mini storage complaint',
#  'find public beach',
#  'individual corporation disputes 25000 dollars manhattan',
#  'building violation status information bronx',
#  'health department low cost confidential clinics',
#  'tow truck company license',
#  'cable phone internet service complaint',
#  'dumping catch basin',
#  'animal bite',
#  'inmate property pickup',
#  'state parking permit people disabilities',
#  'gas service billing',
#  'rent freeze program tenants disabilities',
#  'license verification skilled trades',
#  'rent information line',
#  'assisted living facility adult home complaint',
#  'administration childrens services case status',
#  'find consulate',
#  'dog license apply renew',
#  'carbon monoxide detector information',
#  'adult education program bronx',
#  'death inquiries',
#  'rent freeze program assistance',
#  'marriage ceremony',
#  'property tax payment plan application',
#  'pre kindergarten enrollment',
#  'learn swim',
#  'fdny violation',
#  'building ownership',
#  'parking ticket camera violation copy',
#  'mental health services seniors',
#  'city vehicle complaint',
#  'dead absentee landlord',
#  'water main break',
#  'car service company complaint fare tip',
#  'broken sidewalk',
#  'volunteer',
#  'events',
#  'tenant harassment assistance',
#  'animal stray found healthy small wildlife',
#  'disorderly person creating hazard past chronic',
#  'summer camp parks department',
#  'automated water meter transmitter box broken missing',
#  'health care provider assistance',
#  'recycling collection storm delays',
#  'buy hud owned building',
#  'employee paid safe sick leave information',
#  'city issued summons information',
#  'landmarks',
#  'gracie mansion halloween',
#  'open street excavation priority',
#  'building recycling area sign english spanish',
#  'crime victim assistance senior',
#  'lifeguard complaint',
#  'become nurse',
#  'planned bridge highway tunnel street closures bronx',
#  'dental services referrals insurance assistance',
#  'property record mortgage satisfaction',
#  'wall complaint',
#  'drag racing past chronic',
#  'find botanical garden',
#  'dispute mediation service manhattan',
#  'property lot size change',
#  'pay speed camera violation department finance business centers',
#  'staten island ferry lost found',
#  'street vendor complaint',
#  'cpr aed training fdny',
#  'used car dealer complaint',
#  'report sexual assault',
#  'adult education',
#  'department health clinic feedback',
#  'recycling signs stickers',
#  'immigration naturalization record',
#  'parking meter defective damaged',
#  'divorce separation brooklyn',
#  'ged tasc information',
#  'cable complaint',
#  'new years day',
#  'flooding street',
#  'immunization multiple individuals',
#  'parknyc user account assistance',
#  'water service shut request residential commercial property',
#  'citi bike maintenance customer service',
#  'irs impersonation',
#  'judge complaint',
#  'swimming lesson',
#  'new trash collection residential non profit',
#  'inmate health mental health complaints concerns',
#  'fair fares nyc card replacement',
#  'building floor plan copy queens',
#  'marriage license bronx',
#  'language access request complaint city agency',
#  'illegal conversion residential space',
#  'regents exam information',
#  'dirty sidewalk',
#  'foreclosure prevention information assistance',
#  'certificate occupancy letter objection manhattan',
#  'city worker nonresident tax form nyc 1127',
#  'rent increase information rent stabilized apartments lofts',
#  'parking camera violation advocate',
#  'ice roadway non storm condition',
#  'welder license',
#  'workers compensation',
#  'fight red light camera violation online',
#  'locksmith license',
#  'family justice center queens',
#  'smoke fumes',
#  'report discrimination',
#  'food protection course mobile vendors',
#  'new building structure unsafe priority',
#  'animal injured sick stray dog cat',
#  'eviction prevention assistance non payment rent',
#  'nopv public events',
#  'blindness low vision support',
#  'invite mayor event',
#  'recycle flyer english spanish',
#  'adult protective services complaint',
#  'bottle refund',
#  'dob',
#  'find barbecue area park',
#  'housing information guide notice',
#  'parking cards',
#  'fire hydrant flow test',
#  'find park',
#  'investigate business licensed department consumer affairs',
#  'temporary street fair vendor permit apply',
#  'auto repair complaint',
#  'divorce separation bronx',
#  'bulk item disposal',
#  'excavation demolition permit',
#  'voter registration',
#  'tennis permit',
#  'home schooling information',
#  'syringes sidewalk street',
#  'lost item sidewalk grating',
#  'chemical spill roadway sidewalk priority',
#  'commercial garbage disposal complaint',
#  'get federal employer id number ein',
#  'water complaint water private home commercial building',
#  'domestic partnership',
#  'expedited sidewalk repair program',
#  'child health clinics',
#  'verizon landline assistance',
#  'commercial rent tax',
#  'residential building owner resources',
#  'family justice centers',
#  'home care seniors',
#  'ambulance patient locator',
#  'recycling bin sticker indoor blue',
#  'organ tissue donation',
#  'locate firehouse bronx',
#  'fight parking ticket online',
#  'dumpster complaint',
#  'restaurant mobile food letter grading',
#  'child care financial assistance eligibility application person phone',
#  'parking ticket lookup ticket plate number unknown',
#  'recycling rules corrugated cardboard',
#  'streetlight fixture hanging priority',
#  'property tax exemption appeal',
#  'department citywide administrative services building security complaint',
#  'electrician plumber complaint',
#  'human trafficking',
#  'business tax assistance',
#  'higher education complaint',
#  'locate firehouse staten island',
#  'stoop line stand license apply',
#  'crime stoppers tip',
#  'fire hydrant running',
#  'bees wasps complaint',
#  'animal injured sick common bird small wildlife',
#  '3 day 10 day water notices',
#  'sidewalk guide property owners',
#  'daylight saving time',
#  'dna testing establish child parentage',
#  'civil marriage ceremony',
#  'county clerk bronx',
#  'sidewalk grating defect',
#  'sales tax information',
#  'tobacco retail dealer license renew status',
#  'financial education network money management workshop',
#  'alternate side parking calendar request',
#  'vehicle blocking driveway complaint',
#  'non driver id card',
#  'lewd acts complaint',
#  'car wash license',
#  'youth employment',
#  'idnyc request secondary review card denied',
#  'business courses',
#  'drug rehabilitation program complaint',
#  'police barricade request',
#  'summer camp department youth community development',
#  'mosquito spraying schedule',
#  'vacate order brooklyn',
#  'cold water complaint cloudy milky',
#  'heat complaint commercial building',
#  'parking camera violations refund form',
#  'property market value review',
#  'nycha section 8 voucher holder landlord information',
#  'home improvement salesperson license',
#  'worksite service information con edison',
#  'inmate location found city jail lookup',
#  'property tax payment deferral',
#  'property tax reduction co op condo units apply exemption',
#  'marriage registration',
#  'recycling rules paper',
#  'garbage truck spill',
#  'family court',
#  'idnyc complaints status questions',
#  'car service complaint',
#  'excelsior free tuition program cuny suny students',
#  'hot transfer 911',
#  'advisory restaurant inspection new restaurants',
#  'homeless shelter intake adult families',
#  'disabled homeowners exemption dhe renewal',
#  'public housing assistance status boroughs',
#  'nyc ferry',
#  'catch basin clogged blocked',
#  'idnyc complaints status inquiries',
#  'hiv test treatment',
#  'citizenship appointment',
#  'car service company complaint unauthorized operation',
#  'missing person',
#  'illegal eviction lockout',
#  'sales tax',
#  'bedbug annual report building owners',
#  'dob inspections',
#  'request sheriff serve legal papers',
#  'access hra information',
#  'building floor plan',
#  'nyc small business support center information',
#  'light parking lot complaint',
#  'rent assistance programs apartment registration landlords',
#  'property record notice recorded document information registration',
#  'business fine payment',
#  'rosh hashanah',
#  'verizon telephone pole wire complaint',
#  'prevailing wage complaint information',
#  'illegal dumping chronic',
#  'language assistance',
#  'sexual reproductive health',
#  'property tax exemption application status',
#  'citywide testing public schools',
#  'trespassing progress',
#  'snap food stamps apply person',
#  'rain garden',
#  'building unstable priority',
#  'homeless shelter complaint shelter client',
#  'cityfheps tenant assistance',
#  'measles outbreak brooklyn',
#  'parking ticket hearing appeal status',
#  'nyc condoms organization',
#  'blocked sidewalk sidewalk cafe',
#  'medicare card replacement',
#  'booted vehicle information',
#  'bike rack application',
#  'pay phone complaint street',
#  'property deed record',
#  'department buildings proof compliance correct ecb violation',
#  'safe sick leave complaint',
#  'crash barrier complaint',
#  'burial financial assistance',
#  'adult vaccination immunization',
#  'hiv aids services',
#  'new york state professional business license permit',
#  'catch basin sunken',
#  'press media inquiries',
#  'scaffolding permit',
#  'litter highway',
#  'gas station complaint',
#  'become teacher',
#  'towed vehicle',
#  'learning disabilities',
#  'child care financial assistance status submitted application',
#  'electronic cigarette retail dealer license',
#  'syringe sidewalk street',
#  'department consumer affairs online licensing service payment assistance',
#  'countnyc',
#  'nyc employee nonresident tax form nyc 1127',
#  'cold water complaint particles water',
#  'broken sidewalk 3 fewer residential units',
#  'case assistance management seniors',
#  'radiation equipment permit renew',
#  'illegal conversion commercial space',
#  'vehicle accident',
#  'hospital clinic complaint',
#  'sidewalk violation dismissal city fixed',
#  'hiicap counseling people eligible medicare',
#  'crime victim support',
#  'marriage license brooklyn',
#  'find event park',
#  'shred fest',
#  'public assistance medicaid supplemental nutrition assistance program snap fraud',
#  'bicycle rack application installed city',
#  'commercial rent tax assistance',
#  'public parking lots',
#  'property tax exemption initial application sche',
#  'alcohol sale complaint',
#  'long island rail road',
#  'building exit blocked priority',
#  'film television production complaint',
#  'illegal building conversion occupancy',
#  'blocked sidewalk advertising sign merchandise garbage',
#  'staten island railway',
#  'gas piping hookup complaint',
#  'pay property tax online',
#  'alcohol license check',
#  'irs impersonation scam',
#  'property tax assistance appeal denial removal reduction',
#  'vehicle disposal',
#  'street plate complaint',
#  'bench request',
#  'surrogate court manhattan',
#  'individual corporation disputes 25000 dollars brooklyn',
#  'chemical complaint',
#  'check status adoption subsidy assistance adoption',
#  'hotel contract complaint',
#  'pay property tax mail',
#  'find public parking lot',
#  'amtrak trains',
#  'fdny ambulance billing',
#  'dob build',
#  'department education employee benefits information',
#  'year round food cart vendor permit apply',
#  'lawyer complaint bronx manhattan',
#  'status birth certificate order',
#  'puerto rican day parade',
#  'free tax preparation person assistance',
#  'restaurant letter grading complaint',
#  'taxpayer advocate',
#  'yom kippur',
#  'report animal bite',
#  'disability access inadequate',
#  'letter exemplification death certificate',
#  'handgun permit',
#  'immigrant fraud',
#  'parking ticket payment problem penalty adjustment',
#  'apartment condition harassment',
#  'gas leak notice',
#  'new york police department nypd',
#  'domestic violence shelter complaint',
#  'sports field court permit',
#  'snap food stamps assistance people disabilities',
#  'cell phone complaint coverage',
#  'film video photography permit',
#  'immunization record request',
#  'fight speed camera violation person',
#  'literacy ged tasc instruction adults',
#  'arrested person location brooklyn',
#  'become poll worker',
#  'find police precinct psa name',
#  'order protection information',
#  'child abuse',
#  'service request status dot pothole street',
#  'department finance enrollment events',
#  'inmate location information',
#  'surrogate court queens',
#  'oil street one gallon priority',
#  'senior caregiving support',
#  'exchange refund return business',
#  'consumer affairs violation settlement',
#  'city state jury duty brooklyn',
#  'food cart vendor license permit',
#  'divorce separation',
#  'homeless shelter intake families children',
#  'census data',
#  'fire hydrant misuse',
#  'tax clearance certificate',
#  'workforce1 career centers',
#  'human rights education community outreach',
#  'truck route map',
#  'home instruction schooling',
#  'street vendor unlicensed operating prohibited area',
#  'service dog information',
#  'poll site voting equipment complaint',
#  'ecb violation buildings violation proof compliance',
#  'home sharing seniors',
#  'fourth july holiday',
#  'pay property tax person',
#  'lost seized pet',
#  'become foster parent adopt child',
#  'animal stray found kitten',
#  'park event permit',
#  'pool sauna hot tub steam room spray ground permit renew',
#  'non toll bridge complaint',
#  'property tax exemption non profits',
#  'alarm progress',
#  'memorial day information',
#  'street highway bridge tunnel closures',
#  'schedule plan examiner appointment',
#  'mitchell lama building information',
#  'home water assistance program',
#  'inmate medical concern',
#  'electronic disposal information',
#  'theft service',
#  'home tenant based rental assistance program tbra',
#  'fire ambulance report',
#  'water meter inquiries',
#  'street resurfacing request',
#  'department buildings id job penalization status',
#  'service request status dsny status found',
#  'vehicle accident report',
#  'voluntary placement child foster care',
#  'sports field court permit request',
#  'street highway sign installation removal relocation',
#  'business legal assistance',
#  'vacate order',
#  'dust',
#  'cuny citizenship',
#  'car rental complaint',
#  'measles information',
#  'living communities linc rent program clients',
#  'report domestic violence',
#  'pre operational health inspection restaurant',
#  'city hall tours',
#  'immigration help',
#  'nopv assessed value exemption tax class request appeal',
#  'landlord rent information public assistance',
#  'lawyer complaint brooklyn queens staten island',
#  'property tax exemption information',
#  'case management seniors',
#  'pedestrian ramp complaint',
#  'county clerk brooklyn',
#  'parking ticket camera violation payment',
#  'bail',
#  'insurance complaint',
#  'residential building owner assistance',
#  'organics collection single family homes',
#  'divorce separation manhattan',
#  'nopv property vacant land description request update',
#  'freelance workers hiring parties information assistance',
#  'nyc compost project',
#  'speed camera notice liability copy',
#  'volunteer parks',
#  'speed camera violation program information',
#  'parking ticket camera violation status',
#  'heap homebound individuals',
#  'start small business',
#  'parking sign fact sheet',
#  'immigrant services benefits',
#  'asian longhorned beetles',
#  'animal adoption',
#  'illegal gambling',
#  'homeless person need immediate attention',
#  'seized vehicle',
#  'fire code',
#  'department motor vehicles employee office complaint',
#  '2015 rent regulation laws',
#  'taxpayer advocate complaint',
#  'excavation undermining nearby building',
#  'carbon monoxide emission poisoning',
#  'cfc freon removal appointment confirmation tag number',
#  'garbage truck spillage',
#  'fdny certificates fitness',
#  'parenting support',
#  'wasting water',
#  'childrens services case status parents',
#  'seized vehicle auction',
#  'flu prevention',
#  'unlicensed plumber',
#  'recycling rules',
#  'linc program renewal client questions',
#  'employer paid safe sick leave information',
#  'food protection certificate status replacement',
#  'snap food stamps enrollment assistance seniors',
#  'idnyc reasonable accommodations home visits',
#  'temporary street fair vendor permit',
#  'electronics store complaint',
#  'reclaim towed vehicle nypd',
#  'libraries',
#  'fence complaint',
#  'commissioner deeds registration',
#  'furniture store complaint',
#  'con ed gas service inquiry',
#  'food women infants children wic',
#  'paid care worker employer assistance',
#  'electronic benefit transfer ebt card',
#  'summer camp childrens services recipients',
#  'fight parking ticket mail',
#  'find community board location',
#  'drug sale',
#  'fireworks displays',
#  'affordable housing',
#  'process server individual license',
#  'parking permit disability city application',
#  'garbage debris street',
#  'sale city owned real estate sales auctions',
#  'awning canopy marquee storm enclosure complaint',
#  'vehicle registration clearance',
#  'blocked sidewalk high grass weeds',
#  'property tax payment deferral low income seniors',
#  'city state jury duty bronx',
#  'eviction prevention assistance non payment rent mobile seniors',
#  'property record request tax map',
#  'broken sidewalk 4 residential units',
#  'washingtons birthday information',
#  'overcharge',
#  'communicable diseases',
#  'water pressure temperature complaint',
#  'recycling rules plastic',
#  'home improvement contractor license renew status',
#  'aids hiv assistance',
#  'fire hydrant request',
#  'federal tax assistance businesses irs',
#  'financial empowerment center',
#  'worldpride nyc',
#  'birth certificate change',
#  'seasonal food cart vendor license apply',
#  'advisory restaurant inspection existing restaurant',
#  'paid safe sick leave',
#  'property record update owner information residential commercial property',
#  'early intervention services developmentally delayed infants manhattan',
#  'ambulance billing fdny',
#  ...}

# %%
values_to_remove_drinking = ['illness caused by drinking wat','drinking wat','drinking water inform']
# Remove the values for key 'drinking'
mapping['drinking'] = [value for value in mapping['drinking'] if value not in values_to_remove_drinking]
mapping['water quality'] += values_to_remove_drinking

# %%
set(complaints_final)-set(list(mapping.keys()))
# Out:
# {'adopt basket',
#  'best site safety',
#  'bike rack condition',
#  'bike roller skate chronic',
#  'boilers',
#  'broken parking meter',
#  'building marshals office',
#  'building use',
#  'bulky item',
#  'consumer complaint',
#  'cranes derricks',
#  'department finance parking payment issue',
#  'department finance property owner issue',
#  'department finance property payment issue',
#  'department finance property reduction issue',
#  'department finance property update account',
#  'derelict bicycle',
#  'dirty conditions',
#  'door window',
#  'emergency response team ert',
#  'executive inspections',
#  'facades',
#  'ferry inquiry',
#  'flooring stairs',
#  'forms',
#  'found property',
#  'general construction plumbing',
#  'harboring bees wasps',
#  'highway condition',
#  'hire vehicle complaint',
#  'hire vehicle report',
#  'investigations discipline iad',
#  'maintenance facility',
#  'mobile food vendor',
#  'non emergency police matter',
#  'overflowing litter baskets',
#  'overgrown tree branches',
#  'paint plaster',
#  'pet shop',
#  'posting advertisement',
#  'public payphone complaint',
#  'question',
#  'recycling enforcement',
#  'sanitation condition',
#  'sidewalk condition',
#  'special natural area district snad',
#  'special operations',
#  'special projects inspection team spit',
#  'street light condition',
#  'sustainability enforcement',
#  'sweeping missed',
#  'traffic signal condition',
#  'unsanitary animal pvt property',
#  'unsanitary condition',
#  'unsanitary pigeon condition',
#  'violation park rule',
#  'water conservation',
#  'water system'}

# %%
def map_leftovers(syns_dict, unmapped_ls):
    leftovers_mapped = {}
    for key, values in syns_dict.items():
        for value in values:
            for i in range(len(unmapped_ls)):
                words = unmapped_ls[i].split()
                if value in words:
                    if key not in leftovers_mapped:
                        leftovers_mapped[key] = []
                    leftovers_mapped[key].append(unmapped_ls[i])
    for key, values in leftovers_mapped.items():
        for value in values:
            if value in unmapped_ls:
                unmapped_ls.remove(value)
    return leftovers_mapped, unmapped_ls

# %%
# leftovers_mapped = {}
unmapped_callcomps_copy = unmapped_callcomps
syns_dict = {'adopt basket': ['adopt a basket', 'adopt-a-basket'],
           'best site safety': ['site safety'],
           'bike rack condition': ['bike rack'],
           'boilers': ['boiler'],
             'waste': ['dumpster overflowing','dumpster','trash'],
            'sewer': ['catch basin'],
           'broken parking meter': ['parking meter'],
           'bulky item': ['bulky', 'large item','bulk'],
           'dep street condition': ['street condition','street conditions','highway conditions','highway condition'],
           'derelict bicycle': ['abandoned bike','abandoned bicycle','derelict bike'],
           'dirty conditions': ['unsanitary condition','unsanitary conditions','dirty condition'],
           'door window': ['door','window'],
           'emergency response team ert': ['emergeny response'],
           'executive inspections': ['inspections'],
           'facades': ['building facade','facade'],
           'ferry inquiry': ['ferry'],
           'flooring stairs': ['flooring','stairs'],
           'forms': ['form','paperwork','paper work','application'],
           'found property': ['lost and found'],
           'general construction plumbing': ['plumbing'],
           'harboring bees wasps': ['bees','wasp','bee','wasps'],
           'highway condition': ['highway'],
           'hire vehicle complaint': ['taxi','hire vehicle','hire vehicles'],
           'hire vehicle report': ['taxi','hire vehicle','hire vehicles'],
           'hpd literature request': ['literature request'],
           'missed collection materials': ['missed collection', 'miss trash','missed trash','missed waste'],
           'mobile food vendor': ['food vendor','food vending'],
           'non emergency police matter': ['police'],
           'homeless encampment': ['homeless','encampment','encamp','homelessness'],
             'drug activity': ['drug','drugs'],
           'overflowing litter baskets': ['litter baskets'],
           'overgrown tree branches': ['tree'],
           'public payphone complaint': ['payphone'],
           'question': ['general inquiry'],
           'recycling enforcement': ['recycling'],
           'sanitation condition': ['sanitation'],
           'sidewalk condition': ['sidewalk','curb'],
           'street light condition': ['street light','streetlight', 'lamp post','lamppost'],
           'sweeping missed': ['street cleaning missed', 'missed street cleaning','missed sweeping'],
           'traffic signal condition': ['traffic light','traffic signal'],
           'unsanitary animal pvt property': ['unsanitary'],
           'unsanitary condition': ['unsanitary'],
           'unsanitary pigeon condition': ['unsanitary'],
           'violation park rule': ['park rule violation','park rule','park violation'],
          }

leftovers_mapped, unmapped = map_leftovers(syns_dict, unmapped_callcomps_copy)

# %%
leftovers_mapped
# Out:
# {'boilers': ['boiler defective without permit',
#   'boiler inspection notice violation',
#   'annual boiler inspection',
#   'boiler inspection',
#   'boiler permits registration',
#   'boiler inspection violation',
#   'boiler complaint',
#   'boiler registration'],
#  'waste': ['dumpster overflowing',
#   'dumpster complaint',
#   'blocked street garbage merchandise dumpster trash',
#   'dumpster debris container permit',
#   'dumpster permit',
#   'new trash collection residential non profit',
#   'loose trash',
#   'blocked street garbage merchandise dumpster trash',
#   'improper trash disposal',
#   'recycling trash collection schedules',
#   'lost item trash',
#   'improper trash disposal uncovered partially covered mattress box spring'],
#  'bulky item': ['bulk item pick appointment',
#   'bulk item disposal information',
#   'bulk item pick appointment cancellation rescheduling',
#   'bulk item disposal',
#   'bulk item pick appointment status',
#   'department sanitation literature bulk order'],
#  'door window': ['window guard',
#   'window guard complaint',
#   'window guard information',
#   'window guard apartment complaint tenant'],
#  'executive inspections': ['dob inspections'],
#  'ferry inquiry': ['staten island ferry information statistics',
#   'staten island ferry lost found',
#   'nyc ferry',
#   'nyc ferry service',
#   'new york waterway ferry',
#   'staten island ferry',
#   'staten island ferry schedule'],
#  'forms': ['paternity acknowledgment form',
#   'illegal dumping tip form',
#   'city worker nonresident tax form nyc 1127',
#   'parking camera violations refund form',
#   'nyc employee nonresident tax form nyc 1127',
#   'immigration application form',
#   'affordable housing opportunities application information',
#   'ready rent free affordable housing application assistance',
#   'property tax exemption application veterans',
#   'curb cut application brooklyn',
#   'property tax automatic payment application cancellation',
#   'social security benefits application assistance',
#   'property tax exemption renewal application dhe',
#   'health insurance application assistance',
#   'property tax exemption renewal application sche',
#   'nycha public housing application',
#   'property tax payment plan application',
#   'child care financial assistance eligibility application person phone',
#   'property tax exemption application status',
#   'bike rack application',
#   'child care financial assistance status submitted application',
#   'bicycle rack application installed city',
#   'property tax exemption initial application sche',
#   'parking permit disability city application',
#   'parking permit municipal parking lot garage long term application',
#   'property tax exemption application clergy',
#   'child care financial assistance eligibility information application mail',
#   'tennis permit application status',
#   'social security card application replacement',
#   'public housing application information assistance',
#   'health insurance application assistance getcoverednyc',
#   'property tax exemption initial application dhe',
#   'property tax exemption profit nfp organizations initial application',
#   'immigration application form',
#   'nycha section 8 application information',
#   'child care financial assistance eligibility application online',
#   'parking permit disability state application'],
#  'harboring bees wasps': ['bees wasps complaint',
#   'bees wasps complaint private commercial property',
#   'bees wasps complaint',
#   'bees wasps complaint private commercial property'],
#  'highway condition': ['planned bridge highway tunnel street closures queens',
#   'dead animal highway evenings saturdays',
#   'dead animal highway days sundays holidays',
#   'pothole cave highway',
#   'planned bridge highway tunnel street closures bronx',
#   'litter highway',
#   'street highway bridge tunnel closures',
#   'street highway sign installation removal relocation',
#   'highway sign complaint',
#   'disabled vehicle highway',
#   'cave highway',
#   'pothole highway',
#   'planned bridge highway tunnel street closures brooklyn',
#   'planned bridge highway tunnel street closures staten island',
#   'planned bridge highway tunnel street closures manhattan'],
#  'non emergency police matter': ['police precincts psas',
#   'police report request',
#   'find police precinct psa location',
#   'police barricade request',
#   'new york police department nypd',
#   'find police precinct psa name',
#   'become police officer',
#   'police report',
#   'police officer misconduct',
#   'police officer serious misconduct corruption',
#   'police officer complaint'],
#  'homeless encampment': ['homeless shelters',
#   'housing mentally ill homeless',
#   'homeless outreach',
#   'homeless shelter intake adult families',
#   'homeless shelter complaint shelter client',
#   'homeless shelter intake families children',
#   'homeless person need immediate attention',
#   'homeless person family contact',
#   'homeless shelter intake single adults',
#   'runaway homeless youth shelter support',
#   'homeless drop centers',
#   'homeless shelter complaint',
#   'contact homeless individual family',
#   'family homelessness eviction prevention supplement fheps',
#   'homelessness prevention homebase'],
#  'drug activity': ['drug use',
#   'food drug administration recall information',
#   'drug rehabilitation program complaint',
#   'drug sale',
#   'drug alcohol treatment',
#   'nyc well drug treatment heroin pain relievers drugs',
#   'nyc well drug treatment heroin pain relievers drugs'],
#  'recycling enforcement': ['garbage recycling organics collection',
#   'garbage recycling storage complaint',
#   'garbage recycling bins',
#   'recycling bin sticker indoor green',
#   'garbage recycling collection businesses',
#   'recycling violation',
#   'recycling rules metal',
#   'recycling rules glass',
#   'recycling collection storm delays',
#   'building recycling area sign english spanish',
#   'recycling signs stickers',
#   'recycling bin sticker indoor blue',
#   'recycling rules corrugated cardboard',
#   'recycling rules paper',
#   'recycling rules',
#   'recycling rules plastic',
#   'recycling bin sticker outdoor green',
#   'recycling trash collection schedules',
#   'garbage recycling bin',
#   'recycling bin sticker outdoor blue',
#   'garbage recycling storage complaint residential building',
#   'plastic bag recycling'],
#  'sanitation condition': ['sanitation sign request',
#   'department sanitation worker vehicle complaint',
#   'department sanitation public outreach',
#   'department sanitation vehicle accident',
#   'sanitation complaint private carter',
#   'sanitation vehicle accident',
#   'department sanitation literature bulk order'],
#  'sidewalk condition': ['broken sidewalk commercial property',
#   'blocked sidewalk street basketball hoop personal property',
#   'sidewalk violation repair',
#   'sidewalk utility hardware complaint',
#   'sidewalk repair protest',
#   'blocked sidewalk street',
#   'dead animal street sidewalk priority',
#   'sidewalk violation information',
#   'utility hardware defect sidewalk',
#   'trees sidewalk repair 1 2 3 family residential property',
#   'broken sidewalk city owned',
#   'dispute sidewalk repair protest process',
#   'broken sidewalk',
#   'dirty sidewalk',
#   'syringes sidewalk street',
#   'lost item sidewalk grating',
#   'chemical spill roadway sidewalk priority',
#   'expedited sidewalk repair program',
#   'sidewalk guide property owners',
#   'sidewalk grating defect',
#   'blocked sidewalk sidewalk cafe',
#   'syringe sidewalk street',
#   'broken sidewalk 3 fewer residential units',
#   'sidewalk violation dismissal city fixed',
#   'blocked sidewalk advertising sign merchandise garbage',
#   'blocked sidewalk high grass weeds',
#   'broken sidewalk 4 residential units',
#   'lost article sidewalk grating',
#   'sidewalk violation dismissal property owner fixed',
#   'broken sidewalk information property owners',
#   'street sidewalk marking',
#   'dispute new sidewalk violation reinspection request',
#   'sidewalk cafe license',
#   'sidewalk violation search',
#   'sidewalk cafe license renew status',
#   'sidewalk repair payment plan',
#   'sidewalk cleaning',
#   'curb cut application brooklyn',
#   'curb defect city owned',
#   'curb defect 3 fewer residential units',
#   'curb defect commercial property',
#   'curb complaint',
#   'curb defect metal bar protruding',
#   'curb cut permit',
#   'catch basin curb piece missing',
#   'driveway curb cut complaint'],
#  'street light condition': ['streetlight wiring exposed priority',
#   'streetlight fixture hanging priority',
#   'streetlight pole priority',
#   'streetlight request',
#   'streetlight condition',
#   'streetlight complaint',
#   'service request status dot streetlight',
#   'streetlight installation removal relocation']}

# %%
len(set(unmapped))
# Out:
# 1724

# %%
mapping_final = {}

# combine values for overlapping keys
for key in mapping.keys() & leftovers_mapped.keys():
    mapping_final[key] = mapping[key] + leftovers_mapped[key]

# add remaining keys from dict1
for key in mapping.keys() - leftovers_mapped.keys():
    mapping_final[key] = mapping[key]

# add remaining keys from dict2
for key in leftovers_mapped.keys() - mapping.keys():
    mapping_final[key] = leftovers_mapped[key]

print(mapping_final)
# Out:
# {'drug activity': ['drug activity use progress', 'drug activity use inside progress', 'drug activity use sale outside progress', 'drug activity sale indoor progress', 'drug activity sale progress', 'drug use', 'food drug administration recall information', 'drug rehabilitation program complaint', 'drug sale', 'drug alcohol treatment', 'nyc well drug treatment heroin pain relievers drugs', 'nyc well drug treatment heroin pain relievers drugs'], 'homeless encampment': ['homeless encampment', 'homeless chronic encampment', 'homeless shelters', 'housing mentally ill homeless', 'homeless outreach', 'homeless shelter intake adult families', 'homeless shelter complaint shelter client', 'homeless shelter intake families children', 'homeless person need immediate attention', 'homeless person family contact', 'homeless shelter intake single adults', 'runaway homeless youth shelter support', 'homeless drop centers', 'homeless shelter complaint', 'contact homeless individual family', 'family homelessness eviction prevention supplement fheps', 'homelessness prevention homebase'], 'waste': ['special waste disposal', 'e waste pickup appointment cancellation status rescheduling', 'special waste disposal locations rules', 'commercial waste private carters information', 'commercial waste disposal', 'dog waste street sidewalk adjoining area', 'dog animal waste private property', 'dog animal waste', 'e waste pickup appointment', 'medical waste disposal', 'dumpster overflowing', 'dumpster complaint', 'blocked street garbage merchandise dumpster trash', 'dumpster debris container permit', 'dumpster permit', 'new trash collection residential non profit', 'loose trash', 'blocked street garbage merchandise dumpster trash', 'improper trash disposal', 'recycling trash collection schedules', 'lost item trash', 'improper trash disposal uncovered partially covered mattress box spring'], 'illegal fireworks': ['illegal fireworks progress'], 'taxi': ['taxi lost found', 'taxi complaint route complaint', 'lost property taxi medallion number found 311', 'green boro taxi complaint pick refused', 'taxi hire vehicle congestion surcharge', 'taxi complaint unsafe driving observed non passenger', 'taxi driver complaint accessible taxi passenger', 'yellow taxi fare information', 'yellow green taxi receipt copy', 'lost property green taxi license number unknown', 'taxi driver licensee assistance', 'yellow taxi insurance information request non passenger', 'lost property green taxi license number known', 'taxi receipt copy', 'taxi limousine commission website', 'lost property taxi medallion number known', 'wheelchair accessible taxi dispatch', 'taxi complaint broken missing equipment', 'taxi driver license', 'found property taxi', 'taxi complaint unsafe driving observed passenger', 'accessible taxi dispatch', 'yellow taxi insurance information request passenger', 'green boro taxi complaint rude discourteous', 'lost property taxi medallion number unknown', 'taxi complaint rude discourteous', 'taxi complaint', 'taxi complaint credit card fare tip complaint', 'accessible taxi dispatch passenger wheelchair', 'taxi car service insurance information', 'taxi limousine commissions website', 'taxi complaint fare e zpass tip complaint', 'taxi complaint pick refused', 'taxi inquiry complaint taxi driver taxi licensee'], 'senior citizen rent increase': ['senior citizen rent increase exemption new landlord building manager', 'senior citizen rent increase exemption initial application phone assistance', 'senior citizen rent increase exemption certification senior citizen rent increase exemption renewal without renewal lease', 'senior citizen rent increase exemption assistance senior participant', 'senior citizen rent increase exemption submit updated contact information new lease', 'senior citizen rent increase exemption ombudsperson assistance', 'senior citizen rent increase exemption assistance landlord', 'senior citizen rent increase exemption move death', 'senior citizen rent incr ...

# %%
len(set(complaints_final)-set(list(mapping_final.keys())))
# Out:
# 45

# %%
len(set(complaints_final))
# Out:
# 149

# %%
## Map our dictionaries to the complaint_type_filtered dataframe
complaint_type_filtered['subcat_processed'] = complaint_type_filtered['subcat'].map(processed_comps)
# complaint_type_filtered['callcomp_subcat'] = complaint_type_filtered['subcat_processed'].map(mapping_final)
complaint_type_filtered.head()
# Out:
#                            subcat  count               subcat_processed
# 44                      APPLIANCE  10211                      appliance
# 45              Abandoned Vehicle  24179              abandoned vehicle
# 46                 Adopt-A-Basket    215                   adopt basket
# 56  Advocate-Prop Refunds/Credits    170  advocate prop refunds credits
# 59                    Air Quality   8047                    air quality

# %%
call_comps['subcat_processed'] = call_comps['subcat'].map(processed_callcomps)
call_comps.head(20)
# Out:
#     count                                                cat
# 0   84545                              Department of Finance  \
# 1   76516                                  3-1-1 Call Center
# 2   60523                              Department of Finance
# 3   57674                                                NaN
# 4   57213                                                NaN
# 5   55351                                                NaN
# 6   55032                                                NaN
# 7   54232                                                NaN
# 8   52887                                                NaN
# 9   52218                                                NaN
# 10  50157                    New York City Police Department
# 11  50016  Department of Housing Preservation and Develop...
# 12  49176                    New York City Police Department
# 13  47190                              Department of Finance
# 14  46995                           Department of Sanitation
# 15  46408                                                NaN
# 16  45637                                                NaN
# 17  39599                                  3-1-1 Call Center
# 18  39496  Department of Housing Preservation and Develop...
# 19  38371                                                NaN
#
#                                                subcat
# 0   Parking Ticket Lookup - Ticket or Plate Number...  \
# 1                    Service Request Status - General
# 2   Property Tax Account Assistance and Bill Infor...
# 3                                  Bulk Item Disposal
# 4   Heat or Hot Water Complaint in a Residential B...
# 5                                 Noise from Neighbor
# 6                                    Blocked Driveway
# 7           Parking Ticket or Camera Violation Status
# 8                              Service Request Status
# 9                     Apartment Maintenance Complaint
# 10                                Noise from Neighbor
# 11                    Apartment Maintenance Complaint
# 12                Vehicle Blocking Driveway Complaint
# 13          Find a Towed Vehicle - Plate Number Known
# 14                    Bulk Item Pick Up - Appointment
# 15                            Birth Certificate Order
# 16  Missed Garbage, Recycling, or Organics Collection
# 17      City Worker or Agency Complaint or Compliment
# 18  Heat or Hot Water Complaint in Entire Resident...
# 19                                    Illegal Parking
#
#                                             subsubcat
# 0   Status of a parking ticket. Must know ticket o...  \
# 1     Status of most Service Requests filed with 311.
# 2   Help with questions about the property tax bil...
# 3   Learn how to get rid of bulk items. Schedule, ...
# 4   Report a problem with heat or hot water in a r...
# 5                            Report a noisy neighbor.
# 6    Report a vehicle that is blocking your driveway.
# 7   Look up information about your parking or came...
# 8   Check the status of a Service Request filed wi...
# 9   Report a maintenance problem in a privately-ow...
# 10                           Report a noisy neighbor.
# 11  Report a maintenance problem inside an apartment.
# 12      Report a vehicle that is blocking a driveway.
# 13  Location of a vehicle that may have been towed...
# 14  Schedule pickup appointment for non-recyclable...
# 15                 Get a copy of a birth certificate.
# 16  Report that garbage, recycling, organics, or b...
# 17  Complaint or compliment about a City agency or...
# 18  Report inadequate heat in an apartment buildin...
# 19  Report a non-emergency vehicle parked illegall...
#
#                                         combined_cats
# 0   Department of Finance Parking Ticket Lookup - ...  \
# 1   3-1-1 Call Center Service Request Status - Gen...
# 2   Department of Finance Property Tax Account Ass...
# 3    Bulk Item Disposal Learn how to get rid of bu...
# 4    Heat or Hot Water Complaint in a Residential ...
# 5        Noise from Neighbor Report a noisy neighbor.
# 6    Blocked Driveway Report a vehicle that is blo...
# 7    Parking Ticket or Camera Violation Status Loo...
# 8    Service Request Status Check the status of a ...
# 9    Apartment Maintenance Complaint Report a main...
# 10  New York City Police Department Noise from Nei...
# 11  Department of Housing Preservation and Develop...
# 12  New York City Police Department Vehicle Blocki...
# 13  Department of Finance Find a Towed Vehicle - P...
# 14  Department of Sanitation Bulk Item Pick Up - A...
# 15   Birth Certificate Order Get a copy of a birth...
# 16   Missed Garbage, Recycling, or Organics Collec...
# 17  3-1-1 Call Center City Worker or Agency Compla...
# 18  Department of Housing Preservation and Develop...
# 19   Illegal Parking Report a non-emergency vehicl...
#
#                                   combined_cats_lower
# 0   department of finance parking ticket lookup - ...  \
# 1   3-1-1 call center service request status - gen...
# 2   department of finance property tax account ass...
# 3    bulk item disposal learn how to get rid of bu...
# 4    heat or hot water complaint in a residential ...
# 5        noise from neighbor report a noisy neighbor.
# 6    blocked driveway report a vehicle that is blo...
# 7    parking ticket or camera violation status loo...
# 8    service request status check the status of a ...
# 9    apartment maintenance complaint report a main...
# 10  new york city police department noise from nei...
# 11  department of housing preservation and develop...
# 12  new york city police department vehicle blocki...
# 13  department of finance find a towed vehicle - p...
# 14  department of sanitation bulk item pick up - a...
# 15   birth certificate order get a copy of a birth...
# 16   missed garbage, recycling, or organics collec...
# 17  3-1-1 call center city worker or agency compla...
# 18  department of housing preservation and develop...
# 19   illegal parking report a non-emergency vehicl...
#
#                                       processed_comps
# 0   department finance parking vehicles ticket loo...  \
# 1   call center service request status general sta...
# 2   department finance property building tax accou...
# 3   bulk item disposal learn get rid bulk items sc...
# 4   heat hot water complaint residential building ...
# 5                noise neighbor report noisy neighbor
# 6   blocked driveway report vehicle blocking driveway
# 7   parking vehicles ticket camera violation statu...
# 8   service request status check status service re...
# 9   apartment maintenance complaint report mainten...
# 10  new york city police department noise neighbor...
# 11  department housing preservation development ap...
# 12  new york city police department vehicle blocki...
# 13  department finance find towed vehicle plate nu...
# 14  department sanitation waste bulk item pick app...
# 15  birth certificate order get copy birth certifi...
# 16  missed garbage, recycling, organics collection...
# 17  call center city worker agency complaint comme...
# 18  department housing preservation development he...
# 19  illegal parking vehicles report nonemergency v...
#
#                                      sentiment_scores    neg    neu    pos
# 0   {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'comp...  0.000  0.874  0.126  \
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 2   {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...  0.000  0.876  0.124
# 3   {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'comp...  0.111  0.889  0.000
# 4   {'neg': 0.308, 'neu': 0.692, 'pos': 0.0, 'comp...  0.308  0.692  0.000
# 5   {'neg': 0.298, 'neu': 0.702, 'pos': 0.0, 'comp...  0.298  0.702  0.000
# 6   {'neg': 0.54, 'neu': 0.46, 'pos': 0.0, 'compou...  0.540  0.460  0.000
# 7   {'neg': 0.399, 'neu': 0.601, 'pos': 0.0, 'comp...  0.399  0.601  0.000
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 9   {'neg': 0.412, 'neu': 0.588, 'pos': 0.0, 'comp...  0.412  0.588  0.000
# 10  {'neg': 0.159, 'neu': 0.841, 'pos': 0.0, 'comp...  0.159  0.841  0.000
# 11  {'neg': 0.329, 'neu': 0.671, 'pos': 0.0, 'comp...  0.329  0.671  0.000
# 12  {'neg': 0.425, 'neu': 0.575, 'pos': 0.0, 'comp...  0.425  0.575  0.000
# 13  {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'comp...  0.000  0.852  0.148
# 14  {'neg': 0.157, 'neu': 0.843, 'pos': 0.0, 'comp...  0.157  0.843  0.000
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 16  {'neg': 0.128, 'neu': 0.872, 'pos': 0.0, 'comp...  0.128  0.872  0.000
# 17  {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'comp...  0.286  0.714  0.000
# 18  {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'comp...  0.197  0.803  0.000
# 19  {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'comp...  0.231  0.769  0.000
#
#     compound                                   subcat_processed
# 0     0.1531    parking ticket lookup ticket plate number known
# 1     0.0000                     service request status general
# 2     0.4019   property tax account assistance bill information
# 3    -0.2500                                 bulk item disposal
# 4    -0.5994      heat hot water complaint residential building
# 5    -0.1779                                     noise neighbor
# 6    -0.5719                                   blocked driveway
# 7    -0.8519             parking ticket camera violation status
# 8     0.0000                             service request status
# 9    -0.5994                    apartment maintenance complaint
# 10   -0.1779                                     noise neighbor
# 11   -0.5994                    apartment maintenance complaint
# 12   -0.7506                vehicle blocking driveway complaint
# 13    0.1531              find towed vehicle plate number known
# 14   -0.4215                         bulk item pick appointment
# 15    0.0000                            birth certificate order
# 16   -0.2960       missed garbage recycling organics collection
# 17   -0.5267            city worker agency complaint compliment
# 18   -0.5994  heat hot water complaint entire residential bu...
# 19   -0.5574                                    illegal parking

# %%
calls_to_servreq = {}
for key, values in mapping_final.items():
    for value in values:
        calls_to_servreq[value] = key

print(calls_to_servreq)
# Out:
# {'drug activity use progress': 'drug activity', 'drug activity use inside progress': 'drug activity', 'drug activity use sale outside progress': 'drug activity', 'drug activity sale indoor progress': 'drug activity', 'drug activity sale progress': 'drug activity', 'drug use': 'drug activity', 'food drug administration recall information': 'drug activity', 'drug rehabilitation program complaint': 'drug activity', 'drug sale': 'drug activity', 'drug alcohol treatment': 'drug activity', 'nyc well drug treatment heroin pain relievers drugs': 'drug activity', 'homeless encampment': 'homeless encampment', 'homeless chronic encampment': 'homeless encampment', 'homeless shelters': 'homeless encampment', 'housing mentally ill homeless': 'homeless encampment', 'homeless outreach': 'homeless encampment', 'homeless shelter intake adult families': 'homeless encampment', 'homeless shelter complaint shelter client': 'homeless encampment', 'homeless shelter intake families children': 'homeless encampment', 'homeless person need immediate attention': 'homeless encampment', 'homeless person family contact': 'homeless encampment', 'homeless shelter intake single adults': 'homeless encampment', 'runaway homeless youth shelter support': 'homeless encampment', 'homeless drop centers': 'homeless encampment', 'homeless shelter complaint': 'homeless encampment', 'contact homeless individual family': 'homeless encampment', 'family homelessness eviction prevention supplement fheps': 'homeless encampment', 'homelessness prevention homebase': 'homeless encampment', 'special waste disposal': 'waste', 'e waste pickup appointment cancellation status rescheduling': 'waste', 'special waste disposal locations rules': 'waste', 'commercial waste private carters information': 'waste', 'commercial waste disposal': 'waste', 'dog waste street sidewalk adjoining area': 'waste', 'dog animal waste private property': 'waste', 'dog animal waste': 'waste', 'e waste pickup appointment': 'waste', 'medical waste disposal': 'waste', 'dumpster overflowing': 'waste', 'dumpster complaint': 'waste', 'blocked street garbage merchandise dumpster trash': 'waste', 'dumpster debris container permit': 'waste', 'dumpster permit': 'waste', 'new trash collection residential non profit': 'waste', 'loose trash': 'waste', 'improper trash disposal': 'waste', 'recycling trash collection schedules': 'recycling enforcement', 'lost item trash': 'waste', 'improper trash disposal uncovered partially covered mattress box spring': 'waste', 'illegal fireworks progress': 'illegal fireworks', 'taxi lost found': 'taxi', 'taxi complaint route complaint': 'taxi', 'lost property taxi medallion number found 311': 'taxi', 'green boro taxi complaint pick refused': 'taxi', 'taxi hire vehicle congestion surcharge': 'taxi', 'taxi complaint unsafe driving observed non passenger': 'taxi', 'taxi driver complaint accessible taxi passenger': 'taxi', 'yellow taxi fare information': 'taxi', 'yellow green taxi receipt copy': 'taxi', 'lost property green taxi license number unknown': 'taxi', 'taxi driver licensee assistance': 'taxi', 'yellow taxi insurance information request non passenger': 'taxi', 'lost property green taxi license number known': 'taxi', 'taxi receipt copy': 'taxi', 'taxi limousine commission website': 'taxi', 'lost property taxi medallion number known': 'taxi', 'wheelchair accessible taxi dispatch': 'taxi', 'taxi complaint broken missing equipment': 'taxi', 'taxi driver license': 'taxi', 'found property taxi': 'taxi', 'taxi complaint unsafe driving observed passenger': 'taxi', 'accessible taxi dispatch': 'taxi', 'yellow taxi insurance information request passenger': 'taxi', 'green boro taxi complaint rude discourteous': 'taxi', 'lost property taxi medallion number unknown': 'taxi', 'taxi complaint rude discourteous': 'taxi', 'taxi complaint': 'taxi', 'taxi complaint credit card fare tip complaint': 'taxi', 'accessible taxi dispatch passenger wheelchair': 'taxi', 'taxi car service insurance information':  ...

# %%
len(calls_to_servreq.keys())
# Out:
# 778

# %%
call_comps['subcat_servreq'] = call_comps['subcat_processed'].map(calls_to_servreq)

# %%
call_comps.head()
# Out:
#    count                    cat
# 0  84545  Department of Finance  \
# 1  76516      3-1-1 Call Center
# 2  60523  Department of Finance
# 3  57674                    NaN
# 4  57213                    NaN
#
#                                               subcat
# 0  Parking Ticket Lookup - Ticket or Plate Number...  \
# 1                   Service Request Status - General
# 2  Property Tax Account Assistance and Bill Infor...
# 3                                 Bulk Item Disposal
# 4  Heat or Hot Water Complaint in a Residential B...
#
#                                            subsubcat
# 0  Status of a parking ticket. Must know ticket o...  \
# 1    Status of most Service Requests filed with 311.
# 2  Help with questions about the property tax bil...
# 3  Learn how to get rid of bulk items. Schedule, ...
# 4  Report a problem with heat or hot water in a r...
#
#                                        combined_cats
# 0  Department of Finance Parking Ticket Lookup - ...  \
# 1  3-1-1 Call Center Service Request Status - Gen...
# 2  Department of Finance Property Tax Account Ass...
# 3   Bulk Item Disposal Learn how to get rid of bu...
# 4   Heat or Hot Water Complaint in a Residential ...
#
#                                  combined_cats_lower
# 0  department of finance parking ticket lookup - ...  \
# 1  3-1-1 call center service request status - gen...
# 2  department of finance property tax account ass...
# 3   bulk item disposal learn how to get rid of bu...
# 4   heat or hot water complaint in a residential ...
#
#                                      processed_comps
# 0  department finance parking vehicles ticket loo...  \
# 1  call center service request status general sta...
# 2  department finance property building tax accou...
# 3  bulk item disposal learn get rid bulk items sc...
# 4  heat hot water complaint residential building ...
#
#                                     sentiment_scores    neg    neu    pos
# 0  {'neg': 0.0, 'neu': 0.874, 'pos': 0.126, 'comp...  0.000  0.874  0.126  \
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 2  {'neg': 0.0, 'neu': 0.876, 'pos': 0.124, 'comp...  0.000  0.876  0.124
# 3  {'neg': 0.111, 'neu': 0.889, 'pos': 0.0, 'comp...  0.111  0.889  0.000
# 4  {'neg': 0.308, 'neu': 0.692, 'pos': 0.0, 'comp...  0.308  0.692  0.000
#
#    compound                                  subcat_processed  subcat_servreq
# 0    0.1531   parking ticket lookup ticket plate number known             NaN
# 1    0.0000                    service request status general         general
# 2    0.4019  property tax account assistance bill information             NaN
# 3   -0.2500                                bulk item disposal      bulky item
# 4   -0.5994     heat hot water complaint residential building  heat hot water

# %%
nonlabeled = call_comps[call_comps['subcat_servreq'].isna()]
labeled = call_comps[~call_comps['subcat_servreq'].isna()]

fig,ax = plt.subplots(figsize = (8,4))
plt.hist(call_comps['compound'],bins = 50,density = True,label = 'All Call Complaints')
plt.hist(labeled['compound'],bins = 50,density = True,label = 'Mapped Complaints')
plt.title('Compound Score Density')
plt.legend()
plt.savefig('../Outputs/score_distribution.png')
plt.show()

# %%
serv_req_call_sum = call_comps[['subcat_servreq','count']].groupby(by = 'subcat_servreq').sum().reset_index()
serv_req_call_sum.head()
# Out:
#                   subcat_servreq  count
# 0              abandoned vehicle  43901
# 1  advocate prop refunds credits    276
# 2                    air quality   3742
# 3                   animal abuse   7723
# 4                    animal park    629

# %%
weighted_avg_num = call_comps[['subcat_servreq','subcat','compound','count']].groupby(by = ['subcat_servreq','subcat']).agg({'compound':'mean','count':'sum'})
weighted_avg_num['num'] = weighted_avg_num['compound']*weighted_avg_num['count']
weighted_avg_num = weighted_avg_num.reset_index()
weighted_avg_num = weighted_avg_num[['subcat_servreq','num']].groupby(by = 'subcat_servreq').sum().reset_index()
weighted_avg_num.head(20)
# Out:
#                                        subcat_servreq          num
# 0                                   abandoned vehicle -35431.35600
# 1                       advocate prop refunds credits     42.25560
# 2                                         air quality  -1637.20810
# 3                                        animal abuse  -6663.79055
# 4                                         animal park   -458.75610
# 5                                           appliance      0.00000
# 6                                            asbestos  -1501.50270
# 7                          beach pool sauna complaint   -104.72750
# 8                            benefit card replacement   -496.10400
# 9                                    blocked driveway -31472.80080
# 10                                            boilers  -1889.51550
# 11                                     borough office   -918.23250
# 12                                   bridge condition    -53.72340
# 13                                         bulky item -43421.12480
# 14                                   bus stop shelter   -570.72470
# 15                                       construction -12024.54710
# 16                                     curb condition      0.00000
# 17                                           day care   5919.48670
# 18  department consumer affairs department finance...    130.02970
# 19  department environmental protection street con...     64.74840

# %%
serv_req_weighted_avg = pd.merge(weighted_avg_num,serv_req_call_sum, on = 'subcat_servreq')
serv_req_weighted_avg['weighted_avg_compound'] = serv_req_weighted_avg['num']/serv_req_weighted_avg['count']
serv_req_weighted_avg.head()
# Out:
#                   subcat_servreq          num  count  weighted_avg_compound
# 0              abandoned vehicle -35431.35600  43901              -0.807074
# 1  advocate prop refunds credits     42.25560    276               0.153100
# 2                    air quality  -1637.20810   3742              -0.437522
# 3                   animal abuse  -6663.79055   7723              -0.862850
# 4                    animal park   -458.75610    629              -0.729342

# %%
serv_req_weighted_avg = serv_req_weighted_avg[['subcat_servreq','weighted_avg_compound']]
complaint_type_filtered = pd.merge(complaint_type_filtered,serv_req_weighted_avg,left_on = 'subcat_processed',right_on = 'subcat_servreq')
complaint_type_filtered.head()
# Out:
#                           subcat  count               subcat_processed
# 0                      APPLIANCE  10211                      appliance  \
# 1              Abandoned Vehicle  24179              abandoned vehicle
# 2               Derelict Vehicle  17777              abandoned vehicle
# 3              Derelict Vehicles  36999              abandoned vehicle
# 4  Advocate-Prop Refunds/Credits    170  advocate prop refunds credits
#
#                   subcat_servreq  weighted_avg_compound
# 0                      appliance               0.000000
# 1              abandoned vehicle              -0.807074
# 2              abandoned vehicle              -0.807074
# 3              abandoned vehicle              -0.807074
# 4  advocate prop refunds credits               0.153100

# %%
complaint_type_compound_dict = complaint_type_filtered.set_index('subcat')['weighted_avg_compound'].to_dict()
complaint_type_compound_dict
# Out:
# {'APPLIANCE': 0.0,
#  'Abandoned Vehicle': -0.8070740074257988,
#  'Derelict Vehicle': -0.8070740074257988,
#  'Derelict Vehicles': -0.8070740074257988,
#  'Advocate-Prop Refunds/Credits': 0.1531,
#  'Air Quality': -0.43752220737573494,
#  'Indoor Air Quality': -0.43752220737573494,
#  'Animal Abuse': -0.86285,
#  'Animal-Abuse': -0.86285,
#  'Animal in a Park': -0.7293419713831478,
#  'Asbestos': -0.5208125910509885,
#  'Beach/Pool/Sauna Complaint': -0.19575233644859813,
#  'Benefit Card Replacement': -0.27469767441860465,
#  'Blocked Driveway': -0.5719,
#  'Boilers': -0.627537529060113,
#  'Borough Office': -0.05624012372144301,
#  'Bridge Condition': -0.5267,
#  'Bus Stop Shelter Complaint': -0.7441,
#  'Bus Stop Shelter Placement': -0.7441,
#  'Collection Truck Noise': -0.09766089463854599,
#  'Noise': -0.09766089463854599,
#  'Noise - Commercial': -0.09766089463854599,
#  'Noise - Helicopter': -0.09766089463854599,
#  'Noise - House of Worship': -0.09766089463854599,
#  'Noise - Park': -0.09766089463854599,
#  'Noise - Residential': -0.09766089463854599,
#  'Noise - Street/Sidewalk': -0.09766089463854599,
#  'Noise - Vehicle': -0.09766089463854599,
#  'Construction Safety Enforcement': -0.1846294543053679,
#  'Curb Condition': 0.0,
#  'Department of Consumer Affairs / Department of Finance New License Application Request': 0.04141073248407645,
#  'Department of Environmental Protection Street Condition': 0.06051252336448598,
#  'Department of Finance Parking - Request Copy': -0.16429452054794522,
#  'Department of Finance Parking - Request Status': 0.0,
#  'Department of Finance Parking - Tax Exemption': 0.0,
#  'Department of Finance Property - Property Value': 0.5859,
#  'Department of Finance Property - Real Property Income and Expense Issue': 0.19731749819233546,
#  'Department of Finance Property - Request Copy': 0.0681548551463095,
#  'DOOR/WINDOW': -0.35388374316939886,
#  'Department of Parks and Recreation Internal': 0.18284429621036347,
#  'Disability Rent Increase': 0.32089775332947307,
#  'Damaged Tree': -0.4652883171521036,
#  'Dead/Dying Tree': -0.4652883171521036,
#  'Illegal Tree Damage': -0.4652883171521036,
#  'New Tree Request': -0.4652883171521036,
#  'Day Care': 0.7572581169246513,
#  'Drinking': -0.539474840948525,
#  'Drinking Water': 0.0,
#  'Water Quality': 0.0,
#  'Drug Activity': -0.336360103626943,
#  'ELECTRIC': -0.16452040030792917,
#  'ELEVATOR': -0.6367080278203466,
#  'Elevator': -0.6367080278203466,
#  'Elder Abuse': -0.9087206496519723,
#  'Electrical': -0.7860584376990024,
#  'Electronics Waste Appointment': -0.45647267598842817,
#  'Industrial Waste': -0.45647267598842817,
#  'Executive Inspections': -0.7506,
#  'Ferry Complaint': -0.6932296296296298,
#  'Ferry Inquiry': -0.30135811672388424,
#  'Food Establishment': 0.054655512465373965,
#  'Food Poisoning': -0.8677354176610979,
#  'Forms': 0.23089771768932588,
#  'GENERAL': 0.002118692269898461,
#  'General': 0.002118692269898461,
#  'Graffiti': -0.26504895833333336,
#  'Green Taxi Complaint': -0.42508608703784523,
#  'Taxi Complaint': -0.42508608703784523,
#  'Taxi Compliment': -0.42508608703784523,
#  'Taxi Report': -0.42508608703784523,
#  'HEAT/HOT WATER': -0.508019857963541,
#  'Department of Housing Preservation and Development Literature Request': -0.20664884270193673,
#  'Harboring Bees/Wasps': -0.5267,
#  'Hazardous Materials': 0.0,
#  'Highway Condition': -0.09161333865814696,
#  'Home Delivered Meal - Missed Delivery': -0.296,
#  'Homeless Encampment': -0.184767580139549,
#  'Homeless Person Assistance': 0.3185965724078834,
#  'Housing - Low Income Senior': 0.0,
#  'Housing Options': 0.0,
#  'Illegal Animal Kept as Pet': -0.802,
#  'Illegal Fireworks': -0.6597,
#  'Illegal Parking': -0.62729808414776,
#  'Indoor Sewage': -0.559289898989899,
#  'Lead': -0.33721022530329287,
#  'LinkNYC': -0.45128129496402875,
#  'Literature Request': 0.0,
#  'Litter Basket / Request': -0.7247333333333333,
#  'Lost Property': -0.5574,
#  'Missed Collection (All Materials)': -0.44263881586682036,
#  'Mold': -0.535270321410057,
#  'Mosquitoes': 0.0516,
#  'Non-Emergency Police Matter': -0.11190741437483312,
#  'Non-Residential Heat': -0.6071726202158979,
#  'OUTSIDE BUILDING': -0.1721416589002796,
#  'Other Enforcement': -0.48691381402002865,
#  'PLUMBING': -0.18928015564202333,
#  'Plumbing': -0.18928015564202333,
#  'Panhandling': 0.17214201680672267,
#  'Poison Ivy': -0.8158836879432625,
#  'Quality of Life': 0.0,
#  'Recycling Enforcement': -0.21642926976301793,
#  'Request Large Bulky Item Collection': -0.28422174744063045,
#  'Rodent': -0.3346203314917127,
#  'Root/Sewer/Sidewalk Condition': -0.08334375863183567,
#  'Sewer': -0.08334375863183567,
#  'SAFETY': 0.1726016891554223,
#  'Safety': 0.1726016891554223,
#  'Senior Citizen Rent Increase': 0.16327436895766653,
#  'Sanitation Condition': -0.8845553206360302,
#  'Scaffold Safety': -0.7718405772495756,
#  'School Maintenance': 0.11176920076354883,
#  'Senior Center Complaint': -0.56305,
#  'Sidewalk Condition': -0.6558193250487662,
#  'Smoking': -0.2558786487656994,
#  'Snow': -0.21274266409266412,
#  'Standing Water': 0.0,
#  'Street Condition': -0.1047463624039765,
#  'Street Light Condition': -0.43075646028390213,
#  'Street Sign - Damaged': -0.7845,
#  'Street Sign - Dangling': -0.3612,
#  'Street Sign - Missing': -0.6808,
#  'Sweeping/Inadequate': -0.8225000000000001,
#  'Tattooing': 0.0,
#  'Traffic': -0.33430734702317516,
#  'Unleashed Dog': 0.0,
#  'Urinating in Public': 0.0,
#  'Vacant Lot': -0.505512025012025,
#  'Vending': 0.0,
#  'WATER LEAK': -0.48119914717777384}

# %%
import pickle

with open('../Outputs/serv_req_compound_score.pickle', 'wb') as f:
    pickle.dump(complaint_type_compound_dict, f)

# %%
call_comps[['subcat_servreq','subcat','compound','count']].groupby(by = ['subcat_servreq','subcat']).agg({'compound':'mean','count':'sum'}).sort_values(by = 'compound',ascending = False).tail(20)
# Out:
#                                                                                 compound
# subcat_servreq              subcat
# elder abuse                 Elder Abuse - Manhattan                              -0.9081  \
#                             Elder Abuse - Queens                                 -0.9081
# outside building            Garbage or Recycling Storage Complaint - Outsid...   -0.9081
# sidewalk condition          Dead Animal on Street or Sidewalk - Priority         -0.9081
# elder abuse                 Elder Abuse                                          -0.9081
# highway condition           Dead Animal on Highway - Evenings and Saturdays      -0.9081
# non emergency police matter Police Officer Complaint                             -0.9100
# boilers                     Boiler Inspection Violation                          -0.9153
# sanitation condition        Department of Sanitation Worker or Vehicle Comp...   -0.9168
# taxi                        Taxi Complaint - Broken or Missing Equipment         -0.9186
# elder abuse                 Elder Abuse - Brooklyn - Limited Information or...   -0.9231
# sanitation condition        Department of Sanitation Vehicle Accident            -0.9325
# drug activity               Drug Rehabilitation Program Complaint                -0.9337
# food poisoning              Food Poisoning Complaint - 3 or More People Sick     -0.9360
#                             Food Poisoning Complaint - 1 or 2 People Sick        -0.9360
# sidewalk condition          Dispute New Sidewalk Violation - Reinspection R...   -0.9382
# boilers                     Boiler Inspection Notice of Violation                -0.9432
# sanitation condition        Sanitation Vehicle Accident                          -0.9501
# school                      Public School Bullying Complaint                     -0.9571
# forms                       Illegal Dumping Tip Form                             -0.9595
#
#                                                                                 count
# subcat_servreq              subcat
# elder abuse                 Elder Abuse - Manhattan                               188
#                             Elder Abuse - Queens                                  220
# outside building            Garbage or Recycling Storage Complaint - Outsid...   1728
# sidewalk condition          Dead Animal on Street or Sidewalk - Priority         6215
# elder abuse                 Elder Abuse                                          1544
# highway condition           Dead Animal on Highway - Evenings and Saturdays       101
# non emergency police matter Police Officer Complaint                             4664
# boilers                     Boiler Inspection Violation                           251
# sanitation condition        Department of Sanitation Worker or Vehicle Comp...   3821
# taxi                        Taxi Complaint - Broken or Missing Equipment          101
# elder abuse                 Elder Abuse - Brooklyn - Limited Information or...    107
# sanitation condition        Department of Sanitation Vehicle Accident             573
# drug activity               Drug Rehabilitation Program Complaint                 101
# food poisoning              Food Poisoning Complaint - 3 or More People Sick      219
#                             Food Poisoning Complaint - 1 or 2 People Sick        1073
# sidewalk condition          Dispute New Sidewalk Violation - Reinspection R...   2468
# boilers                     Boiler Inspection Notice of Violation                 190
# sanitation condition        Sanitation Vehicle Accident                           542
# school                      Public School Bullying Complaint                      710
# forms                       Illegal Dumping Tip Form                              123

# %%
call_comps = call_comps.rename(columns = {'subcat_servreq': 'Service Request Complaint','subcat':'Call Complaint'})
call_comps[['Service Request Complaint','Call Complaint','compound']].groupby(by = ['Service Request Complaint','Call Complaint']).mean().sort_values(by = 'compound',ascending = False).tail(10)
# Out:
#                                                                               compound
# Service Request Complaint Call Complaint
# elder abuse               Elder Abuse - Brooklyn - Limited Information or...   -0.9231
# sanitation condition      Department of Sanitation Vehicle Accident            -0.9325
# drug activity             Drug Rehabilitation Program Complaint                -0.9337
# food poisoning            Food Poisoning Complaint - 3 or More People Sick     -0.9360
#                           Food Poisoning Complaint - 1 or 2 People Sick        -0.9360
# sidewalk condition        Dispute New Sidewalk Violation - Reinspection R...   -0.9382
# boilers                   Boiler Inspection Notice of Violation                -0.9432
# sanitation condition      Sanitation Vehicle Accident                          -0.9501
# school                    Public School Bullying Complaint                     -0.9571
# forms                     Illegal Dumping Tip Form                             -0.9595

# %%
call_comps[['Service Request Complaint','Call Complaint','compound']].groupby(by = ['Service Request Complaint','Call Complaint']).mean().sort_values(by = 'compound',ascending = False).head(10)
# Out:
#                                                                                  compound
# Service Request Complaint    Call Complaint
# forms                        Social Security - Benefits Application and Assi...    0.9153
#                              Child Care Financial Assistance - Eligibility a...    0.9062
# senior citizen rent increase Senior Citizen Rent Increase Exemption Ombudspe...    0.8750
# day care                     Day Care Center Referrals                             0.8625
# forms                        Ready to Rent - Free Affordable Housing Applica...    0.8442
# construction                 Residential Construction Tax Benefit Programs         0.8176
#                              Commercial Construction Tax Benefit Programs          0.7845
# forms                        Social Security - Card Application or Replacement     0.7579
# general                      Child Care Financial Assistance - General Infor...    0.7506
# day care                     Adult Day Care                                        0.7506
