# %%
import pandas as pd 
import numpy as np 
import geopandas as gpd 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import censusdata
warnings.simplefilter(action="ignore", category=FutureWarning)
# %matplotlib inline

# %%
income = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/FINALFINAL/Income.csv')

# %%
pea = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/FINALFINAL/poverty_ea.csv')

# %%
race = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/FINALFINAL/Race.csv')

# %%
sd = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/FINALFINAL/streetdensity.csv')

# %%
crime = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/FINALFINAL/NTA_Aggregated_Crime_Complaints2019.csv')

# %%
income.columns
# Out:
# Index(['NTAName_left', 'Population', 'Weighted Median Income'], dtype='object')

# %%
pea.columns
# Out:
# Index(['NTAName', 'PovPop', 'Below Poverty Line %', 'EAPop',
#        'Bachelor degree'],
#       dtype='object')

# %%
race.columns
# Out:
# Index(['NTAName_y', 'Total', 'White, not hispanic',
#        'Black or African American, not hispanic',
#        'American Indian and Alaska Native, not hispanic',
#        'Asain, not hispanic',
#        'Native Hawaiian and Other Pacific Islander, not hispanic',
#        'Some other race alone, not hispanic',
#        'Two or More Races, not hispanic', 'Hispanic or Latino'],
#       dtype='object')

# %%
sd.columns
# Out:
# Index(['NTAName', 'Normalized'], dtype='object')

# %%
crime.columns
# Out:
# Index(['Unnamed: 0', 'NTAName', 'Total_NYPD_Complaints'], dtype='object')

# %%
race = race.rename(columns = {'NTAName_y':'NTAName'})

# %%
income = income.rename(columns = {'NTAName_left':'NTAName'})

# %%
crime = crime.drop('Unnamed: 0', axis=1)

# %%
crime
# Out:
#                                     NTAName  Total_NYPD_Complaints
# 0                                  Allerton                   1852
# 1                           Alley Pond Park                     30
# 2    Annadale-Huguenot-Prince's Bay-Woodrow                    781
# 3                   Arden Heights-Rossville                    424
# 4                         Astoria (Central)                   1723
# ..                                      ...                    ...
# 229             Windsor Terrace-South Slope                    502
# 230                               Woodhaven                   1106
# 231                       Woodlawn Cemetery                    203
# 232                                Woodside                   1432
# 233         Yankee Stadium-Macombs Dam Park                    544
#
# [234 rows x 2 columns]

# %%
m = pd.merge(income, pea, on='NTAName')

# %%
mm = pd.merge(m, race, on='NTAName')

# %%
merged = pd.merge(mm, sd, on='NTAName')

# %%
merged = merged.rename(columns = {'Normalized':'NormalizedSD'})

# %%
M = pd.merge(merged, crime, on='NTAName')

# %%
M
# Out:
#                                     NTAName   Population  \
# 0                                  Allerton  3117.473684
# 1                           Alley Pond Park  4118.636364
# 2    Annadale-Huguenot-Prince's Bay-Woodrow  5090.315789
# 3                   Arden Heights-Rossville  4266.533333
# 4                         Astoria (Central)  3012.892857
# ..                                      ...          ...
# 188                Williamsbridge-Olinville  3314.289474
# 189                            Williamsburg  4570.125000
# 190             Windsor Terrace-South Slope  2884.850000
# 191                               Woodhaven  2885.523810
# 192                                Woodside  3329.875000
#
#      Weighted Median Income  PovPop  Below Poverty Line %  EAPop  \
# 0              62141.291295   36057             24.602712  29883
# 1             107518.289372      42              7.142857     39
# 2             126245.529571   44139              5.965246  35230
# ...

# %%
M = M.drop('PovPop', axis=1)

# %%
M['Total_NYPD_Complaints'] = M['Total_NYPD_Complaints'] / M['EAPop']

# %%
M
# Out:
#                                     NTAName   Population  \
# 0                                  Allerton  3117.473684
# 1                           Alley Pond Park  4118.636364
# 2    Annadale-Huguenot-Prince's Bay-Woodrow  5090.315789
# 3                   Arden Heights-Rossville  4266.533333
# 4                         Astoria (Central)  3012.892857
# ..                                      ...          ...
# 188                Williamsbridge-Olinville  3314.289474
# 189                            Williamsburg  4570.125000
# 190             Windsor Terrace-South Slope  2884.850000
# 191                               Woodhaven  2885.523810
# 192                                Woodside  3329.875000
#
#      Weighted Median Income  Below Poverty Line %  EAPop  Bachelor degree  \
# 0              62141.291295             24.602712  29883         7.867349
# 1             107518.289372              7.142857     39         0.000000
# ...

# %%
sev = pd.read_csv('/Users/ananyarajesh/Desktop/MLC_Data/FINALFINAL/nta_complaint_severity_2019.csv')

# %%
sev = sev.drop('Unnamed: 0', axis=1)

# %%
MERGE = pd.merge(M, sev, on='NTAName')

# %%
MERGE
# Out:
#                                     NTAName   Population  \
# 0                                  Allerton  3117.473684
# 1                           Alley Pond Park  4118.636364
# 2    Annadale-Huguenot-Prince's Bay-Woodrow  5090.315789
# 3                   Arden Heights-Rossville  4266.533333
# 4                         Astoria (Central)  3012.892857
# ..                                      ...          ...
# 188                Williamsbridge-Olinville  3314.289474
# 189                            Williamsburg  4570.125000
# 190             Windsor Terrace-South Slope  2884.850000
# 191                               Woodhaven  2885.523810
# 192                                Woodside  3329.875000
#
#      Weighted Median Income  Below Poverty Line %  EAPop  Bachelor degree  \
# 0              62141.291295             24.602712  29883         7.867349
# 1             107518.289372              7.142857     39         0.000000
# ...

# %%
#MERGE.to_csv('mergedregressors.csv', index=False)
